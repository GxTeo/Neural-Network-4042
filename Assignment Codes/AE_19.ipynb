# %%
import math
import random
import os
import time
import json
from functools import partial
from collections import defaultdict

import numpy as np
import pandas as pd

# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf

# %% [markdown]
# ### Check Version

# %%
tf.__version__
# Out:
# '2.9.1'

# %% [markdown]
# ### GPU Configuration

# %%
gpus = tf.config.list_physical_devices('GPU')
# Out:
# 2022-11-06 03:56:36.861379: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:36.868210: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:36.869500: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ### Pandas Config

# %%
pd.set_option('display.max_column', None)

# %% [markdown]
# ### Input Pipeline

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256

TRAIN_BATCH_SIZE = 4
VAL_BATCH_SIZE = 4

# %%
CROP_WIDTH = 227
CROP_HEIGHT = 227

# %%
foldFiles = ["adience/unprocessed/fold_0_data.txt",
             "adience/unprocessed/fold_1_data.txt",
             "adience/unprocessed/fold_2_data.txt",
             "adience/unprocessed/fold_3_data.txt",
             "adience/unprocessed/fold_4_data.txt"]

# %%
genderMap = defaultdict(lambda : np.NaN)
genderMap['m'] = 0
genderMap['f'] = 1

# %%
ages = ['(0, 2)', '(4, 6)', '(8, 13)', '(15, 20)', '(25, 32)', '(38, 43)', '(48, 53)', '(60, 100)']
ageMap = defaultdict(lambda : np.NaN)
for i,a in enumerate(ages):
    ageMap[a] = i

# %% [markdown]
# ### Dataset Generation

# %% [markdown]
# Dataset generation pipeline:
# Input:
# - foldFile - Path to fold file. Fold file Describes which images are in the fold and its corresponding labels
# - imgBaseFolder - Base folder to search image from
# - imgPrefix - Prefix of image file
# - genderMap - Map from ['m', 'f', 'u', None], to one hot index
# - ageMap - Map from age category to one hot index
# - imgWidth - Resulting image width
# - imgHeigh - Resulting image height
# - batchSize - Int or None, batch size
# - configureDs - Function accepting dataset for performance configurations
# - preBatch - List of (name, functions) pair that will be mapped before batching. name is used as name parameters for tf graph
# - postBatch - List of (name, functions) that will be mapped after batching. name is used as name parameters for tf graph
#
# The processing functions should have signature function(img, label) -> (img, label)
#
# Pipeline
#
# Read Fold File -> Preprocess filename and labels (dataframe) -> Convert filename and labels to numpy array -> Convert filename and labels to tf dataset -> Parse images and labels -> Configure Dataset for performance -> Pre-Batching preprocessing -> Batch -> Post-Batching preprocessing -> Output
#
# Some preprocessing steps can only be done before and some can only be done after batching, thats why there are seperated pre and post batching list

# %%
def generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, batchSize, configureDs=None, preBatch=[], postBatch=[]):
    
    def parseImage(filename):
        img = tf.io.read_file(filename)
        img = tf.image.decode_jpeg(img)
        img = tf.image.resize(img, [imgHeight, imgWidth])
         
        return img
    
    # Read Fold File
    foldData = []
    for f in foldFiles:
        foldData.append(pd.read_csv(f, sep="\t"))
    foldData = pd.concat(foldData)
    
    # Form File Name
    foldData['filename'] = foldData.apply(lambda r: os.path.join(imgBaseFolder, r['user_id'], f"{imgPrefix}.{r['face_id']}.{r['original_image']}"), axis=1)
    
    # Generate Label One Hot Index
    foldData['gender_ind'] = foldData['gender'].map(genderMap)
    foldData['age_ind'] = foldData['age'].map(ageMap)
    
    # Remove dirty data
    foldData.dropna(subset=['gender_ind', 'age_ind'], inplace=True)
    
    # Dataframe to numpy
    filenames = foldData['filename'].to_numpy()
    
    genderIndex = foldData['gender_ind'].to_numpy().astype(int)
    ageIndex = foldData['age_ind'].to_numpy().astype(int)
    
    # Numpy to Dataset
    fnDs = tf.data.Dataset.from_tensor_slices(filenames)
    genderIndDs = tf.data.Dataset.from_tensor_slices(genderIndex)
    ageIndDs = tf.data.Dataset.from_tensor_slices(ageIndex)
    
    # Parse Images
    imageDs = fnDs.map(parseImage, num_parallel_calls=tf.data.AUTOTUNE, name="parse_image")
    
    # Parse Labels
    genderLabDs = genderIndDs.map(lambda x: tf.one_hot(x, genderDepth), num_parallel_calls=tf.data.AUTOTUNE, name="gender_one_hot")
    ageLabDs = ageIndDs.map(lambda x: tf.one_hot(x, ageDepth), num_parallel_calls=tf.data.AUTOTUNE, name="age_one_hot")
    
    # Combine Labels
    labelDs = tf.data.Dataset.zip((genderLabDs, ageLabDs), name="label_zip")
    labelDs = labelDs.map(lambda g,a: {"gender": g, "age": a}, num_parallel_calls=tf.data.AUTOTUNE, name='label_dict')
    
    # Combine Images and Labels into dataset
    ds = tf.data.Dataset.zip((imageDs, labelDs))
    
    # Configure Performance
    if(configureDs is not None):
        ds = configureDs(ds)
    
    # Pre Batch Preprocessing
    for n,f in preBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    # Batch
    if(batchSize is not None):
        ds = ds.batch(batchSize, name="ds_batch")
    
    # Post Batch Preprocessing
    for n,f in postBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    return ds

# %% [markdown]
# ### Preprocessings

# %%
def trainConfigPerformance(ds):
    #ds = ds.cache()
    ds = ds.shuffle(buffer_size=100)
    ds = ds.repeat()
    return ds

# %%
def valConfigPerformance(ds):
    #ds = ds.cache()
    return ds

# %% [markdown]
# #### Preprocessing steps

# %%
def trainPreprocessA(img, lab):
        
        ud = tf.random.uniform([], dtype=tf.float32)
        udCond = tf.less(ud, 0.5)
        
        img = tf.cond(udCond, lambda: tf.image.flip_up_down(img), lambda: img)
        
        lr = tf.random.uniform([], dtype=tf.float32)
        lrCond = tf.less(lr, 0.5)
        
        img = tf.cond(lrCond, lambda: tf.image.flip_left_right(img), lambda: img)
        
        img = tf.image.random_brightness(img, 63/255)
        
        img = tf.image.random_contrast(img, 0.2, 1.8)
        
        return img, lab

# %%
def preprocessB(img, lab, rotL, rotH, shXL, shXH, shYL, shYH, zoomL, zoomH, hTransL, hTransH, vTransL, vTransH):
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    rRot = tf.random.uniform([shape[0]], minval=rotL, maxval=rotH, dtype=tf.float32)
    rShearX = tf.random.uniform([shape[0]], minval=shXL, maxval=shXH, dtype=tf.float32)
    rShearY = tf.random.uniform([shape[0]], minval=shYL, maxval=shYH, dtype=tf.float32)
    rZoom = tf.random.uniform([shape[0]], minval=zoomL, maxval=zoomH, dtype=tf.float32) #% Zoom
    rTx = tf.random.uniform([shape[0]], minval=hTransL, maxval=hTransH, dtype=tf.float32) #% Horiz Translation
    rTy = tf.random.uniform([shape[0]], minval=vTransL, maxval=vTransH, dtype=tf.float32) #% Vert Translation

    cT = tf.math.cos(rRot)
    sT = tf.math.sin(rRot)

    one = tf.ones([shape[0]], dtype=tf.float32)
    zero = tf.zeros([shape[0]], dtype=tf.float32)

    transC = tf.stack([[1, 0, -shapeF[2]/2], [0, 1, -shapeF[1]/2], [0, 0, 1]])
    transCI = tf.stack([[1, 0, shapeF[2]/2], [0, 1, shapeF[1]/2], [0, 0, 1]])

    trans = tf.transpose(tf.stack([[one, zero, rTx*shapeF[2]], [zero, one, rTy*shapeF[1]], [zero, zero, one]]), [2,0,1])
    rot = tf.transpose(tf.stack([[cT, -sT, zero], [sT, cT, zero], [zero, zero, one]]), [2,0,1])
    scale = tf.transpose(tf.stack([[rZoom, rShearX, zero], [rShearY, rZoom, zero], [zero, zero, one]]), [2,0,1])

    rotScale = rot@scale

    afTMat = transCI @ trans @ rotScale @ transC
    afT = tf.reshape(afTMat, [shape[0], -1])[:,:-1]

    img = tf.raw_ops.ImageProjectiveTransformV3(interpolation='NEAREST', images=img, transforms=afT, output_shape=shape[1:3], fill_value=0)

    return img, lab

# %%
def preprocessNoise(img, lab, gMean, gStd, spAmountP, spRatio, speckleVar):
        
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    # Gaussian Noise
    gNoise = tf.random.normal(shape, gMean, gStd)

    img += gNoise

    # Salt and pepper noise
    spMask = tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spAmountP), tf.float32)
    spNoise = 255*tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spRatio), tf.float32)

    img = tf.math.add(tf.math.multiply(img, 1.0 - spMask), tf.math.multiply(spNoise, spMask))

    # Speckles
    sNoise = speckleVar * tf.random.normal(shape)
    img = img + tf.math.multiply(img, sNoise)

    img = tf.clip_by_value(img, 0, 255)

    return img, lab

# %%
def clipValue(img, lab):
    img = tf.clip_by_value(img, 0.0, 255.0)
    return img, lab

# %%
def valPreprocessA(img, lab):
        
        img = tf.image.crop_to_bounding_box(img,
                                            (IMG_HEIGHT-CROP_HEIGHT) // 2,
                                            (IMG_WIDTH-CROP_WIDTH) // 2,
                                            CROP_HEIGHT,
                                            CROP_WIDTH)
        
        return img, lab

# %% [markdown]
# #### Label extractor

# %%
def prepareLabel(img, lab):
    
    lab = lab['gender']
    
    return img, {"recon" : img, "gender" : lab }

# %% [markdown]
# ### Generate Folds for K-Folds validation

# %%
def generateFoldDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, valBatchSize, trainConfigureDs=None, trainPreBatch=[], trainPostBatch=[], valConfigureDs=None, valPreBatch=[], valPostBatch=[]):
    '''
        Returns list of (train, validation) datasets
    '''
    
    N = len(foldFiles)
    
    folds = []
    
    for i in range(N):
        
        trainFiles = foldFiles[:i]
        if(i < N-1):
            trainFiles.extend(foldFiles[i+1:])
            
        valFiles = foldFiles[i]
        
        trainDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, configureDs=trainConfigureDs, preBatch=trainPreBatch, postBatch=trainPostBatch)
        valDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, valBatchSize, configureDs=valConfigureDs, preBatch=valPreBatch, postBatch=valPostBatch)
        
        folds.append((trainDs, valDs))
        
    return folds

# %%
genParams = {
            "rotation": [-math.pi, math.pi],
            "shearX": [-0.2, 0.2],
            "shearY": [-0.2, 0.2],
            
            "zoom": [0.8, 1.2], # +- 20%
            "hTranslation": [-0.2, 0.2], # +- 20%
            "vTranslation": [-0.2, 0.2], # +- 20%
            
            "gaussianMean": 0.0,
            "gaussianStd": 2.0,
            
            "spAmount": 0.0001,
            "spRatio": 0.5,
            
            "speckleVar": 0.01
        }

# %%
trainPreprocessB = partial(preprocessB,
                           rotL = genParams['rotation'][0],
                           rotH = genParams['rotation'][1],
                           shXL = genParams['shearX'][0],
                           shXH = genParams['shearX'][1], 
                           shYL = genParams['shearY'][0],
                           shYH = genParams['shearY'][1],
                           zoomL = genParams['zoom'][0],
                           zoomH = genParams['zoom'][1],
                           hTransL = genParams['hTranslation'][0],
                           hTransH = genParams['hTranslation'][1],
                           vTransL = genParams['vTranslation'][0],
                           vTransH = genParams['vTranslation'][1])

# %%
trainPreprocessC = partial(preprocessNoise,
                           gMean = genParams['gaussianMean'],
                           gStd = genParams['gaussianStd'],
                           spAmountP = genParams['spAmount'],
                           spRatio = genParams['spRatio'],
                           speckleVar = genParams['speckleVar'])

# %%
trainPreBatch = [("train_process_a", trainPreprocessA)]
trainPostBatch = [("train_process_b", trainPreprocessB),
                  ("train_process_c", trainPreprocessC),
                  ("train_clip", clipValue),
                  ("train_prepare_label", prepareLabel)]

valPreBatch = [("val_prepare_label", prepareLabel)]

# %%
folds = generateFoldDs(foldFiles, "adience/faces", "coarse_tilt_aligned_face", genderMap, ageMap, 2, 8, 
                       IMG_WIDTH, IMG_HEIGHT, TRAIN_BATCH_SIZE, VAL_BATCH_SIZE, 
                       trainConfigureDs=trainConfigPerformance, trainPreBatch=trainPreBatch, 
                       trainPostBatch=trainPostBatch,
                       valConfigureDs=valConfigPerformance, valPreBatch=valPreBatch)
# Out:
# 2022-11-06 03:56:37.151831: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 03:56:37.152522: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:37.152848: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:37.153118: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:37.449641: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:37.449907: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:37.450133: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:975] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2022-11-06 03:56:37.450349: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4755 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 3080 Ti, pci bus id: 0000:2d:00.0, compute capability: 8.6

# %%
len(folds)
# Out:
# 5

# %% [markdown]
# ### Check data

# %%
for x,y in folds[0][0].take(1):
    pass

# %%
x
# Out:
# <tf.Tensor: shape=(4, 256, 256, 3), dtype=float32, numpy=
# array([[[[1.18903112e+00, 2.21834612e+00, 0.00000000e+00],
#          [1.49677977e-01, 0.00000000e+00, 1.28376782e+00],
#          [1.07901466e+00, 3.69418955e+00, 0.00000000e+00],
#          ...,
#          [1.42433512e+00, 4.01276350e+00, 0.00000000e+00],
#          [3.12306499e+00, 4.12947267e-01, 0.00000000e+00],
#          [2.01496840e+00, 9.50636387e-01, 0.00000000e+00]],
#
#         [[0.00000000e+00,
]],
#
#
#         [[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [1.93857992e+00, 9.04615223e-01, 0.00000000e+00],
#           [3.02376103e+00, 1.31151485e+00, 2.02159858e+00],
#           ...,
#           [0.00000000e+00, 2.26027155e+00, 2.74299622e+00],
#           [0.00000000e+00, 0.00000000e+00, 1.65056780e-01],
#           [3.13316679e+00, 2.05520964e+00, 2.25812411e+00]],
#
#          [[1.85134029e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [1.66103035e-01, 1.05216002e+00, 5.43814719e-01],
#           ...,
#           [0.00000000e+00, 1.57228208e+00, 0.00000000e+00],
#           [1.27551866e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 1.07160223e+00]],
#
#          [[0.00000000e+00, 9.37588632e-01, 0.00000000e+00],
#           [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [1.12670243e+00, 2.15168214e+00, 1.96066391e+00],
#           ...,
#           [1.52908969e+00, 0.00000000e+00, 6.55490458e-01],
#           [0.00000000e+00, 3.71053505e+00, 1.62976086e-01],
#           [0.00000000e+00, 6.16528571e-01, 0.00000000e+00]],
#
#          ...,
#
#          [[4.86371660e+00, 0.00000000e+00, 1.96771109e+00],
#           [0.00000000e+00, 1.07119896e-01, 0.00000000e+00],
#           [3.57599211e+00, 3.33461583e-01, 8.15752268e-01],
#           ...,
#           [4.56592293e+01, 3.83791199e+01, 2.53472214e+01],
#           [4.40449104e+01, 3.80507240e+01, 2.54472160e+01],
#           [4.69223938e+01, 3.70895348e+01, 2.27985916e+01]],
#
#          [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#           [0.00000000e+00, 1.68682814e-01, 0.00000000e+00],
#           [5.09099364e-01, 0.00000000e+00, 1.37727618e+00],
#           ...,
#           [4.44024582e+01, 3.79760628e+01, 2.66047440e+01],
#           [4.61985664e+01, 3.55474663e+01, 2.77211246e+01],
#           [4.83554268e+01, 3.60137405e+01, 2.76368771e+01]],
#
#          [[2.97168708e+00, 1.81663406e+00, 0.00000000e+00],
#           [0.00000000e+00, 2.34992218e+00, 7.70143643e-02],
#           [4.11899662e+00, 0.00000000e+00, 9.22492504e-01],
#           ...,
#           [4.21906242e+01, 3.41988907e+01, 2.80110664e+01],
#           [4.38423958e+01, 3.65321121e+01, 2.58557281e+01],
#           [4.74047508e+01, 3.43690414e+01, 2.32528725e+01]]]],
#        dtype=float32)>,
#  'gender': <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
#  array([[1., 0.],
#         [1., 0.],
#         [0., 1.],
#         [0., 1.]], dtype=float32)>}

# %%
fig1, ax1 = plt.subplots(nrows=TRAIN_BATCH_SIZE, ncols=1)

if(TRAIN_BATCH_SIZE is None or TRAIN_BATCH_SIZE == 1):
    ax1.imshow(x/255)
    ax1.set_title(y)
else:
    for i in range(TRAIN_BATCH_SIZE):
        ax1[i].imshow(x[i]/255)
        ax1[i].set_title(f"Gender:{y['gender'][i]}")
        
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model

# %%
def createModel(latentSize):
    inp = tf.keras.Input(shape=(IMG_HEIGHT, IMG_WIDTH, 3))

    encoder = tf.keras.Sequential([
        tf.keras.layers.Conv2D(64, 7, strides=(4,4), padding='same', activation='relu', name='enc_conv1'),
        tf.keras.layers.Conv2D(128, 5, strides=(2,2), padding='same', activation='relu', name='enc_conv2'),
        tf.keras.layers.Conv2D(256, 3, strides=(2,2), padding='same', activation='relu', name='enc_conv3'),
        tf.keras.layers.Conv2D(32, 1, padding='same', activation='relu', name='enc_conv4'),
        tf.keras.layers.Flatten(name="enc_flat"),
        tf.keras.layers.Dense(latentSize, name="enc_out")
    ], name='enc')
    
    decoder = tf.keras.Sequential([
        tf.keras.layers.InputLayer(input_shape=(latentSize), name='dec_inp'),
        tf.keras.layers.Dense(8*8*64, activation='relu', name='dec_fc1'),
        tf.keras.layers.Reshape(target_shape=(8,8,64), name='dec_reshape'),
        tf.keras.layers.Conv2DTranspose(128, 3, strides=(2,2), padding='same', activation='relu', name='dec_deconv1'),
        tf.keras.layers.Conv2DTranspose(256, 3, strides=(2,2), padding='same', activation='relu', name='dec_deconv2'),
        tf.keras.layers.Conv2DTranspose(128, 3, strides=(2,2), padding='same', activation='relu', name='dec_deconv3'),
        tf.keras.layers.Conv2DTranspose(64, 3, strides=(2,2), padding='same', activation='relu', name='dec_deconv4'),
        tf.keras.layers.Conv2DTranspose(3, 3, strides=(2,2), padding='same', activation='tanh', name='dec_deconv5')
    ], name='dec')

    fc1 = tf.keras.layers.Dense(258, activation='relu', name='fc1')
    do1 = tf.keras.layers.Dropout(0.5, name='do1')

    fc2 = tf.keras.layers.Dense(2, activation='softmax', name='gender_out')
    
    # Preprocess Input
    preInp = inp / 127.5 - 1.0
    
    latent = encoder(preInp)
    recon = decoder(latent)
    recon = tf.math.multiply((recon + 1.0), 127.5, name='recon')
    
    o = fc1(latent)
    o = do1(o)
    
    outLab = fc2(o)
    
    model = tf.keras.models.Model(inputs=inp, outputs={"recon": recon, "gender": outLab}, name='AE_19')
    
    #encoder.summary()
    #decoder.summary()
    
    return model

# %%
LATENT_SIZE = 128

# %%
model = createModel(LATENT_SIZE)

# %%
model.summary()
# Out:
# Model: "AE_19"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 256, 256, 3  0           []
#                                 )]
#
#  tf.math.truediv (TFOpLambda)   (None, 256, 256, 3)  0           ['input_1[0][0]']
#
#  tf.math.subtract (TFOpLambda)  (None, 256, 256, 3)  0           ['tf.math.truediv[0][0]']
#
#  enc (Sequential)               (None, 128)          1566496     ['tf.math.subtract[0][0]']
#
#  fc1 (Dense)                    (None, 258)          33282       ['enc[0][0]']
#
#  dec (Sequential)               (None, 256, 256, 3)  1267971     ['enc[0][0]']
#
#  do1 (Dropout)                  (None, 258)          0           ['fc1[0][0]']
#
#  tf.__operators__.add (TFOpLamb  (None, 256, 256, 3)  0          ['dec[0][0]']
#  da)
#
#  gender_out (Dense)             (None, 2)            518         ['do1[0][0]']
#
#  tf.math.multiply (TFOpLambda)  (None, 256, 256, 3)  0           ['tf.__operators__.add[0][0]']
#
# ==================================================================================================
# Total params: 2,868,267
# Trainable params: 2,868,267
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %% [markdown]
# ### Compile Model

# %%
STEPS_PER_EPOCH = 1000
EPOCH = 300

START_EPOCH = 0
END_EPOCH = START_EPOCH + EPOCH

# %% [markdown]
# #### Learning Rate Schedule

# %%
def schedule(epoch, lr):
    return lr

# %%
logBasePath = "log/AE_19"
logPrefix = "log"

# %%
for i, (train, val) in enumerate([folds[0]]):
    
    model = createModel(LATENT_SIZE)
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.0002, beta_1=0.98)
    loss = {"gender": tf.keras.losses.CategoricalCrossentropy(), "recon": tf.keras.losses.MeanSquaredError()}
    lossWeight = {"gender": 2500, "recon": 1}
    metrics = {"gender": 'accuracy'}
    
    model.compile(optimizer=opt, loss=loss, loss_weights=lossWeight, metrics=metrics)
    
    tboardCb = tf.keras.callbacks.TensorBoard(log_dir=f"{logBasePath}/{logPrefix}_{i}", histogram_freq=1, profile_batch=(2,10))
    lrSchedule = tf.keras.callbacks.LearningRateScheduler(schedule)
    
    cbs = [tboardCb]
    
    model.evaluate(val)
    model.fit(train, initial_epoch=START_EPOCH, epochs=END_EPOCH, steps_per_epoch=STEPS_PER_EPOCH, callbacks=cbs, validation_data=val)
# Out:
# 2022-11-06 03:56:43.540425: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-06 03:56:43.540446: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-06 03:56:43.540466: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1665] Profiler found 1 GPUs
# 2022-11-06 03:56:43.658575: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-06 03:56:43.659904: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1799] CUPTI activity buffer flushed
# 2022-11-06 03:56:44.314476: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8101
#   13/3528 [..............................] - ETA: 15s - loss: 7135.4663 - gender_out_loss: 0.6881 - tf.math.multiply_1_loss: 5415.1494 - gender_out_accuracy: 0.5577
# 2022-11-06 03:56:45.093006: I tensorflow/stream_executor/cuda/cuda_blas.cc:1786] TensorFloat-32 will be used for the matrix multiplication. This will only be logged once.
# 3528/3528 [==============================] - 15s 4ms/step - loss: 7733.5308 - gender_out_loss: 0.6973 - tf.math.multiply_1_loss: 5990.3931 - gender_out_accuracy: 0.4771
# Epoch 1/300
#    1/1000 [..............................] - ETA: 14:20 - loss: 10579.8438 - gender_out_loss: 0.6772 - tf.math.multiply_1_loss: 8886.7646 - gender_out_accuracy: 0.2500
# 2022-11-06 03:56:59.220447: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-06 03:56:59.220473: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
#   10/1000 [..............................] - ETA: 1:11 - loss: 9608.9512 - gender_out_loss: 0.7197 - tf.math.multiply_1_loss: 7809.6807 - gender_out_accuracy: 0.3750
# 2022-11-06 03:56:59.701991: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-11-06 03:56:59.702835: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1799] CUPTI activity buffer flushed
# 2022-11-06 03:56:59.732950: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:521]  GpuTracer has collected 2918 callback api events and 2877 activity events.
# 2022-11-06 03:56:59.756839: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-06 03:56:59.783249: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59
#
# 2022-11-06 03:56:59.820580: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.trace.json.gz
# 2022-11-06 03:56:59.858429: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59
#
# 2022-11-06 03:56:59.863829: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.memory_profile.json.gz
# 2022-11-06 03:56:59.864639: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59
# Dumped tool data for xplane.pb to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.xplane.pb
# Dumped tool data for overview_page.pb to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.overview_page.pb
# Dumped tool data for input_pipeline.pb to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to log/AE_19/log_0/plugins/profile/2022_11_06_03_56_59/rachanon-pc1.kernel_stats.pb
# 1000/1000 [==============================] - 21s 21ms/step - loss: 4486.1895 - gender_out_loss: 0.6994 - tf.math.multiply_1_loss: 2737.6648 - gender_out_accuracy: 0.5238 - val_loss: 3808.5854 - val_gender_out_loss: 0.6846 - val_tf.math.multiply_1_loss: 2097.1936 - val_gender_out_accuracy: 0.5627
# Epoch 2/300
#    7/1000 [..............................] - ETA: 8s - loss: 3340.5215 - gender_out_loss: 0.6964 - tf.math.multiply_1_loss: 1599.6395 - gender_out_accuracy: 0.3929
# 2022-11-06 03:57:19.584023: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 251658240 exceeds 10% of free system memory.
# 2022-11-06 03:57:19.633328: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 125829120 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 20s 20ms/step - loss: 3276.8269 - gender_out_loss: 0.6926 - tf.math.multiply_1_loss: 1545.4272 - gender_out_accuracy: 0.5303 - val_loss: 3240.9104 - val_gender_out_loss: 0.6839 - val_tf.math.multiply_1_loss: 1531.0548 - val_gender_out_accuracy: 0.5504
# Epoch 3/300
#    8/1000 [..............................] - ETA: 8s - loss: 2695.7935 - gender_out_loss: 0.6762 - tf.math.multiply_1_loss: 1005.2671 - gender_out_accuracy: 0.5000
# 2022-11-06 03:57:39.326709: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 251658240 exceeds 10% of free system memory.
# 2022-11-06 03:57:39.378030: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 125829120 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2921.0017 - gender_out_loss: 0.6631 - tf.math.multiply_1_loss: 1263.3373 - gender_out_accuracy: 0.5882 - val_loss: 3083.4900 - val_gender_out_loss: 0.6871 - val_tf.math.multiply_1_loss: 1365.7218 - val_gender_out_accuracy: 0.5747
# Epoch 4/300
#    8/1000 [..............................] - ETA: 8s - loss: 2644.5154 - gender_out_loss: 0.7028 - tf.math.multiply_1_loss: 887.5406 - gender_out_accuracy: 0.4062
# 2022-11-06 03:57:59.143624: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 251658240 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2834.0522 - gender_out_loss: 0.6848 - tf.math.multiply_1_loss: 1121.9857 - gender_out_accuracy: 0.5510 - val_loss: 2961.3147 - val_gender_out_loss: 0.6843 - val_tf.math.multiply_1_loss: 1250.5492 - val_gender_out_accuracy: 0.5660
# Epoch 5/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2692.2524 - gender_out_loss: 0.6936 - tf.math.multiply_1_loss: 958.2386 - gender_out_accuracy: 0.5042 - val_loss: 2877.2192 - val_gender_out_loss: 0.6851 - val_tf.math.multiply_1_loss: 1164.4019 - val_gender_out_accuracy: 0.5640
# Epoch 6/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2615.1375 - gender_out_loss: 0.6575 - tf.math.multiply_1_loss: 971.4290 - gender_out_accuracy: 0.6165 - val_loss: 2970.0127 - val_gender_out_loss: 0.6907 - val_tf.math.multiply_1_loss: 1243.3309 - val_gender_out_accuracy: 0.5331
# Epoch 7/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2678.8816 - gender_out_loss: 0.6830 - tf.math.multiply_1_loss: 971.4534 - gender_out_accuracy: 0.5652 - val_loss: 2788.1841 - val_gender_out_loss: 0.6787 - val_tf.math.multiply_1_loss: 1091.4146 - val_gender_out_accuracy: 0.5592
# Epoch 8/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2612.7285 - gender_out_loss: 0.6900 - tf.math.multiply_1_loss: 887.7161 - gender_out_accuracy: 0.5368 - val_loss: 2748.5503 - val_gender_out_loss: 0.6802 - val_tf.math.multiply_1_loss: 1048.0121 - val_gender_out_accuracy: 0.5710
# Epoch 9/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2624.7461 - gender_out_loss: 0.6849 - tf.math.multiply_1_loss: 912.4706 - gender_out_accuracy: 0.5645 - val_loss: 2806.7463 - val_gender_out_loss: 0.6833 - val_tf.math.multiply_1_loss: 1098.5096 - val_gender_out_accuracy: 0.5528
# Epoch 10/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2527.6304 - gender_out_loss: 0.6582 - tf.math.multiply_1_loss: 882.1195 - gender_out_accuracy: 0.6047 - val_loss: 2764.1760 - val_gender_out_loss: 0.6859 - val_tf.math.multiply_1_loss: 1049.3315 - val_gender_out_accuracy: 0.5429
# Epoch 11/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2536.4963 - gender_out_loss: 0.6816 - tf.math.multiply_1_loss: 832.5474 - gender_out_accuracy: 0.5470 - val_loss: 2719.3213 - val_gender_out_loss: 0.6902 - val_tf.math.multiply_1_loss: 993.9174 - val_gender_out_accuracy: 0.5290
# Epoch 12/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2504.2046 - gender_out_loss: 0.6920 - tf.math.multiply_1_loss: 774.1564 - gender_out_accuracy: 0.5197 - val_loss: 2670.4424 - val_gender_out_loss: 0.6795 - val_tf.math.multiply_1_loss: 971.6649 - val_gender_out_accuracy: 0.5661
# Epoch 13/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2449.3315 - gender_out_loss: 0.6567 - tf.math.multiply_1_loss: 807.5975 - gender_out_accuracy: 0.6140 - val_loss: 2746.8198 - val_gender_out_loss: 0.6773 - val_tf.math.multiply_1_loss: 1053.4619 - val_gender_out_accuracy: 0.5697
# Epoch 14/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2511.1658 - gender_out_loss: 0.6811 - tf.math.multiply_1_loss: 808.4827 - gender_out_accuracy: 0.5648 - val_loss: 2730.3174 - val_gender_out_loss: 0.6953 - val_tf.math.multiply_1_loss: 991.9855 - val_gender_out_accuracy: 0.5345
# Epoch 15/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2518.0754 - gender_out_loss: 0.6908 - tf.math.multiply_1_loss: 791.1091 - gender_out_accuracy: 0.5403 - val_loss: 2610.0959 - val_gender_out_loss: 0.6776 - val_tf.math.multiply_1_loss: 916.1780 - val_gender_out_accuracy: 0.5810
# Epoch 16/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2490.3740 - gender_out_loss: 0.6790 - tf.math.multiply_1_loss: 792.9340 - gender_out_accuracy: 0.5780 - val_loss: 2740.0615 - val_gender_out_loss: 0.7087 - val_tf.math.multiply_1_loss: 968.4232 - val_gender_out_accuracy: 0.5362
# Epoch 17/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2419.8345 - gender_out_loss: 0.6540 - tf.math.multiply_1_loss: 784.9085 - gender_out_accuracy: 0.6085 - val_loss: 2756.1802 - val_gender_out_loss: 0.7210 - val_tf.math.multiply_1_loss: 953.7126 - val_gender_out_accuracy: 0.4942
# Epoch 18/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2497.9021 - gender_out_loss: 0.6832 - tf.math.multiply_1_loss: 789.7836 - gender_out_accuracy: 0.5497 - val_loss: 2634.9739 - val_gender_out_loss: 0.6820 - val_tf.math.multiply_1_loss: 929.9731 - val_gender_out_accuracy: 0.5632
# Epoch 19/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2446.7498 - gender_out_loss: 0.6903 - tf.math.multiply_1_loss: 720.8828 - gender_out_accuracy: 0.5395 - val_loss: 2650.0698 - val_gender_out_loss: 0.6757 - val_tf.math.multiply_1_loss: 960.9290 - val_gender_out_accuracy: 0.5739
# Epoch 20/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2369.6567 - gender_out_loss: 0.6472 - tf.math.multiply_1_loss: 751.7069 - gender_out_accuracy: 0.6145 - val_loss: 2731.2153 - val_gender_out_loss: 0.6870 - val_tf.math.multiply_1_loss: 1013.8118 - val_gender_out_accuracy: 0.5679
# Epoch 21/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2490.9602 - gender_out_loss: 0.6803 - tf.math.multiply_1_loss: 790.2206 - gender_out_accuracy: 0.5665 - val_loss: 2687.1899 - val_gender_out_loss: 0.7099 - val_tf.math.multiply_1_loss: 912.4645 - val_gender_out_accuracy: 0.5340
# Epoch 22/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2466.0332 - gender_out_loss: 0.6872 - tf.math.multiply_1_loss: 747.9921 - gender_out_accuracy: 0.5520 - val_loss: 2578.1711 - val_gender_out_loss: 0.6769 - val_tf.math.multiply_1_loss: 885.8162 - val_gender_out_accuracy: 0.5733
# Epoch 23/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2470.6499 - gender_out_loss: 0.6830 - tf.math.multiply_1_loss: 763.1850 - gender_out_accuracy: 0.5625 - val_loss: 2639.5671 - val_gender_out_loss: 0.6861 - val_tf.math.multiply_1_loss: 924.2679 - val_gender_out_accuracy: 0.5544
# Epoch 24/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2373.6682 - gender_out_loss: 0.6533 - tf.math.multiply_1_loss: 740.2987 - gender_out_accuracy: 0.6168 - val_loss: 2613.1216 - val_gender_out_loss: 0.6808 - val_tf.math.multiply_1_loss: 911.0571 - val_gender_out_accuracy: 0.5808
# Epoch 25/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2439.5828 - gender_out_loss: 0.6813 - tf.math.multiply_1_loss: 736.3608 - gender_out_accuracy: 0.5648 - val_loss: 2569.7983 - val_gender_out_loss: 0.6749 - val_tf.math.multiply_1_loss: 882.4690 - val_gender_out_accuracy: 0.5684
# Epoch 26/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2439.0862 - gender_out_loss: 0.6832 - tf.math.multiply_1_loss: 731.1729 - gender_out_accuracy: 0.5698 - val_loss: 2645.1353 - val_gender_out_loss: 0.6837 - val_tf.math.multiply_1_loss: 935.9110 - val_gender_out_accuracy: 0.5701
# Epoch 27/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2366.6067 - gender_out_loss: 0.6560 - tf.math.multiply_1_loss: 726.7092 - gender_out_accuracy: 0.6143 - val_loss: 3035.4033 - val_gender_out_loss: 0.8346 - val_tf.math.multiply_1_loss: 948.7982 - val_gender_out_accuracy: 0.5367
# Epoch 28/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2447.0317 - gender_out_loss: 0.6780 - tf.math.multiply_1_loss: 751.9313 - gender_out_accuracy: 0.5740 - val_loss: 2599.4070 - val_gender_out_loss: 0.6886 - val_tf.math.multiply_1_loss: 877.9846 - val_gender_out_accuracy: 0.5450
# Epoch 29/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2428.7400 - gender_out_loss: 0.6852 - tf.math.multiply_1_loss: 715.8113 - gender_out_accuracy: 0.5385 - val_loss: 2529.5298 - val_gender_out_loss: 0.6773 - val_tf.math.multiply_1_loss: 836.2687 - val_gender_out_accuracy: 0.5676
# Epoch 30/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2428.3857 - gender_out_loss: 0.6762 - tf.math.multiply_1_loss: 737.9542 - gender_out_accuracy: 0.5738 - val_loss: 2617.1028 - val_gender_out_loss: 0.6757 - val_tf.math.multiply_1_loss: 927.7977 - val_gender_out_accuracy: 0.5665
# Epoch 31/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2342.9521 - gender_out_loss: 0.6555 - tf.math.multiply_1_loss: 704.2812 - gender_out_accuracy: 0.6190 - val_loss: 2483.1055 - val_gender_out_loss: 0.6699 - val_tf.math.multiply_1_loss: 808.4012 - val_gender_out_accuracy: 0.5755
# Epoch 32/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2340.0691 - gender_out_loss: 0.6757 - tf.math.multiply_1_loss: 650.7584 - gender_out_accuracy: 0.5753 - val_loss: 2506.6780 - val_gender_out_loss: 0.6709 - val_tf.math.multiply_1_loss: 829.5483 - val_gender_out_accuracy: 0.5764
# Epoch 33/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2377.5005 - gender_out_loss: 0.6807 - tf.math.multiply_1_loss: 675.7388 - gender_out_accuracy: 0.5627 - val_loss: 2602.3376 - val_gender_out_loss: 0.6785 - val_tf.math.multiply_1_loss: 906.0598 - val_gender_out_accuracy: 0.5697
# Epoch 34/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2322.6428 - gender_out_loss: 0.6566 - tf.math.multiply_1_loss: 681.2565 - gender_out_accuracy: 0.6127 - val_loss: 2962.8408 - val_gender_out_loss: 0.8383 - val_tf.math.multiply_1_loss: 867.1139 - val_gender_out_accuracy: 0.5275
# Epoch 35/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2364.2158 - gender_out_loss: 0.6724 - tf.math.multiply_1_loss: 683.2243 - gender_out_accuracy: 0.5770 - val_loss: 2495.5420 - val_gender_out_loss: 0.6801 - val_tf.math.multiply_1_loss: 795.2626 - val_gender_out_accuracy: 0.5488
# Epoch 36/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2380.3774 - gender_out_loss: 0.6710 - tf.math.multiply_1_loss: 702.9165 - gender_out_accuracy: 0.5893 - val_loss: 2459.6431 - val_gender_out_loss: 0.6720 - val_tf.math.multiply_1_loss: 779.6633 - val_gender_out_accuracy: 0.5713
# Epoch 37/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2353.1470 - gender_out_loss: 0.6679 - tf.math.multiply_1_loss: 683.3366 - gender_out_accuracy: 0.5903 - val_loss: 2541.5569 - val_gender_out_loss: 0.6811 - val_tf.math.multiply_1_loss: 838.7058 - val_gender_out_accuracy: 0.5721
# Epoch 38/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2280.9758 - gender_out_loss: 0.6477 - tf.math.multiply_1_loss: 661.7789 - gender_out_accuracy: 0.6288 - val_loss: 2477.8809 - val_gender_out_loss: 0.6771 - val_tf.math.multiply_1_loss: 785.1440 - val_gender_out_accuracy: 0.5686
# Epoch 39/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2325.0020 - gender_out_loss: 0.6683 - tf.math.multiply_1_loss: 654.1556 - gender_out_accuracy: 0.5938 - val_loss: 2524.1472 - val_gender_out_loss: 0.6923 - val_tf.math.multiply_1_loss: 793.3238 - val_gender_out_accuracy: 0.5696
# Epoch 40/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2387.2834 - gender_out_loss: 0.6759 - tf.math.multiply_1_loss: 697.4817 - gender_out_accuracy: 0.5798 - val_loss: 2523.0889 - val_gender_out_loss: 0.6746 - val_tf.math.multiply_1_loss: 836.5565 - val_gender_out_accuracy: 0.5698
# Epoch 41/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 
300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2224.5488 - gender_out_loss: 0.6450 - tf.math.multiply_1_loss: 612.1219 - gender_out_accuracy: 0.6380 - val_loss: 2416.7712 - val_gender_out_loss: 0.6648 - val_tf.math.multiply_1_loss: 754.8052 - val_gender_out_accuracy: 0.5824
# Epoch 53/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2307.7661 - gender_out_loss: 0.6683 - tf.math.multiply_1_loss: 636.8901 - gender_out_accuracy: 0.5888 - val_loss: 2448.3093 - val_gender_out_loss: 0.6705 - val_tf.math.multiply_1_loss: 772.0862 - val_gender_out_accuracy: 0.5876
# Epoch 54/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2300.0481 - gender_out_loss: 0.6671 - tf.math.multiply_1_loss: 632.2048 - gender_out_accuracy: 0.6005 - val_loss: 2709.6348 - val_gender_out_loss: 0.7593 - val_tf.math.multiply_1_loss: 811.2824 - val_gender_out_accuracy: 0.5240
# Epoch 55/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2361.9329 - gender_out_loss: 0.6775 - tf.math.multiply_1_loss: 668.1650 - gender_out_accuracy: 0.5860 - val_loss: 2397.8782 - val_gender_out_loss: 0.6613 - val_tf.math.multiply_1_loss: 744.6630 - val_gender_out_accuracy: 0.5954
# Epoch 56/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2275.0347 - gender_out_loss: 0.6548 - tf.math.multiply_1_loss: 637.9341 - gender_out_accuracy: 0.6133 - val_loss: 2409.1953 - val_gender_out_loss: 0.6658 - val_tf.math.multiply_1_loss: 744.6551 - val_gender_out_accuracy: 0.5975
# Epoch 57/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2309.2708 - gender_out_loss: 0.6595 - tf.math.multiply_1_loss: 660.5599 - gender_out_accuracy: 0.6145 - val_loss: 2478.5688 - val_gender_out_loss: 0.6645 - val_tf.math.multiply_1_loss: 817.3347 - val_gender_out_accuracy: 0.6006
# Epoch 58/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2295.3506 - gender_out_loss: 0.6689 - tf.math.multiply_1_loss: 622.9814 - gender_out_accuracy: 0.5890 - val_loss: 2418.5127 - val_gender_out_loss: 0.6666 - val_tf.math.multiply_1_loss: 752.0588 - val_gender_out_accuracy: 0.5778
# Epoch 59/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2227.2417 - gender_out_loss: 0.6365 - tf.math.multiply_1_loss: 635.8679 - gender_out_accuracy: 0.6467 - val_loss: 2428.0129 - val_gender_out_loss: 0.6715 - val_tf.math.multiply_1_loss: 749.3807 - val_gender_out_accuracy: 0.5774
# Epoch 60/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2293.6331 - gender_out_loss: 0.6691 - tf.math.multiply_1_loss: 620.9184 - gender_out_accuracy: 0.5830 - val_loss: 2397.1313 - val_gender_out_loss: 0.6628 - val_tf.math.multiply_1_loss: 740.0865 - val_gender_out_accuracy: 0.5876
# Epoch 61/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2317.8604 - gender_out_loss: 0.6716 - tf.math.multiply_1_loss: 638.9114 - gender_out_accuracy: 0.5895 - val_loss: 2398.9211 - val_gender_out_loss: 0.6597 - val_tf.math.multiply_1_loss: 749.6030 - val_gender_out_accuracy: 0.5954
# Epoch 62/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2300.6067 - gender_out_loss: 0.6504 - tf.math.multiply_1_loss: 674.6736 - gender_out_accuracy: 0.6250 - val_loss: 2413.9619 - val_gender_out_loss: 0.6580 - val_tf.math.multiply_1_loss: 769.0356 - val_gender_out_accuracy: 0.5929
# Epoch 63/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2261.2263 - gender_out_loss: 0.6518 - tf.math.multiply_1_loss: 631.7535 - gender_out_accuracy: 0.6058 - val_loss: 2455.8308 - val_gender_out_loss: 0.6714 - val_tf.math.multiply_1_loss: 777.4540 - val_gender_out_accuracy: 0.5855
# Epoch 64/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2294.4009 - gender_out_loss: 0.6681 - tf.math.multiply_1_loss: 624.0385 - gender_out_accuracy: 0.5962 - val_loss: 2499.5991 - val_gender_out_loss: 0.6685 - val_tf.math.multiply_1_loss: 828.4684 - val_gender_out_accuracy: 0.5858
# Epoch 65/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2298.7554 - gender_out_loss: 0.6666 - tf.math.multiply_1_loss: 632.1722 - gender_out_accuracy: 0.6003 - val_loss: 2424.8835 - val_gender_out_loss: 0.6687 - val_tf.math.multiply_1_loss: 753.0334 - val_gender_out_accuracy: 0.5771
# Epoch 66/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2209.3804 - gender_out_loss: 0.6318 - tf.math.multiply_1_loss: 629.9092 - gender_out_accuracy: 0.6398 - val_loss: 2458.5039 - val_gender_out_loss: 0.6619 - val_tf.math.multiply_1_loss: 803.8278 - val_gender_out_accuracy: 0.6048
# Epoch 67/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2306.8896 - gender_out_loss: 0.6673 - tf.math.multiply_1_loss: 638.7191 - gender_out_accuracy: 0.5885 - val_loss: 2423.1392 - val_gender_out_loss: 0.6777 - val_tf.math.multiply_1_loss: 728.9340 - val_gender_out_accuracy: 0.5690
# Epoch 68/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2315.4641 - gender_out_loss: 0.6745 - tf.math.multiply_1_loss: 629.1635 - gender_out_accuracy: 0.5775 - val_loss: 2377.8174 - val_gender_out_loss: 0.6611 - val_tf.math.multiply_1_loss: 725.0909 - val_gender_out_accuracy: 0.5897
# Epoch 69/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2314.4890 - gender_out_loss: 0.6561 - tf.math.multiply_1_loss: 674.3501 - gender_out_accuracy: 0.6227 - val_loss: 2455.6252 - val_gender_out_loss: 0.6725 - val_tf.math.multiply_1_loss: 774.2573 - val_gender_out_accuracy: 0.5820
# Epoch 70/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2269.5654 - gender_out_loss: 0.6527 - tf.math.multiply_1_loss: 637.7910 - gender_out_accuracy: 0.6130 - val_loss: 2438.8284 - val_gender_out_loss: 0.6652 - val_tf.math.multiply_1_loss: 775.8395 - val_gender_out_accuracy: 0.5971
# Epoch 71/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2276.4473 - gender_out_loss: 0.6604 - tf.math.multiply_1_loss: 625.3305 - gender_out_accuracy: 0.6035 - val_loss: 2577.8120 - val_gender_out_loss: 0.6645 - val_tf.math.multiply_1_loss: 916.4407 - val_gender_out_accuracy: 0.5861
# Epoch 72/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2313.2051 - gender_out_loss: 0.6681 - tf.math.multiply_1_loss: 643.0679 - gender_out_accuracy: 0.5847 - val_loss: 2432.4082 - val_gender_out_loss: 0.6747 - val_tf.math.multiply_1_loss: 745.7466 - val_gender_out_accuracy: 0.5678
# Epoch 73/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2214.3948 - gender_out_loss: 0.6398 - tf.math.multiply_1_loss: 615.0000 - gender_out_accuracy: 0.6388 - val_loss: 2471.8081 - val_gender_out_loss: 0.6659 - val_tf.math.multiply_1_loss: 807.0751 - val_gender_out_accuracy: 0.5858
# Epoch 74/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2315.6130 - gender_out_loss: 0.6685 - tf.math.multiply_1_loss: 644.2776 - gender_out_accuracy: 0.6003 - val_loss: 2414.4268 - val_gender_out_loss: 0.6678 - val_tf.math.multiply_1_loss: 744.8870 - val_gender_out_accuracy: 0.5753
# Epoch 75/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2310.4731 - gender_out_loss: 0.6702 - tf.math.multiply_1_loss: 635.0545 - gender_out_accuracy: 0.5815 - val_loss: 2372.9060 - val_gender_out_loss: 0.6578 - val_tf.math.multiply_1_loss: 728.3832 - val_gender_out_accuracy: 0.6013
# Epoch 76/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2322.3103 - gender_out_loss: 0.6621 - tf.math.multiply_1_loss: 666.9364 - gender_out_accuracy: 0.6102 - val_loss: 2497.5444 - val_gender_out_loss: 0.6904 - val_tf.math.multiply_1_loss: 771.4719 - val_gender_out_accuracy: 0.5588
# Epoch 77/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2240.7856 - gender_out_loss: 0.6431 - tf.math.multiply_1_loss: 633.1365 - gender_out_accuracy: 0.6210 - val_loss: 2436.0269 - val_gender_out_loss: 0.6664 - val_tf.math.multiply_1_loss: 770.0048 - val_gender_out_accuracy: 0.5963
# Epoch 78/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2269.3618 - gender_out_loss: 0.6604 - tf.math.multiply_1_loss: 618.4072 - gender_out_accuracy: 0.5993 - val_loss: 2581.8379 - val_gender_out_loss: 0.6744 - val_tf.math.multiply_1_loss: 895.7593 - val_gender_out_accuracy: 0.5791
# Epoch 79/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2312.7639 - gender_out_loss: 0.6777 - tf.math.multiply_1_loss: 618.3876 - gender_out_accuracy: 0.5727 - val_loss: 2417.4031 - val_gender_out_loss: 0.6622 - val_tf.math.multiply_1_loss: 761.8778 - val_gender_out_accuracy: 0.5944
# Epoch 80/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2196.6934 - gender_out_loss: 0.6335 - tf.math.multiply_1_loss: 612.9309 - gender_out_accuracy: 0.6553 - val_loss: 2455.1553 - val_gender_out_loss: 0.6630 - val_tf.math.multiply_1_loss: 797.7307 - val_gender_out_accuracy: 0.5877
# Epoch 81/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2305.7119 - gender_out_loss: 0.6683 - tf.math.multiply_1_loss: 634.8561 - gender_out_accuracy: 0.6025 - val_loss: 2450.1062 - val_gender_out_loss: 0.6752 - val_tf.math.multiply_1_loss: 762.0320 - val_gender_out_accuracy: 0.5711
# Epoch 82/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2315.3975 - gender_out_loss: 0.6728 - tf.math.multiply_1_loss: 633.4262 - gender_out_accuracy: 0.5692 - val_loss: 2351.2520 - val_gender_out_loss: 0.6536 - val_tf.math.multiply_1_loss: 717.3010 - val_gender_out_accuracy: 0.6048
# Epoch 83/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2298.9229 - gender_out_loss: 0.6648 - tf.math.multiply_1_loss: 636.9263 - gender_out_accuracy: 0.6143 - val_loss: 2449.0908 - val_gender_out_loss: 0.6582 - val_tf.math.multiply_1_loss: 803.4717 - val_gender_out_accuracy: 0.6064
# Epoch 84/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2195.2668 - gender_out_loss: 0.6403 - tf.math.multiply_1_loss: 594.5478 - gender_out_accuracy: 0.6298 - val_loss: 2403.3311 - val_gender_out_loss: 0.6651 - val_tf.math.multiply_1_loss: 740.5610 - val_gender_out_accuracy: 0.5943
# Epoch 85/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2280.6560 - gender_out_loss: 0.6695 - tf.math.multiply_1_loss: 606.8193 - gender_out_accuracy: 0.5778 - val_loss: 2369.6494 - val_gender_out_loss: 0.6524 - val_tf.math.multiply_1_loss: 738.7531 - val_gender_out_accuracy: 0.6060
# Epoch 86/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2303.7998 - gender_out_loss: 0.6768 - tf.math.multiply_1_loss: 611.7864 - gender_out_accuracy: 0.5748 - val_loss: 2414.8582 - val_gender_out_loss: 0.6750 - val_tf.math.multiply_1_loss: 727.2636 - val_gender_out_accuracy: 0.5815
# Epoch 87/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2185.0752 - gender_out_loss: 0.6399 - tf.math.multiply_1_loss: 585.2850 - gender_out_accuracy: 0.6285 - val_loss: 2709.3442 - val_gender_out_loss: 0.7795 - val_tf.math.multiply_1_loss: 760.6138 - val_gender_out_accuracy: 0.5569
# Epoch 88/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2296.5159 - gender_out_loss: 0.6680 - tf.math.multiply_1_loss: 626.6014 - gender_out_accuracy: 0.6003 - val_loss: 2408.8921 - val_gender_out_loss: 0.6742 - val_tf.math.multiply_1_loss: 723.2866 - val_gender_out_accuracy: 0.5816
# Epoch 89/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2282.7485 - gender_out_loss: 0.6687 - tf.math.multiply_1_loss: 611.0078 - gender_out_accuracy: 0.5872 - val_loss: 2348.7173 - val_gender_out_loss: 0.6532 - val_tf.math.multiply_1_loss: 715.7881 - val_gender_out_accuracy: 0.5988
# Epoch 90/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2291.7178 - gender_out_loss: 0.6606 - tf.math.multiply_1_loss: 640.2709 - gender_out_accuracy: 0.6083 - val_loss: 2409.1768 - val_gender_out_loss: 0.6639 - val_tf.math.multiply_1_loss: 749.3700 - val_gender_out_accuracy: 0.5932
# Epoch 91/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2179.4055 - gender_out_loss: 0.6327 - tf.math.multiply_1_loss: 597.5383 - gender_out_accuracy: 0.6400 - val_loss: 2384.6411 - val_gender_out_loss: 0.6482 - val_tf.math.multiply_1_loss: 764.0234 - val_gender_out_accuracy: 0.6134
# Epoch 92/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2272.2690 - gender_out_loss: 0.6653 - tf.math.multiply_1_loss: 609.1296 - gender_out_accuracy: 0.6058 - val_loss: 2357.1511 - val_gender_out_loss: 0.6526 - val_tf.math.multiply_1_loss: 725.5621 - val_gender_out_accuracy: 0.6062
# Epoch 93/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2246.4890 - gender_out_loss: 0.6574 - tf.math.multiply_1_loss: 602.9166 - gender_out_accuracy: 0.6077 - val_loss: 2493.0803 - val_gender_out_loss: 0.6795 - val_tf.math.multiply_1_loss: 794.3248 - val_gender_out_accuracy: 0.5745
# Epoch 94/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2202.5237 - gender_out_loss: 0.6428 - tf.math.multiply_1_loss: 595.6490 - gender_out_accuracy: 0.6290 - val_loss: 2979.4792 - val_gender_out_loss: 0.8753 - val_tf.math.multiply_1_loss: 791.3044 - val_gender_out_accuracy: 0.5353
# Epoch 95/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2283.7224 - gender_out_loss: 0.6632 - tf.math.multiply_1_loss: 625.6025 - gender_out_accuracy: 0.5922 - val_loss: 2424.8879 - val_gender_out_loss: 0.6641 - val_tf.math.multiply_1_loss: 764.6210 - val_gender_out_accuracy: 0.5844
# Epoch 96/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 
300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2264.2048 - gender_out_loss: 0.6708 - tf.math.multiply_1_loss: 587.2542 - gender_out_accuracy: 0.5930 - val_loss: 2409.2388 - val_gender_out_loss: 0.6604 - val_tf.math.multiply_1_loss: 758.1993 - val_gender_out_accuracy: 0.5940
# Epoch 108/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2264.0085 - gender_out_loss: 0.6648 - tf.math.multiply_1_loss: 602.0491 - gender_out_accuracy: 0.5970 - val_loss: 2360.1741 - val_gender_out_loss: 0.6608 - val_tf.math.multiply_1_loss: 708.1430 - val_gender_out_accuracy: 0.5960
# Epoch 109/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2211.5554 - gender_out_loss: 0.6426 - tf.math.multiply_1_loss: 605.1503 - gender_out_accuracy: 0.6240 - val_loss: 2387.9746 - val_gender_out_loss: 0.6671 - val_tf.math.multiply_1_loss: 720.1043 - val_gender_out_accuracy: 0.5771
# Epoch 110/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2242.4316 - gender_out_loss: 0.6615 - tf.math.multiply_1_loss: 588.7404 - gender_out_accuracy: 0.5968 - val_loss: 2380.0989 - val_gender_out_loss: 0.6653 - val_tf.math.multiply_1_loss: 716.7625 - val_gender_out_accuracy: 0.6071
# Epoch 111/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2255.5322 - gender_out_loss: 0.6653 - tf.math.multiply_1_loss: 592.3516 - gender_out_accuracy: 0.5928 - val_loss: 2454.7324 - val_gender_out_loss: 0.6783 - val_tf.math.multiply_1_loss: 759.0524 - val_gender_out_accuracy: 0.5839
# Epoch 112/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2193.3423 - gender_out_loss: 0.6380 - tf.math.multiply_1_loss: 598.3084 - gender_out_accuracy: 0.6405 - val_loss: 2355.7693 - val_gender_out_loss: 0.6562 - val_tf.math.multiply_1_loss: 715.2736 - val_gender_out_accuracy: 0.5985
# Epoch 113/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2277.4102 - gender_out_loss: 0.6684 - tf.math.multiply_1_loss: 606.4963 - gender_out_accuracy: 0.5888 - val_loss: 2366.4514 - val_gender_out_loss: 0.6603 - val_tf.math.multiply_1_loss: 715.6149 - val_gender_out_accuracy: 0.6024
# Epoch 114/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2260.4094 - gender_out_loss: 0.6690 - tf.math.multiply_1_loss: 587.9221 - gender_out_accuracy: 0.5895 - val_loss: 2463.9651 - val_gender_out_loss: 0.6722 - val_tf.math.multiply_1_loss: 783.3505 - val_gender_out_accuracy: 0.5904
# Epoch 115/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2263.6045 - gender_out_loss: 0.6647 - tf.math.multiply_1_loss: 601.9632 - gender_out_accuracy: 0.6028 - val_loss: 2362.9041 - val_gender_out_loss: 0.6597 - val_tf.math.multiply_1_loss: 713.6528 - val_gender_out_accuracy: 0.6043
# Epoch 116/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2205.7837 - gender_out_loss: 0.6401 - tf.math.multiply_1_loss: 605.5890 - gender_out_accuracy: 0.6245 - val_loss: 2357.5168 - val_gender_out_loss: 0.6632 - val_tf.math.multiply_1_loss: 699.5759 - val_gender_out_accuracy: 0.5888
# Epoch 117/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2255.4055 - gender_out_loss: 0.6659 - tf.math.multiply_1_loss: 590.6895 - gender_out_accuracy: 0.5907 - val_loss: 2424.9946 - val_gender_out_loss: 0.6718 - val_tf.math.multiply_1_loss: 745.4576 - val_gender_out_accuracy: 0.6006
# Epoch 118/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2241.8120 - gender_out_loss: 0.6580 - tf.math.multiply_1_loss: 596.8226 - gender_out_accuracy: 0.6108 - val_loss: 2601.0071 - val_gender_out_loss: 0.6621 - val_tf.math.multiply_1_loss: 945.7601 - val_gender_out_accuracy: 0.6024
# Epoch 119/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2177.8511 - gender_out_loss: 0.6313 - tf.math.multiply_1_loss: 599.5869 - gender_out_accuracy: 0.6503 - val_loss: 2409.3899 - val_gender_out_loss: 0.6631 - val_tf.math.multiply_1_loss: 751.5448 - val_gender_out_accuracy: 0.5951
# Epoch 120/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2255.7073 - gender_out_loss: 0.6605 - tf.math.multiply_1_loss: 604.5097 - gender_out_accuracy: 0.6033 - val_loss: 2359.5071 - val_gender_out_loss: 0.6454 - val_tf.math.multiply_1_loss: 745.9221 - val_gender_out_accuracy: 0.6148
# Epoch 121/300
# 1000/1000 [==============================] - 29s 29ms/step - loss: 2236.4158 - gender_out_loss: 0.6617 - tf.math.multiply_1_loss: 582.2458 - gender_out_accuracy: 0.5870 - val_loss: 2570.6345 - val_gender_out_loss: 0.7021 - val_tf.math.multiply_1_loss: 815.4640 - val_gender_out_accuracy: 0.5722
# Epoch 122/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2286.6335 - gender_out_loss: 0.6662 - tf.math.multiply_1_loss: 621.1763 - gender_out_accuracy: 0.6033 - val_loss: 2344.0154 - val_gender_out_loss: 0.6561 - val_tf.math.multiply_1_loss: 703.6528 - val_gender_out_accuracy: 0.6053
# Epoch 123/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2226.4443 - gender_out_loss: 0.6481 - tf.math.multiply_1_loss: 606.2813 - gender_out_accuracy: 0.6177 - val_loss: 2360.4924 - val_gender_out_loss: 0.6599 - val_tf.math.multiply_1_loss: 710.6303 - val_gender_out_accuracy: 0.6136
# Epoch 124/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2258.1851 - gender_out_loss: 0.6593 - tf.math.multiply_1_loss: 609.9608 - gender_out_accuracy: 0.6112 - val_loss: 2423.4866 - val_gender_out_loss: 0.6553 - val_tf.math.multiply_1_loss: 785.1451 - val_gender_out_accuracy: 0.6174
# Epoch 125/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2250.3862 - gender_out_loss: 0.6616 - tf.math.multiply_1_loss: 596.3253 - gender_out_accuracy: 0.6118 - val_loss: 2359.0166 - val_gender_out_loss: 0.6534 - val_tf.math.multiply_1_loss: 725.4099 - val_gender_out_accuracy: 0.5989
# Epoch 126/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2173.5981 - gender_out_loss: 0.6316 - tf.math.multiply_1_loss: 594.5251 - gender_out_accuracy: 0.6435 - val_loss: 2361.3416 - val_gender_out_loss: 0.6509 - val_tf.math.multiply_1_loss: 734.1113 - val_gender_out_accuracy: 0.6140
# Epoch 127/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2256.5686 - gender_out_loss: 0.6601 - tf.math.multiply_1_loss: 606.3487 - gender_out_accuracy: 0.6133 - val_loss: 2332.1702 - val_gender_out_loss: 0.6539 - val_tf.math.multiply_1_loss: 697.3365 - val_gender_out_accuracy: 0.6009
# Epoch 128/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2243.6179 - gender_out_loss: 0.6641 - tf.math.multiply_1_loss: 583.4579 - gender_out_accuracy: 0.6005 - val_loss: 2312.0386 - val_gender_out_loss: 0.6479 - val_tf.math.multiply_1_loss: 692.2896 - val_gender_out_accuracy: 0.6103
# Epoch 129/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2278.1963 - gender_out_loss: 0.6571 - tf.math.multiply_1_loss: 635.4819 - gender_out_accuracy: 0.6175 - val_loss: 2352.5002 - val_gender_out_loss: 0.6565 - val_tf.math.multiply_1_loss: 711.1733 - val_gender_out_accuracy: 0.5951
# Epoch 130/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2211.7327 - gender_out_loss: 0.6405 - tf.math.multiply_1_loss: 610.4730 - gender_out_accuracy: 0.6258 - val_loss: 2362.1499 - val_gender_out_loss: 0.6524 - val_tf.math.multiply_1_loss: 731.1131 - val_gender_out_accuracy: 0.6041
# Epoch 131/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2249.1611 - gender_out_loss: 0.6601 - tf.math.multiply_1_loss: 598.8266 - gender_out_accuracy: 0.6097 - val_loss: 2447.0530 - val_gender_out_loss: 0.6572 - val_tf.math.multiply_1_loss: 804.0828 - val_gender_out_accuracy: 0.5893
# Epoch 132/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2276.4250 - gender_out_loss: 0.6642 - tf.math.multiply_1_loss: 616.0260 - gender_out_accuracy: 0.5928 - val_loss: 2372.8943 - val_gender_out_loss: 0.6583 - val_tf.math.multiply_1_loss: 727.1362 - val_gender_out_accuracy: 0.5869
# Epoch 133/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2165.3582 - gender_out_loss: 0.6229 - tf.math.multiply_1_loss: 608.0218 - gender_out_accuracy: 0.6593 - val_loss: 2415.9453 - val_gender_out_loss: 0.6543 - val_tf.math.multiply_1_loss: 780.2809 - val_gender_out_accuracy: 0.6033
# Epoch 134/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2235.4978 - gender_out_loss: 0.6563 - tf.math.multiply_1_loss: 594.7113 - gender_out_accuracy: 0.6010 - val_loss: 2386.2561 - val_gender_out_loss: 0.6641 - val_tf.math.multiply_1_loss: 726.0342 - val_gender_out_accuracy: 0.5842
# Epoch 135/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2267.4319 - gender_out_loss: 0.6687 - tf.math.multiply_1_loss: 595.6754 - gender_out_accuracy: 0.6030 - val_loss: 2314.3447 - val_gender_out_loss: 0.6468 - val_tf.math.multiply_1_loss: 697.3824 - val_gender_out_accuracy: 0.6132
# Epoch 136/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2274.3147 - gender_out_loss: 0.6557 - tf.math.multiply_1_loss: 635.0649 - gender_out_accuracy: 0.6300 - val_loss: 2411.5303 - val_gender_out_loss: 0.6626 - val_tf.math.multiply_1_loss: 755.0875 - val_gender_out_accuracy: 0.5880
# Epoch 137/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2181.3689 - gender_out_loss: 0.6349 - tf.math.multiply_1_loss: 594.1695 - gender_out_accuracy: 0.6355 - val_loss: 2351.5984 - val_gender_out_loss: 0.6521 - val_tf.math.multiply_1_loss: 721.4594 - val_gender_out_accuracy: 0.6136
# Epoch 138/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2257.0049 - gender_out_loss: 0.6574 - tf.math.multiply_1_loss: 613.6172 - gender_out_accuracy: 0.6130 - val_loss: 2483.7366 - val_gender_out_loss: 0.6701 - val_tf.math.multiply_1_loss: 808.5487 - val_gender_out_accuracy: 0.5948
# Epoch 139/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2275.3733 - gender_out_loss: 0.6720 - tf.math.multiply_1_loss: 595.2803 - gender_out_accuracy: 0.5850 - val_loss: 2363.1416 - val_gender_out_loss: 0.6579 - val_tf.math.multiply_1_loss: 718.4609 - val_gender_out_accuracy: 0.5951
# Epoch 140/300
# ...
# Epoch 250/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2146.3918 - gender_out_loss: 0.6215 - tf.math.multiply_1_loss: 592.5803 - gender_out_accuracy: 0.6417 - val_loss: 2343.0544 - val_gender_out_loss: 0.6533 - val_tf.math.multiply_1_loss: 709.7717 - val_gender_out_accuracy: 0.6470
# Epoch 251/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2233.5132 - gender_out_loss: 0.6586 - tf.math.multiply_1_loss: 586.9997 - gender_out_accuracy: 0.6122 - val_loss: 2389.1587 - val_gender_out_loss: 0.6569 - val_tf.math.multiply_1_loss: 746.9896 - val_gender_out_accuracy: 0.6163
# Epoch 252/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2168.4744 - gender_out_loss: 0.6403 - tf.math.multiply_1_loss: 567.8132 - gender_out_accuracy: 0.6325 - val_loss: 2289.5447 - val_gender_out_loss: 0.6396 - val_tf.math.multiply_1_loss: 690.5100 - val_gender_out_accuracy: 0.6235
# Epoch 253/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2151.1279 - gender_out_loss: 0.6286 - tf.math.multiply_1_loss: 579.5555 - gender_out_accuracy: 0.6628 - val_loss: 2316.4175 - val_gender_out_loss: 0.6417 - val_tf.math.multiply_1_loss: 712.2296 - val_gender_out_accuracy: 0.6268
# Epoch 254/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2232.9849 - gender_out_loss: 0.6563 - tf.math.multiply_1_loss: 592.1688 - gender_out_accuracy: 0.6108 - val_loss: 2298.7888 - val_gender_out_loss: 0.6400 - val_tf.math.multiply_1_loss: 698.9141 - val_gender_out_accuracy: 0.6199
# Epoch 255/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2218.8198 - gender_out_loss: 0.6527 - tf.math.multiply_1_loss: 587.1058 - gender_out_accuracy: 0.6180 - val_loss: 2279.9075 - val_gender_out_loss: 0.6321 - val_tf.math.multiply_1_loss: 699.6084 - val_gender_out_accuracy: 0.6334
# Epoch 256/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2228.1960 - gender_out_loss: 0.6495 - tf.math.multiply_1_loss: 604.4762 - gender_out_accuracy: 0.6345 - val_loss: 2288.7239 - val_gender_out_loss: 0.6333 - val_tf.math.multiply_1_loss: 705.5972 - val_gender_out_accuracy: 0.6209
# Epoch 257/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2155.1221 - gender_out_loss: 0.6261 - tf.math.multiply_1_loss: 589.8028 - gender_out_accuracy: 0.6400 - val_loss: 2338.3040 - val_gender_out_loss: 0.6517 - val_tf.math.multiply_1_loss: 709.0742 - val_gender_out_accuracy: 0.6255
# Epoch 258/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2218.2485 - gender_out_loss: 0.6509 - tf.math.multiply_1_loss: 590.8772 - gender_out_accuracy: 0.6252 - val_loss: 2388.0002 - val_gender_out_loss: 0.6455 - val_tf.math.multiply_1_loss: 774.2535 - val_gender_out_accuracy: 0.6180
# Epoch 259/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2182.8315 - gender_out_loss: 0.6493 - tf.math.multiply_1_loss: 559.6747 - gender_out_accuracy: 0.6212 - val_loss: 2305.2056 - val_gender_out_loss: 0.6415 - val_tf.math.multiply_1_loss: 701.4799 - val_gender_out_accuracy: 0.6130
# Epoch 260/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2112.3875 - gender_out_loss: 0.6153 - tf.math.multiply_1_loss: 574.1773 - gender_out_accuracy: 0.6650 - val_loss: 2311.0261 - val_gender_out_loss: 0.6304 - val_tf.math.multiply_1_loss: 735.1356 - val_gender_out_accuracy: 0.6445
# Epoch 261/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2219.1135 - gender_out_loss: 0.6491 - tf.math.multiply_1_loss: 596.2927 - gender_out_accuracy: 0.6195 - val_loss: 2298.2344 - val_gender_out_loss: 0.6412 - val_tf.math.multiply_1_loss: 695.2983 - val_gender_out_accuracy: 0.6045
# Epoch 262/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2230.4382 - gender_out_loss: 0.6608 - tf.math.multiply_1_loss: 578.3470 - gender_out_accuracy: 0.5978 - val_loss: 2265.8098 - val_gender_out_loss: 0.6312 - val_tf.math.multiply_1_loss: 687.7457 - val_gender_out_accuracy: 0.6388
# Epoch 263/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2212.9304 - gender_out_loss: 0.6397 - tf.math.multiply_1_loss: 613.7883 - gender_out_accuracy: 0.6382 - val_loss: 2299.7175 - val_gender_out_loss: 0.6301 - val_tf.math.multiply_1_loss: 724.4224 - val_gender_out_accuracy: 0.6288
# Epoch 264/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2133.2122 - gender_out_loss: 0.6169 - tf.math.multiply_1_loss: 591.0252 - gender_out_accuracy: 0.6442 - val_loss: 2284.3171 - val_gender_out_loss: 0.6350 - val_tf.math.multiply_1_loss: 696.7560 - val_gender_out_accuracy: 0.6528
# Epoch 265/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2201.4548 - gender_out_loss: 0.6519 - tf.math.multiply_1_loss: 571.7630 - gender_out_accuracy: 0.6263 - val_loss: 2373.4177 - val_gender_out_loss: 0.6373 - val_tf.math.multiply_1_loss: 780.1082 - val_gender_out_accuracy: 0.6473
# Epoch 266/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2185.0303 - gender_out_loss: 0.6435 - tf.math.multiply_1_loss: 576.2242 - gender_out_accuracy: 0.6223 - val_loss: 2332.1252 - val_gender_out_loss: 0.6389 - val_tf.math.multiply_1_loss: 734.8199 - val_gender_out_accuracy: 0.6374
# Epoch 267/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2121.9861 - gender_out_loss: 0.6184 - tf.math.multiply_1_loss: 576.0638 - gender_out_accuracy: 0.6560 - val_loss: 2319.9465 - val_gender_out_loss: 0.6167 - val_tf.math.multiply_1_loss: 778.1734 - val_gender_out_accuracy: 0.6509
# Epoch 268/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2223.2747 - gender_out_loss: 0.6503 - tf.math.multiply_1_loss: 597.5433 - gender_out_accuracy: 0.6273 - val_loss: 2345.3352 - val_gender_out_loss: 0.6603 - val_tf.math.multiply_1_loss: 694.5357 - val_gender_out_accuracy: 0.5818
# Epoch 269/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2209.9763 - gender_out_loss: 0.6605 - tf.math.multiply_1_loss: 558.7595 - gender_out_accuracy: 0.6005 - val_loss: 2236.3489 - val_gender_out_loss: 0.6226 - val_tf.math.multiply_1_loss: 679.7919 - val_gender_out_accuracy: 0.6559
# Epoch 270/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2194.7595 - gender_out_loss: 0.6429 - tf.math.multiply_1_loss: 587.4081 - gender_out_accuracy: 0.6417 - val_loss: 2360.6831 - val_gender_out_loss: 0.6485 - val_tf.math.multiply_1_loss: 739.4210 - val_gender_out_accuracy: 0.6117
# Epoch 271/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2115.7334 - gender_out_loss: 0.6139 - tf.math.multiply_1_loss: 581.1021 - gender_out_accuracy: 0.6503 - val_loss: 2332.8982 - val_gender_out_loss: 0.6458 - val_tf.math.multiply_1_loss: 718.5010 - val_gender_out_accuracy: 0.6201
# Epoch 272/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2223.2996 - gender_out_loss: 0.6625 - tf.math.multiply_1_loss: 567.0410 - gender_out_accuracy: 0.6020 - val_loss: 2281.1794 - val_gender_out_loss: 0.6246 - val_tf.math.multiply_1_loss: 719.7410 - val_gender_out_accuracy: 0.6452
# Epoch 273/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2196.3435 - gender_out_loss: 0.6524 - tf.math.multiply_1_loss: 565.2756 - gender_out_accuracy: 0.6240 - val_loss: 2265.4465 - val_gender_out_loss: 0.6250 - val_tf.math.multiply_1_loss: 702.8970 - val_gender_out_accuracy: 0.6505
# Epoch 274/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2119.2822 - gender_out_loss: 0.6229 - tf.math.multiply_1_loss: 562.1549 - gender_out_accuracy: 0.6575 - val_loss: 2497.4045 - val_gender_out_loss: 0.7077 - val_tf.math.multiply_1_loss: 728.0610 - val_gender_out_accuracy: 0.5940
# Epoch 275/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2205.7786 - gender_out_loss: 0.6497 - tf.math.multiply_1_loss: 581.4951 - gender_out_accuracy: 0.6155 - val_loss: 2370.2175 - val_gender_out_loss: 0.6714 - val_tf.math.multiply_1_loss: 691.7371 - val_gender_out_accuracy: 0.5902
# Epoch 276/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2202.2778 - gender_out_loss: 0.6556 - tf.math.multiply_1_loss: 563.2897 - gender_out_accuracy: 0.6018 - val_loss: 2217.1653 - val_gender_out_loss: 0.6117 - val_tf.math.multiply_1_loss: 687.9736 - val_gender_out_accuracy: 0.6640
# Epoch 277/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2201.1331 - gender_out_loss: 0.6475 - tf.math.multiply_1_loss: 582.3459 - gender_out_accuracy: 0.6330 - val_loss: 2269.8789 - val_gender_out_loss: 0.6260 - val_tf.math.multiply_1_loss: 704.9288 - val_gender_out_accuracy: 0.6435
# Epoch 278/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2091.8901 - gender_out_loss: 0.6062 - tf.math.multiply_1_loss: 576.2776 - gender_out_accuracy: 0.6568 - val_loss: 2370.3799 - val_gender_out_loss: 0.6598 - val_tf.math.multiply_1_loss: 720.7990 - val_gender_out_accuracy: 0.6145
# Epoch 279/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2226.7866 - gender_out_loss: 0.6607 - tf.math.multiply_1_loss: 574.9703 - gender_out_accuracy: 0.6045 - val_loss: 2216.9558 - val_gender_out_loss: 0.6159 - val_tf.math.multiply_1_loss: 677.2650 - val_gender_out_accuracy: 0.6496
# Epoch 280/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2196.9500 - gender_out_loss: 0.6522 - tf.math.multiply_1_loss: 566.4085 - gender_out_accuracy: 0.6208 - val_loss: 2406.4924 - val_gender_out_loss: 0.6569 - val_tf.math.multiply_1_loss: 764.1234 - val_gender_out_accuracy: 0.6097
# Epoch 281/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2116.1306 - gender_out_loss: 0.6173 - tf.math.multiply_1_loss: 572.8936 - gender_out_accuracy: 0.6605 - val_loss: 2733.0281 - val_gender_out_loss: 0.8005 - val_tf.math.multiply_1_loss: 731.6809 - val_gender_out_accuracy: 0.5684
# Epoch 282/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2210.8640 - gender_out_loss: 0.6475 - tf.math.multiply_1_loss: 592.0123 - gender_out_accuracy: 0.6267 - val_loss: 2242.6313 - val_gender_out_loss: 0.6239 - val_tf.math.multiply_1_loss: 682.8940 - val_gender_out_accuracy: 0.6399
# Epoch 283/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2197.9626 - gender_out_loss: 0.6543 - tf.math.multiply_1_loss: 562.2055 - gender_out_accuracy: 0.6060 - val_loss: 2225.8794 - val_gender_out_loss: 0.6151 - val_tf.math.multiply_1_loss: 688.2370 - val_gender_out_accuracy: 0.6579
# Epoch 284/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2190.3303 - gender_out_loss: 0.6367 - tf.math.multiply_1_loss: 598.6345 - gender_out_accuracy: 0.6460 - val_loss: 2316.8389 - val_gender_out_loss: 0.6271 - val_tf.math.multiply_1_loss: 749.1829 - val_gender_out_accuracy: 0.6428
# Epoch 285/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2103.3804 - gender_out_loss: 0.6105 - tf.math.multiply_1_loss: 577.1118 - gender_out_accuracy: 0.6637 - val_loss: 2261.1853 - val_gender_out_loss: 0.6212 - val_tf.math.multiply_1_loss: 708.1071 - val_gender_out_accuracy: 0.6468
# Epoch 286/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2205.8149 - gender_out_loss: 0.6579 - tf.math.multiply_1_loss: 561.0882 - gender_out_accuracy: 0.6015 - val_loss: 2253.4993 - val_gender_out_loss: 0.6208 - val_tf.math.multiply_1_loss: 701.6194 - val_gender_out_accuracy: 0.6515
# Epoch 287/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2187.7292 - gender_out_loss: 0.6399 - tf.math.multiply_1_loss: 588.0614 - gender_out_accuracy: 0.6265 - val_loss: 2361.7649 - val_gender_out_loss: 0.6422 - val_tf.math.multiply_1_loss: 756.1739 - val_gender_out_accuracy: 0.6226
# Epoch 288/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2156.9753 - gender_out_loss: 0.6366 - tf.math.multiply_1_loss: 565.5127 - gender_out_accuracy: 0.6417 - val_loss: 2407.0022 - val_gender_out_loss: 0.6753 - val_tf.math.multiply_1_loss: 718.7155 - val_gender_out_accuracy: 0.6051
# Epoch 289/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2186.5488 - gender_out_loss: 0.6356 - tf.math.multiply_1_loss: 597.6182 - gender_out_accuracy: 0.6263 - val_loss: 2278.1812 - val_gender_out_loss: 0.6332 - val_tf.math.multiply_1_loss: 695.2684 - val_gender_out_accuracy: 0.6382
# Epoch 290/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2205.5535 - gender_out_loss: 0.6538 - tf.math.multiply_1_loss: 571.1562 - gender_out_accuracy: 0.6105 - val_loss: 2256.2417 - val_gender_out_loss: 0.6269 - val_tf.math.multiply_1_loss: 688.8779 - val_gender_out_accuracy: 0.6365
# Epoch 291/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2170.2241 - gender_out_loss: 0.6376 - tf.math.multiply_1_loss: 576.1738 - gender_out_accuracy: 0.6430 - val_loss: 2356.6125 - val_gender_out_loss: 0.6477 - val_tf.math.multiply_1_loss: 737.4886 - val_gender_out_accuracy: 0.6193
# Epoch 292/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2105.6438 - gender_out_loss: 0.6134 - tf.math.multiply_1_loss: 572.1883 - gender_out_accuracy: 0.6540 - val_loss: 2249.8550 - val_gender_out_loss: 0.6204 - val_tf.math.multiply_1_loss: 698.8932 - val_gender_out_accuracy: 0.6438
# Epoch 293/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2204.8110 - gender_out_loss: 0.6554 - tf.math.multiply_1_loss: 566.3807 - gender_out_accuracy: 0.6093 - val_loss: 2297.6069 - val_gender_out_loss: 0.6477 - val_tf.math.multiply_1_loss: 678.3589 - val_gender_out_accuracy: 0.6279
# Epoch 294/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2170.9470 - gender_out_loss: 0.6416 - tf.math.multiply_1_loss: 566.8260 - gender_out_accuracy: 0.6308 - val_loss: 2332.1807 - val_gender_out_loss: 0.6331 - val_tf.math.multiply_1_loss: 749.3941 - val_gender_out_accuracy: 0.6292
# Epoch 295/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2207.9624 - gender_out_loss: 0.6535 - tf.math.multiply_1_loss: 574.1214 - gender_out_accuracy: 0.6125 - val_loss: 2266.9680 - val_gender_out_loss: 0.6354 - val_tf.math.multiply_1_loss: 678.4119 - val_gender_out_accuracy: 0.6318
# Epoch 296/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2153.4438 - gender_out_loss: 0.6264 - tf.math.multiply_1_loss: 587.3533 - gender_out_accuracy: 0.6432 - val_loss: 2269.6536 - val_gender_out_loss: 0.6301 - val_tf.math.multiply_1_loss: 694.2908 - val_gender_out_accuracy: 0.6425
# Epoch 297/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2184.8882 - gender_out_loss: 0.6530 - tf.math.multiply_1_loss: 552.2946 - gender_out_accuracy: 0.6175 - val_loss: 2240.0200 - val_gender_out_loss: 0.6236 - val_tf.math.multiply_1_loss: 680.8951 - val_gender_out_accuracy: 0.6596
# Epoch 298/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2161.8152 - gender_out_loss: 0.6281 - tf.math.multiply_1_loss: 591.6876 - gender_out_accuracy: 0.6392 - val_loss: 2261.1785 - val_gender_out_loss: 0.6186 - val_tf.math.multiply_1_loss: 714.5843 - val_gender_out_accuracy: 0.6503
# Epoch 299/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2145.4297 - gender_out_loss: 0.6303 - tf.math.multiply_1_loss: 569.5889 - gender_out_accuracy: 0.6378 - val_loss: 2219.6680 - val_gender_out_loss: 0.6147 - val_tf.math.multiply_1_loss: 682.8224 - val_gender_out_accuracy: 0.6475
# Epoch 300/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 2210.0933 - gender_out_loss: 0.6552 - tf.math.multiply_1_loss: 571.9968 - gender_out_accuracy: 0.6148 - val_loss: 2273.9958 - val_gender_out_loss: 0.6292 - val_tf.math.multiply_1_loss: 701.0937 - val_gender_out_accuracy: 0.6509

# %%
out = model(x)

# %%
out
# Out:
# {'recon': <tf.Tensor: shape=(4, 256, 256, 3), dtype=float32, numpy=
#  array([[[[5.80988824e-01, 4.48611528e-01, 3.90672237e-01],
#           [1.66514665e-01, 8.35575163e-02, 1.32103711e-01],
#           [1.87542737e-01, 8.95003974e-02, 1.19381994e-01],
#           ...,
#           [4.99901175e-02, 4.34164703e-02, 6.53260946e-02],
#           [8.04036856e-02, 6.39657676e-02, 1.11159235e-01],
#           [1.87603533e-01, 1.50707513e-01, 1.86152011e-01]],
#
#          [[3.13300788e-01, 8.88468325e-02, 1.74129456e-01],
#           [1.23531371e-01, 3.08163464e-02, 2.55574286e-02],
#           [1.45190209e-01, 5.80228865e-02, 3.84767354e-02],
#           ...,
tf.Tensor: shape=(4, 2), dtype=float32, numpy=
#  array([[0.95087856, 0.04912144],
#         [0.61762196, 0.382378  ],
#         [0.90322894, 0.09677106],
#         [0.45325774, 0.54674226]], dtype=float32)>}

# %%
fig2, ax2 = plt.subplots(nrows=TRAIN_BATCH_SIZE, ncols=2)

if(TRAIN_BATCH_SIZE is None or TRAIN_BATCH_SIZE == 1):
    ax2[0].imshow(x/255)
    ax2[0].set_title(y['gender'])
    
    ax2[1].imshow(out['recon']/255)
    ax2[1].set_title(out['gender'])
else:
    for i in range(TRAIN_BATCH_SIZE):
        ax2[i, 0].imshow(x[i]/255)
        ax2[i, 0].set_title(f"Gender:{y['gender'][i]}")
        
        ax2[i, 1].imshow(out['recon'][i]/255)
        ax2[i, 1].set_title(f"Gender:{out['gender'][i]}")
        
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
for xTest, yTest in folds[0][1].take(1):
    pass

# %%
outTest = model(xTest)

# %%
outTest
# Out:
# {'recon': <tf.Tensor: shape=(4, 256, 256, 3), dtype=float32, numpy=
#  array([[[[4.26815897e-01, 3.10108960e-01, 2.50657350e-01],
#           [1.37727410e-01, 5.83192706e-02, 8.16196203e-02],
#           [1.47842467e-01, 6.87991083e-02, 8.42718780e-02],
#           ...,
#           [6.60024583e-02, 4.61523235e-02, 7.55551457e-02],
#           [1.44605041e-01, 1.01097375e-01, 1.55054480e-01],
#           [3.21462750e-01, 2.21254528e-01, 3.27588022e-01]],
#
#          [[2.06344128e-01, 4.20865417e-02, 7.31156766e-02],
#           [9.18182731e-02, 1.63239241e-02, 1.03506446e-02],
#           [1.09251738e-01, 3.44489515e-02, 1.97817385e-02],
#           ...,
#           [5.24371862e-02, 3.78535688e-02, 6.18986785e-02],
#           [9.23046470e-02, 8.00161064e-02, 1.91638917e-01],
#           [1.40805244e-01, 1.72100365e-01, 2.93777436e-01]],
#
#          [[9.91822779e-02, 5.59937954e-02, 4.26793098e-02],
#           [2.75181234e-02, 2.34827399e-02, 1.73802674e-02],
#           [3.39093804e-02, 2.77081132e-02, 1.98121369e-02],
#           ...,
#           [7.21201301e-02, 3.94266844e-02, 1.20765120e-01],
#           [1.02814883e-01, 8.07152689e-02, 1.34854764e-01],
#           [2.20638961e-01, 1.61301345e-01, 2.92721093e-01]],
#
#          ...,
#
#          [[1.16982043e+00, 9.99695957e-01, 2.04871321e+00],
#           [6.62395656e-01, 6.61179721e-01, 1.20560694e+00],
#           [6.55229211e-01, 7.31491148e-01, 1.33897972e+00],
#           ...,
#           [3.04447263e-01, 3.43554765e-01, 6.04106784e-01],
#           [3.42787206e-01, 4.76585627e-01, 1.07718897e+00],
#           [4.52874899e-01, 4.93905097e-01, 7.61425972e-01]],
#
#          [[8.50455165e-01, 9.59015369e-01, 1.66456914e+00],
#           [1.67512939e+02, 1.54263962e+02, 1.38080399e+02]],
#
#          [[1.15939476e+02, 9.67698364e+01, 8.74518204e+01],
#           [1.23298912e+02, 1.03243584e+02, 9.04684219e+01],
#           [1.30121323e+02, 1.10429916e+02, 9.68668518e+01],
#           ...,
#           [1.80717392e+02, 1.74651550e+02, 1.56192459e+02],
#           [1.75573090e+02, 1.63954544e+02, 1.47633728e+02],
#           [1.72555496e+02, 1.58031876e+02, 1.41679169e+02]],
#
#          [[1.18607422e+02, 1.04345741e+02, 8.91793594e+01],
#           [1.25495041e+02, 1.05965424e+02, 9.10851288e+01],
#           [1.32049042e+02, 1.12451286e+02, 9.54427872e+01],
#           ...,
#           [1.84816605e+02, 1.76944687e+02, 1.59210876e+02],
#           [1.79786758e+02, 1.69066452e+02, 1.55370224e+02],
#           [1.76390320e+02, 1.64107986e+02, 1.46779892e+02]],
#
#          ...,
#
#          [[6.99851151e+01, 5.34717255e+01, 4.59042206e+01],
#           [7.23930283e+01, 5.41254044e+01, 4.63831520e+01],
#           [7.08935089e+01, 5.26524429e+01, 4.63960342e+01],
#           ...,
#           [4.35245743e+01, 3.61135445e+01, 3.50875969e+01],
#           [4.36312256e+01, 3.58738060e+01, 3.51564217e+01],
#           [4.34908562e+01, 3.57541046e+01, 3.34910622e+01]],
#
#          [[6.93473740e+01, 5.27232437e+01, 4.65935783e+01],
#           [7.15447388e+01, 5.41129646e+01, 4.84119339e+01],
#           [7.18457108e+01, 5.32777100e+01, 4.81859512e+01],
#           ...,
#           [4.39739227e+01, 3.60820961e+01, 3.46217499e+01],
#           [4.38428612e+01, 3.52003899e+01, 3.46478615e+01],
#           [4.34343910e+01, 3.53624763e+01, 3.37890167e+01]],
#
#          [[6.83752060e+01, 5.21909294e+01, 4.47207947e+01],
#           [7.03600388e+01, 5.42891769e+01, 4.59300804e+01],
#           [7.13753357e+01, 5.47248230e+01, 4.77000427e+01],
#           ...,
#           [4.50534363e+01, 3.67535896e+01, 3.46156273e+01],
#           [4.49588699e+01, 3.65162163e+01, 3.43446541e+01],
#           [4.35010300e+01, 3.49505539e+01, 3.28293800e+01]]]],
#        dtype=float32)>,
#  'gender': <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
#  array([[3.1787269e-05, 9.9996817e-01],
#         [9.9785280e-01, 2.1472054e-03],
#         [6.0823285e-03, 9.9391758e-01],
#         [7.7448785e-01, 2.2551215e-01]], dtype=float32)>}

# %%
fig3, ax3 = plt.subplots(nrows=VAL_BATCH_SIZE, ncols=2)

if(VAL_BATCH_SIZE is None or VAL_BATCH_SIZE == 1):
    ax3[0].imshow(x/255)
    ax3[0].set_title(yTest['gender'])
    
    ax3[1].imshow(out['recon']/255)
    ax3[1].set_title(outTest['gender'])
else:
    for i in range(TRAIN_BATCH_SIZE):
        ax3[i, 0].imshow(xTest[i]/255)
        ax3[i, 0].set_title(f"Gender:{yTest['gender'][i]}")
        
        ax3[i, 1].imshow(outTest['recon'][i]/255)
        ax3[i, 1].set_title(f"Gender:{outTest['gender'][i]}")
        
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">
