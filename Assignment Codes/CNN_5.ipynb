# %%
import math
import random
import os
import time
import json
from functools import partial
from collections import defaultdict

import numpy as np
import pandas as pd

# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf

# %% [markdown]
# ### Check Version

# %%
tf.__version__
# Out:
# '2.9.0'

# %% [markdown]
# ### GPU Configuration

# %%
gpus = tf.config.list_physical_devices('GPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ### Pandas Config

# %%
pd.set_option('display.max_column', None)

# %% [markdown]
# ### Input Pipeline

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256

TRAIN_BATCH_SIZE = 4
VAL_BATCH_SIZE = 4

# %%
CROP_WIDTH = 227
CROP_HEIGHT = 227

# %%
foldFiles = ["adience/unprocessed/fold_0_data.txt",
             "adience/unprocessed/fold_1_data.txt",
             "adience/unprocessed/fold_2_data.txt",
             "adience/unprocessed/fold_3_data.txt",
             "adience/unprocessed/fold_4_data.txt"]

# %%
genderMap = defaultdict(lambda : np.NaN)
genderMap['m'] = 0
genderMap['f'] = 1

# %%
ages = ['(0, 2)', '(4, 6)', '(8, 13)', '(15, 20)', '(25, 32)', '(38, 43)', '(48, 53)', '(60, 100)']
ageMap = defaultdict(lambda : np.NaN)
for i,a in enumerate(ages):
    ageMap[a] = i

# %% [markdown]
# ### Dataset Generation

# %% [markdown]
# Dataset generation pipeline:
# Input:
# - foldFile - Path to fold file. Fold file Describes which images are in the fold and its corresponding labels
# - imgBaseFolder - Base folder to search image from
# - imgPrefix - Prefix of image file
# - genderMap - Map from ['m', 'f', 'u', None], to one hot index
# - ageMap - Map from age category to one hot index
# - imgWidth - Resulting image width
# - imgHeigh - Resulting image height
# - batchSize - Int or None, batch size
# - configureDs - Function accepting dataset for performance configurations
# - preBatch - List of (name, functions) pair that will be mapped before batching. name is used as name parameters for tf graph
# - postBatch - List of (name, functions) that will be mapped after batching. name is used as name parameters for tf graph
#
# The processing functions should have signature function(img, label) -> (img, label)
#
# Pipeline
#
# Read Fold File -> Preprocess filename and labels (dataframe) -> Convert filename and labels to numpy array -> Convert filename and labels to tf dataset -> Parse images and labels -> Configure Dataset for performance -> Pre-Batching preprocessing -> Batch -> Post-Batching preprocessing -> Output
#
# Some preprocessing steps can only be done before and some can only be done after batching, thats why there are seperated pre and post batching list

# %%
def generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, batchSize, configureDs=None, preBatch=[], postBatch=[]):
    
    def parseImage(filename):
        img = tf.io.read_file(filename)
        img = tf.image.decode_jpeg(img)
        img = tf.image.resize(img, [imgHeight, imgWidth])
         
        return img
    
    # Read Fold File
    foldData = []
    for f in foldFiles:
        foldData.append(pd.read_csv(f, sep="\t"))
    foldData = pd.concat(foldData)
    
    # Form File Name
    foldData['filename'] = foldData.apply(lambda r: os.path.join(imgBaseFolder, r['user_id'], f"{imgPrefix}.{r['face_id']}.{r['original_image']}"), axis=1)
    
    # Generate Label One Hot Index
    foldData['gender_ind'] = foldData['gender'].map(genderMap)
    foldData['age_ind'] = foldData['age'].map(ageMap)
    
    # Remove dirty data
    foldData.dropna(subset=['gender_ind', 'age_ind'], inplace=True)
    
    # Dataframe to numpy
    filenames = foldData['filename'].to_numpy()
    
    genderIndex = foldData['gender_ind'].to_numpy().astype(int)
    ageIndex = foldData['age_ind'].to_numpy().astype(int)
    
    # Numpy to Dataset
    fnDs = tf.data.Dataset.from_tensor_slices(filenames)
    genderIndDs = tf.data.Dataset.from_tensor_slices(genderIndex)
    ageIndDs = tf.data.Dataset.from_tensor_slices(ageIndex)
    
    # Parse Images
    imageDs = fnDs.map(parseImage, num_parallel_calls=tf.data.AUTOTUNE, name="parse_image")
    
    # Parse Labels
    genderLabDs = genderIndDs.map(lambda x: tf.one_hot(x, genderDepth), num_parallel_calls=tf.data.AUTOTUNE, name="gender_one_hot")
    ageLabDs = ageIndDs.map(lambda x: tf.one_hot(x, ageDepth), num_parallel_calls=tf.data.AUTOTUNE, name="age_one_hot")
    
    # Combine Labels
    labelDs = tf.data.Dataset.zip((genderLabDs, ageLabDs), name="label_zip")
    labelDs = labelDs.map(lambda g,a: {"gender": g, "age": a}, num_parallel_calls=tf.data.AUTOTUNE, name='label_dict')
    
    # Combine Images and Labels into dataset
    ds = tf.data.Dataset.zip((imageDs, labelDs))
    
    # Configure Performance
    if(configureDs is not None):
        ds = configureDs(ds)
    
    # Pre Batch Preprocessing
    for n,f in preBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    # Batch
    if(batchSize is not None):
        ds = ds.batch(batchSize, name="ds_batch")
    
    # Post Batch Preprocessing
    for n,f in postBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    return ds

# %% [markdown]
# ### Preprocessings

# %%
def trainConfigPerformance(ds):
    #ds = ds.cache()
    ds = ds.shuffle(buffer_size=100)
    ds = ds.repeat()
    return ds

# %%
def valConfigPerformance(ds):
    #ds = ds.cache()
    return ds

# %% [markdown]
# #### Preprocessing steps

# %%
def trainPreprocessA(img, lab):
        
        img = tf.image.random_crop(img, [CROP_HEIGHT, CROP_WIDTH, 3])
        
        ud = tf.random.uniform([], dtype=tf.float32)
        udCond = tf.less(ud, 0.5)
        
        img = tf.cond(udCond, lambda: tf.image.flip_up_down(img), lambda: img)
        
        lr = tf.random.uniform([], dtype=tf.float32)
        lrCond = tf.less(lr, 0.5)
        
        img = tf.cond(lrCond, lambda: tf.image.flip_left_right(img), lambda: img)
        
        img = tf.image.random_brightness(img, 63/255)
        
        img = tf.image.random_contrast(img, 0.2, 1.8)
        
        return img, lab

# %%
def preprocessB(img, lab, rotL, rotH, shXL, shXH, shYL, shYH, zoomL, zoomH, hTransL, hTransH, vTransL, vTransH):
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    rRot = tf.random.uniform([shape[0]], minval=rotL, maxval=rotH, dtype=tf.float32)
    rShearX = tf.random.uniform([shape[0]], minval=shXL, maxval=shXH, dtype=tf.float32)
    rShearY = tf.random.uniform([shape[0]], minval=shYL, maxval=shYH, dtype=tf.float32)
    rZoom = tf.random.uniform([shape[0]], minval=zoomL, maxval=zoomH, dtype=tf.float32) #% Zoom
    rTx = tf.random.uniform([shape[0]], minval=hTransL, maxval=hTransH, dtype=tf.float32) #% Horiz Translation
    rTy = tf.random.uniform([shape[0]], minval=vTransL, maxval=vTransH, dtype=tf.float32) #% Vert Translation

    cT = tf.math.cos(rRot)
    sT = tf.math.sin(rRot)

    one = tf.ones([shape[0]], dtype=tf.float32)
    zero = tf.zeros([shape[0]], dtype=tf.float32)

    transC = tf.stack([[1, 0, -shapeF[2]/2], [0, 1, -shapeF[1]/2], [0, 0, 1]])
    transCI = tf.stack([[1, 0, shapeF[2]/2], [0, 1, shapeF[1]/2], [0, 0, 1]])

    trans = tf.transpose(tf.stack([[one, zero, rTx*shapeF[2]], [zero, one, rTy*shapeF[1]], [zero, zero, one]]), [2,0,1])
    rot = tf.transpose(tf.stack([[cT, -sT, zero], [sT, cT, zero], [zero, zero, one]]), [2,0,1])
    scale = tf.transpose(tf.stack([[rZoom, rShearX, zero], [rShearY, rZoom, zero], [zero, zero, one]]), [2,0,1])

    rotScale = rot@scale

    afTMat = transCI @ trans @ rotScale @ transC
    afT = tf.reshape(afTMat, [shape[0], -1])[:,:-1]

    img = tf.raw_ops.ImageProjectiveTransformV3(interpolation='NEAREST', images=img, transforms=afT, output_shape=shape[1:3], fill_value=0)

    return img, lab

# %%
def preprocessNoise(img, lab, gMean, gStd, spAmountP, spRatio, speckleVar):
        
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    # Gaussian Noise
    gNoise = tf.random.normal(shape, gMean, gStd)

    img += gNoise

    # Salt and pepper noise
    spMask = tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spAmountP), tf.float32)
    spNoise = 255*tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spRatio), tf.float32)

    img = tf.math.add(tf.math.multiply(img, 1.0 - spMask), tf.math.multiply(spNoise, spMask))

    # Speckles
    sNoise = speckleVar * tf.random.normal(shape)
    img = img + tf.math.multiply(img, sNoise)

    img = tf.clip_by_value(img, 0, 255)

    return img, lab

# %%
def clipValue(img, lab):
    img = tf.clip_by_value(img, 0.0, 255.0)
    return img, lab

# %%
def valPreprocessA(img, lab):
        
        img = tf.image.crop_to_bounding_box(img,
                                            (IMG_HEIGHT-CROP_HEIGHT) // 2,
                                            (IMG_WIDTH-CROP_WIDTH) // 2,
                                            CROP_HEIGHT,
                                            CROP_WIDTH)
        
        return img, lab

# %% [markdown]
# #### Label extractor

# %%
def extractGenderLabel(img, lab):
    
    lab = lab['gender']
    
    return img, lab

# %%
def extractAgeLabel(img, lab):
    
    lab = lab['age']
    
    return img, lab

# %% [markdown]
# ### Generate Folds for K-Folds validation

# %%
def generateFoldDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, valBatchSize, trainConfigureDs=None, trainPreBatch=[], trainPostBatch=[], valConfigureDs=None, valPreBatch=[], valPostBatch=[]):
    '''
        Returns list of (train, validation) datasets
    '''
    
    N = len(foldFiles)
    
    folds = []
    
    for i in range(N):
        
        trainFiles = foldFiles[:i]
        if(i < N-1):
            trainFiles.extend(foldFiles[i+1:])
            
        valFiles = foldFiles[i]
        
        trainDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, configureDs=trainConfigureDs, preBatch=trainPreBatch, postBatch=trainPostBatch)
        valDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, valBatchSize, configureDs=valConfigureDs, preBatch=valPreBatch, postBatch=valPostBatch)
        
        folds.append((trainDs, valDs))
        
    return folds

# %%
genParams = {
            "rotation": [-math.pi, math.pi],
            "shearX": [-0.2, 0.2],
            "shearY": [-0.2, 0.2],
            
            "zoom": [0.8, 1.2], # +- 20%
            "hTranslation": [-0.2, 0.2], # +- 20%
            "vTranslation": [-0.2, 0.2], # +- 20%
            
            "gaussianMean": 0.0,
            "gaussianStd": 2.0,
            
            "spAmount": 0.0001,
            "spRatio": 0.5,
            
            "speckleVar": 0.01
        }

# %%
trainPreprocessB = partial(preprocessB,
                           rotL = genParams['rotation'][0],
                           rotH = genParams['rotation'][1],
                           shXL = genParams['shearX'][0],
                           shXH = genParams['shearX'][1], 
                           shYL = genParams['shearY'][0],
                           shYH = genParams['shearY'][1],
                           zoomL = genParams['zoom'][0],
                           zoomH = genParams['zoom'][1],
                           hTransL = genParams['hTranslation'][0],
                           hTransH = genParams['hTranslation'][1],
                           vTransL = genParams['vTranslation'][0],
                           vTransH = genParams['vTranslation'][1])

# %%
trainPreprocessC = partial(preprocessNoise,
                           gMean = genParams['gaussianMean'],
                           gStd = genParams['gaussianStd'],
                           spAmountP = genParams['spAmount'],
                           spRatio = genParams['spRatio'],
                           speckleVar = genParams['speckleVar'])

# %%
trainPreBatch = [("train_process_a", trainPreprocessA)]
trainPostBatch = [("train_process_b", trainPreprocessB),
                  ("train_process_c", trainPreprocessC),
                  ("train_clip", clipValue),
                  ("train_extract_gender", extractGenderLabel)]

valPreBatch = [("val_process_a", valPreprocessA), 
               ("val_extract_gender", extractGenderLabel)]

# %%
folds = generateFoldDs(foldFiles, "adience/faces", "coarse_tilt_aligned_face", genderMap, ageMap, 2, 8, 
                       IMG_WIDTH, IMG_HEIGHT, TRAIN_BATCH_SIZE, VAL_BATCH_SIZE, 
                       trainConfigureDs=trainConfigPerformance, trainPreBatch=trainPreBatch, 
                       trainPostBatch=trainPostBatch,
                       valConfigureDs=valConfigPerformance, valPreBatch=valPreBatch)
# Out:
# 2022-11-06 14:05:16.601982: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 14:05:17.648011: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 1202 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
len(folds)
# Out:
# 5

# %% [markdown]
# ### Check data

# %%
for x,y in folds[0][0].take(1):
    pass

# %%
x
# Out:
# <tf.Tensor: shape=(4, 227, 227, 3), dtype=float32, numpy=
# array([[[[8.28712997e+01, 6.87214890e+01, 4.75332985e+01],
#          [8.13162308e+01, 6.91876297e+01, 4.94159508e+01],
#          [8.26246033e+01, 6.34402275e+01, 4.80635338e+01],
#          ...,
#          [9.25321341e-01, 0.00000000e+00, 0.00000000e+00],
#          [1.08478713e+00, 5.02498806e-01, 0.00000000e+00],
#          [0.00000000e+00, 1.00206685e+00, 0.00000000e+00]],
#
#         [[7.94726639e+01, 6.90237732e+01, 4.65436172e+01],
#          [7.93443298e+01, 6.87248306e+01, 4.77144127e+01],
#          [7.80165024e+01, 6.17089310e+01, 4.52089844e+01],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 1
+00, 0.00000000e+00],
#          [0.00000000e+00, 1.80332661e+00, 0.00000000e+00],
#          ...,
#          [5.40909469e-01, 0.00000000e+00, 0.00000000e+00],
#          [9.30457950e-01, 0.00000000e+00, 1.92806137e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[3.90937090e-01, 1.02227294e+00, 0.00000000e+00],
#          [5.02741671e+00, 1.67689502e+00, 2.12810183e+00],
#          [1.46789491e+00, 1.31310835e-01, 1.20533638e-01],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 3.08314174e-01],
#          [0.00000000e+00, 3.11932027e-01, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.12036967e+00, 2.88707113e+00, 2.08011174e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.19580889e+00, 0.00000000e+00, 9.46328580e-01],
#          [0.00000000e+00, 0.00000000e+00, 1.33454889e-01],
#          [4.35496643e-02, 0.00000000e+00, 1.15047038e+00]],
#
#         ...,
#
#         [[0.00000000e+00, 0.00000000e+00, 1.26015139e+00],
#          [2.38847628e-01, 1.24689507e+00, 0.00000000e+00],
#          [0.00000000e+00, 1.97297990e-01, 5.27821302e-01],
#          ...,
#          [3.00548047e-01, 0.00000000e+00, 6.26138449e-01],
#          [3.79898500e+00, 0.00000000e+00, 2.04571080e+00],
#          [0.00000000e+00, 2.22733688e+00, 0.00000000e+00]],
#
#         [[0.00000000e+00, 0.00000000e+00, 1.21872211e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.53513002e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [1.74823143e-02, 0.00000000e+00, 1.74751830e+00],
#          [0.00000000e+00, 3.32611012e+00, 4.02434158e+00],
#          [0.00000000e+00, 0.00000000e+00, 2.01260820e-02]],
#
#         [[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.02303767e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [4.42235619e-01, 8.87579203e-01, 0.00000000e+00],
#          [0.00000000e+00, 2.08322954e+00, 2.54542494e+00],
#          [1.85200572e+00, 0.00000000e+00, 0.00000000e+00]]],
#
#
#        [[[2.11672044e+00, 0.00000000e+00, 0.00000000e+00],
#          [3.41119075e+00, 0.00000000e+00, 3.36638331e+00],
#          [3.83458519e+00, 0.00000000e+00, 4.39820766e-01],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 9.61920023e-01]],
#
#         [[0.00000000e+00, 5.97192883e-01, 1.15267895e-01],
#          [0.00000000e+00, 1.96532285e+00, 1.89868331e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 1.16790971e-02, 0.00000000e+00],
#          [5.65276183e-02, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 7.17227757e-01]],
#
#         [[9.38354909e-01, 2.45765829e+00, 0.00000000e+00],
#          [1.96171474e+00, 4.13955487e-02, 4.33016872e+00],
#          [0.00000000e+00, 1.94396174e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.12970877e+00, 2.08627081e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         ...,
#
#         [[3.81849110e-01, 4.71834660e-01, 1.63366807e+00],
#          [3.42449975e+00, 8.54358017e-01, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 7.12279201e-01, 0.00000000e+00],
#          [3.67979527e-01, 0.00000000e+00, 1.35106695e+00],
#          [2.32808948e+00, 4.99089509e-01, 0.00000000e+00]],
#
#         [[4.33585739e+00, 0.00000000e+00, 1.85240889e+00],
#          [0.00000000e+00, 1.93457067e+00, 0.00000000e+00],
#          [2.90840650e+00, 0.00000000e+00, 8.44773829e-01],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 5.04493809e+00, 0.00000000e+00],
#          [1.72512484e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[7.92125821e-01, 4.18840438e-01, 0.00000000e+00],
#          [0.00000000e+00, 2.60063320e-01, 1.28134060e+00],
#          [0.00000000e+00, 1.96840182e-01, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 4.29421806e+00, 0.00000000e+00],
#          [1.70263982e+00, 0.00000000e+00, 1.89018118e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]]]],
#       dtype=float32)>

# %%
y
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[1., 0.],
#        [0., 1.],
#        [1., 0.],
#        [1., 0.]], dtype=float32)>

# %%
fig1, ax1 = plt.subplots(nrows=TRAIN_BATCH_SIZE, ncols=1)

if(TRAIN_BATCH_SIZE is None or TRAIN_BATCH_SIZE == 1):
    ax1.imshow(x/255)
    ax1.set_title(y)
else:
    for i in range(TRAIN_BATCH_SIZE):
        ax1[i].imshow(x[i]/255)
        ax1[i].set_title(f"Gender:{y[i]}")
        
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model

# %%
def createModel():
    inp = tf.keras.Input(shape=(CROP_HEIGHT, CROP_WIDTH, 3))

    conv1 = tf.keras.layers.Conv2D(64, 7, strides=(4,4), activation='relu', name='conv1')
    pool1 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool1')

    conv2 = tf.keras.layers.Conv2D(128, 5, activation='relu', name='conv2')
    pool2 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool2')

    conv3 = tf.keras.layers.Conv2D(256, 3, activation='relu', name='conv3')
    pool3 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool3')

    flat1 = tf.keras.layers.Flatten(name='flat1')
    fc1 = tf.keras.layers.Dense(128, activation='relu', name='fc1')
    do1 = tf.keras.layers.Dropout(0.5, name='do1')

    fc2 = tf.keras.layers.Dense(2, activation='softmax', name='fc2')

    o = inp / 127.5 - 1.0
    
    o = conv1(o)
    o = pool1(o)

    o = conv2(o)
    o = pool2(o)

    o = conv3(o)
    o = pool3(o)

    o = flat1(o)
    o = fc1(o)
    o = do1(o)

    o = fc2(o)

    model = tf.keras.models.Model(inputs=inp, outputs=o, name='CNN_1')
    
    return model

# %%
model = createModel()

# %%
model.summary()
# Out:
# Model: "CNN_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 227, 227, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 227, 227, 3)      0
#  a)
#
#  conv1 (Conv2D)              (None, 56, 56, 64)        9472
#
#  pool1 (MaxPooling2D)        (None, 27, 27, 64)        0
#
#  conv2 (Conv2D)              (None, 23, 23, 128)       204928
#
#  pool2 (MaxPooling2D)        (None, 11, 11, 128)       0
#
#  conv3 (Conv2D)              (None, 9, 9, 256)         295168
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  flat1 (Flatten)             (None, 4096)              0
#
#  fc1 (Dense)                 (None, 128)               524416
#
#  do1 (Dropout)               (None, 128)               0
#
#  fc2 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 1,034,242
# Trainable params: 1,034,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile Model

# %%
STEPS_PER_EPOCH = 1000
EPOCH = 300

START_EPOCH = 0
END_EPOCH = START_EPOCH + EPOCH

# %% [markdown]
# #### Learning Rate Schedule

# %%
def schedule(epoch, lr):
    return lr

# %%
logBasePath = "log/CNN_5"
logPrefix = "log"

# %%
for i, (train, val) in enumerate([folds[0]]):
    
    model = createModel()
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.000001, clipvalue=0.1)
    loss = tf.keras.losses.CategoricalCrossentropy()
    metrics = ['accuracy']
    
    model.compile(optimizer=opt, loss=loss, metrics=metrics)
    
    tboardCb = tf.keras.callbacks.TensorBoard(log_dir=f"{logBasePath}/{logPrefix}_{i}", histogram_freq=1, profile_batch=(2,10))
    lrSchedule = tf.keras.callbacks.LearningRateScheduler(schedule)
    
    cbs = [tboardCb]
    
    model.evaluate(val)
    model.fit(train, initial_epoch=START_EPOCH, epochs=END_EPOCH, steps_per_epoch=STEPS_PER_EPOCH, callbacks=cbs, validation_data=val)
# Out:
# 2022-11-06 14:06:15.852505: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-06 14:06:15.852545: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-06 14:06:15.852578: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1665] Profiler found 1 GPUs
# 2022-11-06 14:06:15.854795: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/ntcadmin/env/trt-11.0/TensorRT-7.1.3.4/lib:
# 2022-11-06 14:06:15.855128: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so'; dlerror: libcupti.so: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/ntcadmin/env/trt-11.0/TensorRT-7.1.3.4/lib:
# 2022-11-06 14:06:15.855194: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: error 999:
# 2022-11-06 14:06:15.855244: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:184] cuptiSubscribe: ignored due to a previous error.
# 2022-11-06 14:06:15.855279: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:06:15.855317: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1716] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2022-11-06 14:06:15.855397: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-06 14:06:15.855462: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:140] cuptiFinalize: ignored due to a previous error.
# 2022-11-06 14:06:15.855473: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:06:15.855480: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1808] function cupti_interface_->Finalize()failed with error
# 2022-11-06 14:06:16.887285: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 3528/3528 [==============================] - 19s 5ms/step - loss: 0.6970 - accuracy: 0.4764
# Epoch 1/300
#   16/1000 [..............................] - ETA: 11s - loss: 0.6891 - accuracy: 0.5625
# 2022-11-06 14:06:36.719447: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-06 14:06:36.719485: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-06 14:06:36.719548: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-06 14:06:36.719568: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:184] cuptiSubscribe: ignored due to a previous error.
# 2022-11-06 14:06:36.719575: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:06:36.719580: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1716] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2022-11-06 14:06:36.783011: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-11-06 14:06:36.783151: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:140] cuptiFinalize: ignored due to a previous error.
# 2022-11-06 14:06:36.783164: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:06:36.783171: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1808] function cupti_interface_->Finalize()failed with error
# 2022-11-06 14:06:36.792158: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-06 14:06:36.792198: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-06 14:06:36.792208: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:521]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2022-11-06 14:06:36.795147: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-06 14:06:36.798453: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36
#
# 2022-11-06 14:06:36.800256: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.trace.json.gz
# 2022-11-06 14:06:36.838856: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36
#
# 2022-11-06 14:06:36.845302: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.memory_profile.json.gz
# 2022-11-06 14:06:36.845650: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36
# Dumped tool data for xplane.pb to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.xplane.pb
# Dumped tool data for overview_page.pb to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.overview_page.pb
# Dumped tool data for input_pipeline.pb to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to log/CNN_5/log_0/plugins/profile/2022_11_06_14_06_36/ntcadmin-scse.kernel_stats.pb
# 1000/1000 [==============================] - 27s 26ms/step - loss: 0.6946 - accuracy: 0.5230 - val_loss: 0.6909 - val_accuracy: 0.5348
# Epoch 2/300
#    7/1000 [..............................] - ETA: 9s - loss: 0.7232 - accuracy: 0.3214
# 2022-11-06 14:07:02.115746: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 49152000 exceeds 10% of free system memory.
# 2022-11-06 14:07:02.142556: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 70778880 exceeds 10% of free system memory.
# 2022-11-06 14:07:02.172923: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 125829120 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6943 - accuracy: 0.5125 - val_loss: 0.6887 - val_accuracy: 0.5365
# Epoch 3/300
#    6/1000 [..............................] - ETA: 9s - loss: 0.6921 - accuracy: 0.4583
# 2022-11-06 14:07:27.238799: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 49152000 exceeds 10% of free system memory.
# 2022-11-06 14:07:27.261682: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 70778880 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6862 - accuracy: 0.5512 - val_loss: 0.6878 - val_accuracy: 0.5608
# Epoch 4/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6882 - accuracy: 0.5418 - val_loss: 0.6864 - val_accuracy: 0.5564
# Epoch 5/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6934 - accuracy: 0.5070 - val_loss: 0.6857 - val_accuracy: 0.5662
# Epoch 6/300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6769 - accuracy: 0.5765 - val_loss: 0.6873 - val_accuracy: 0.5335
# Epoch 7/300
# 1000/1000 [==============================] - 25s 26ms/step - loss: 0.6902 - accuracy: 0.5370 - val_loss: 0.6862 - val_accuracy: 0.5338
# Epoch 8/300
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.6906 - accuracy: 0.5303 - val_loss: 0.6835 - val_accuracy: 0.5701
# Epoch 9/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6895 - accuracy: 0.5418 - val_loss: 0.6822 - val_accuracy: 0.5757
# Epoch 10/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6804 - accuracy: 0.5675 - val_loss: 0.6810 - val_accuracy: 0.5805
# Epoch 11/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6840 - accuracy: 0.5500 - val_loss: 0.6834 - val_accuracy: 0.5523
# Epoch 12/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6897 - accuracy: 0.5330 - val_loss: 0.6810 - val_accuracy: 0.5724
# Epoch 13/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6718 - accuracy: 0.6005 - val_loss: 0.6863 - val_accuracy: 0.5389
# Epoch 14/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6882 - accuracy: 0.5418 - val_loss: 0.6817 - val_accuracy: 0.5489
# Epoch 15/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6871 - accuracy: 0.5347 - val_loss: 0.6778 - val_accuracy: 0.5839
# Epoch 16/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6883 - accuracy: 0.5393 - val_loss: 0.6769 - val_accuracy: 0.5919
# Epoch 17/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6754 - accuracy: 0.5735 - val_loss: 0.6765 - val_accuracy: 0.5929
# Epoch 18/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6820 - accuracy: 0.5560 - val_loss: 0.6759 - val_accuracy: 0.5887
# Epoch 19/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6880 - accuracy: 0.5403 - val_loss: 0.6784 - val_accuracy: 0.5774
# Epoch 20/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6685 - accuracy: 0.5980 - val_loss: 0.6912 - val_accuracy: 0.5362
# Epoch 21/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6880 - accuracy: 0.5437 - val_loss: 0.6780 - val_accuracy: 0.5633
# Epoch 22/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6856 - accuracy: 0.5443 - val_loss: 0.6745 - val_accuracy: 0.5917
# Epoch 23/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6853 - accuracy: 0.5475 - val_loss: 0.6743 - val_accuracy: 0.5973
# Epoch 24/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6707 - accuracy: 0.5882 - val_loss: 0.6725 - val_accuracy: 0.6000
# Epoch 25/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6820 - accuracy: 0.5648 - val_loss: 0.6724 - val_accuracy: 0.5917
# Epoch 26/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.
300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6785 - accuracy: 0.5638 - val_loss: 0.6636 - val_accuracy: 0.6116
# Epoch 58/300
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.6734 - accuracy: 0.5817 - val_loss: 0.6623 - val_accuracy: 0.6132
# Epoch 59/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6605 - accuracy: 0.6200 - val_loss: 0.6649 - val_accuracy: 0.5873
# Epoch 60/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6770 - accuracy: 0.5717 - val_loss: 0.6684 - val_accuracy: 0.5781
# Epoch 61/300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6793 - accuracy: 0.5655 - val_loss: 0.6623 - val_accuracy: 0.6141
# Epoch 62/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6807 - accuracy: 0.5738 - val_loss: 0.6634 - val_accuracy: 0.5964
# Epoch 63/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6679 - accuracy: 0.5905 - val_loss: 0.6641 - val_accuracy: 0.6121
# Epoch 64/300
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.6763 - accuracy: 0.5725 - val_loss: 0.6616 - val_accuracy: 0.6087
# Epoch 65/300
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.6751 - accuracy: 0.5732 - val_loss: 0.6617 - val_accuracy: 0.6034
# Epoch 66/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6611 - accuracy: 0.6047 - val_loss: 0.6643 - val_accuracy: 0.5874
# Epoch 67/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6720 - accuracy: 0.5788 - val_loss: 0.6739 - val_accuracy: 0.5689
# Epoch 68/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6812 - accuracy: 0.5775 - val_loss: 0.6599 - val_accuracy: 0.6159
# Epoch 69/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6755 - accuracy: 0.5840 - val_loss: 0.6637 - val_accuracy: 0.5887
# Epoch 70/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6641 - accuracy: 0.5972 - val_loss: 0.6610 - val_accuracy: 0.6162
# Epoch 71/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6754 - accuracy: 0.5763 - val_loss: 0.6602 - val_accuracy: 0.6180
# Epoch 72/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6761 - accuracy: 0.5715 - val_loss: 0.6601 - val_accuracy: 0.6077
# Epoch 73/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6606 - accuracy: 0.6162 - val_loss: 0.6730 - val_accuracy: 0.5718
# Epoch 74/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6716 - accuracy: 0.5755 - val_loss: 0.6707 - val_accuracy: 0.5732
# Epoch 75/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6802 - accuracy: 0.5555 - val_loss: 0.6589 - val_accuracy: 0.6192
# Epoch 76/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6729 - accuracy: 0.5938 - val_loss: 0.6631 - val_accuracy: 0.5885
# Epoch 77/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6599 - accuracy: 0.6010 - val_loss: 0.6610 - val_accuracy: 0.6182
# Epoch 78/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6731 - accuracy: 0.5800 - val_loss: 0.6628 - val_accuracy: 0.6140
# Epoch 79/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6733 - accuracy: 0.5790 - val_loss: 0.6586 - val_accuracy: 0.6193
# Epoch 80/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6554 - accuracy: 0.6137 - val_loss: 0.6886 - val_accuracy: 0.5557
# Epoch 81/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6736 - accuracy: 0.5753 - val_loss: 0.6703 - val_accuracy: 0.5722
# Epoch 82/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6829 - accuracy: 0.5583 - val_loss: 0.6578 - val_accuracy: 0.6162
# Epoch 83/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6695 - accuracy: 0.5997 - val_loss: 0.6583 - val_accuracy: 0.6041
# Epoch 84/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6578 - accuracy: 0.6070 - val_loss: 0.6616 - val_accuracy: 0.6164
# Epoch 85/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6709 - accuracy: 0.5798 - val_loss: 0.6565 - val_accuracy: 0.6112
# Epoch 86/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6751 - accuracy: 0.5750 - val_loss: 0.6606 - val_accuracy: 0.6158
# Epoch 87/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6570 - accuracy: 0.6140 - val_loss: 0.7002 - val_accuracy: 0.5479
# Epoch 88/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.
300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6715 - accuracy: 0.5925 - val_loss: 0.6701 - val_accuracy: 0.5753
# Epoch 149/300
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.6756 - accuracy: 0.5765 - val_loss: 0.6463 - val_accuracy: 0.6357
# Epoch 150/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6612 - accuracy: 0.6095 - val_loss: 0.6460 - val_accuracy: 0.6336
# Epoch 151/300
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6461 - accuracy: 0.6242 - val_loss: 0.6518 - val_accuracy: 0.6270
# Epoch 152/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6706 - accuracy: 0.5773 - val_loss: 0.6472 - val_accuracy: 0.6197
# Epoch 153/300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6649 - accuracy: 0.5995 - val_loss: 0.6507 - val_accuracy: 0.6292
# Epoch 154/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6565 - accuracy: 0.6160 - val_loss: 0.7055 - val_accuracy: 0.5547
# Epoch 155/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6666 - accuracy: 0.5930 - val_loss: 0.6514 - val_accuracy: 0.6079
# Epoch 156/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6715 - accuracy: 0.5805 - val_loss: 0.6463 - val_accuracy: 0.6371
# Epoch 157/300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6624 - accuracy: 0.6173 - val_loss: 0.6452 - val_accuracy: 0.6377
# Epoch 158/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6441 - accuracy: 0.6277 - val_loss: 0.6455 - val_accuracy: 0.6279
# Epoch 159/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6692 - accuracy: 0.5800 - val_loss: 0.6446 - val_accuracy: 0.6358
# Epoch 160/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6666 - accuracy: 0.5903 - val_loss: 0.6476 - val_accuracy: 0.6372
# Epoch 161/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6612 - accuracy: 0.6108 - val_loss: 0.6832 - val_accuracy: 0.5654
# Epoch 162/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6608 - accuracy: 0.5982 - val_loss: 0.6490 - val_accuracy: 0.6133
# Epoch 163/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6693 - accuracy: 0.5842 - val_loss: 0.6467 - val_accuracy: 0.6259
# Epoch 164/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6596 - accuracy: 0.6158 - val_loss: 0.6655 - val_accuracy: 0.5856
# Epoch 165/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6452 - accuracy: 0.6233 - val_loss: 0.6477 - val_accuracy: 0.6169
# Epoch 166/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6690 - accuracy: 0.5905 - val_loss: 0.6493 - val_accuracy: 0.6326
# Epoch 167/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6686 - accuracy: 0.5903 - val_loss: 0.6436 - val_accuracy: 0.6369
# Epoch 168/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6649 - accuracy: 0.6047 - val_loss: 0.6525 - val_accuracy: 0.6077
# Epoch 169/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6503 - accuracy: 0.6083 - val_loss: 0.6438 - val_accuracy: 0.6388
# Epoch 170/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6682 - accuracy: 0.5857 - val_loss: 0.6447 - val_accuracy: 0.6391
# Epoch 171/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6517 - accuracy: 0.6208 - val_loss: 0.6708 - val_accuracy: 0.5709
# Epoch 172/300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6464 - accuracy: 0.6273 - val_loss: 0.6462 - val_accuracy: 0.6219
# Epoch 173/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6690 - accuracy: 0.5813 - val_loss: 0.6443 - val_accuracy: 0.6409
# Epoch 174/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6678 - accuracy: 0.5940 - val_loss: 0.6432 - val_accuracy: 0.6335
# Epoch 175/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6669 - accuracy: 0.5993 - val_loss: 0.6469 - val_accuracy: 0.6207
# Epoch 176/300
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.6533 - accuracy: 0.6115 - val_loss: 0.6447 - val_accuracy: 0.6311
# Epoch 177/300
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6698 - accuracy: 0.5847 - val_loss: 0.6509 - val_accuracy: 0.6332
# Epoch 178/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6582 - accuracy: 0.6160 - val_loss: 0.6522 - val_accuracy: 0.6216
# Epoch 179/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.
300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6708 - accuracy: 0.5800 - val_loss: 0.6406 - val_accuracy: 0.6383
# Epoch 210/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6609 - accuracy: 0.6080 - val_loss: 0.6446 - val_accuracy: 0.6246
# Epoch 211/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6319 - accuracy: 0.6470 - val_loss: 0.6514 - val_accuracy: 0.6197
# Epoch 212/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6658 - accuracy: 0.6050 - val_loss: 0.6396 - val_accuracy: 0.6400
# Epoch 213/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6606 - accuracy: 0.5982 - val_loss: 0.6460 - val_accuracy: 0.6330
# Epoch 214/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6416 - accuracy: 0.6277 - val_loss: 0.7202 - val_accuracy: 0.5545
# Epoch 215/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6648 - accuracy: 0.5985 - val_loss: 0.6568 - val_accuracy: 0.5975
# Epoch 216/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6684 - accuracy: 0.5878 - val_loss: 0.6399 - val_accuracy: 0.6394
# Epoch 217/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6556 - accuracy: 0.6315 - val_loss: 0.6393 - val_accuracy: 0.6415
# Epoch 218/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6398 - accuracy: 0.6373 - val_loss: 0.6389 - val_accuracy: 0.6442
# Epoch 219/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6666 - accuracy: 0.5950 - val_loss: 0.6425 - val_accuracy: 0.6308
# Epoch 220/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6618 - accuracy: 0.6028 - val_loss: 0.6464 - val_accuracy: 0.6312
# Epoch 221/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6466 - accuracy: 0.6317 - val_loss: 0.7103 - val_accuracy: 0.5574
# Epoch 222/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6565 - accuracy: 0.6020 - val_loss: 0.6463 - val_accuracy: 0.6170
# Epoch 223/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6666 - accuracy: 0.5828 - val_loss: 0.6393 - val_accuracy: 0.6404
# Epoch 224/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6551 - accuracy: 0.6195 - val_loss: 0.6409 - val_accuracy: 0.6452
# Epoch 225/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6380 - accuracy: 0.6352 - val_loss: 0.6408 - val_accuracy: 0.6313
# Epoch 226/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6630 - accuracy: 0.6000 - val_loss: 0.6397 - val_accuracy: 0.6460
# Epoch 227/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6633 - accuracy: 0.5930 - val_loss: 0.6373 - val_accuracy: 0.6470
# Epoch 228/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6586 - accuracy: 0.6137 - val_loss: 0.6657 - val_accuracy: 0.5871
# Epoch 229/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6487 - accuracy: 0.6120 - val_loss: 0.6384 - val_accuracy: 0.6405
# Epoch 230/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6668 - accuracy: 0.5888 - val_loss: 0.6390 - val_accuracy: 0.6443
# Epoch 231/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6457 - accuracy: 0.6350 - val_loss: 0.6739 - val_accuracy: 0.5659
# Epoch 232/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6404 - accuracy: 0.6288 - val_loss: 0.6434 - val_accuracy: 0.6269
# Epoch 233/300
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.6650 - accuracy: 0.5935 - val_loss: 0.6448 - val_accuracy: 0.6363
# Epoch 234/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6634 - accuracy: 0.5928 - val_loss: 0.6399 - val_accuracy: 0.6348
# Epoch 235/300
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.6622 - accuracy: 0.6160 - val_loss: 0.6440 - val_accuracy: 0.6258
# Epoch 236/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6467 - accuracy: 0.6190 - val_loss: 0.6382 - val_accuracy: 0.6416
# Epoch 237/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6640 - accuracy: 0.5888 - val_loss: 0.6396 - val_accuracy: 0.6484
# Epoch 238/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6476 - accuracy: 0.6330 - val_loss: 0.6575 - val_accuracy: 0.6007
# Epoch 239/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6395 - accuracy: 0.6313 - val_loss: 0.6404 - val_accuracy: 0.6331
# Epoch 240/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6619 - accuracy: 0.5970 - val_loss: 0.6375 - val_accuracy: 0.6491
# Epoch 241/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6631 - accuracy: 0.5950 - val_loss: 0.6373 - val_accuracy: 0.6509
# Epoch 242/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6603 - accuracy: 0.6227 - val_loss: 0.6395 - val_accuracy: 0.6368
# Epoch 243/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6395 - accuracy: 0.6255 - val_loss: 0.6361 - val_accuracy: 0.6457
# Epoch 244/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6616 - accuracy: 0.5913 - val_loss: 0.6389 - val_accuracy: 0.6485
# Epoch 245/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6538 - accuracy: 0.6195 - val_loss: 0.6388 - val_accuracy: 0.6483
# Epoch 246/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6324 - accuracy: 0.6482 - val_loss: 0.6381 - val_accuracy: 0.6384
# Epoch 247/300
# 1000/1000 [==============================] - 33s 33ms/step - loss: 0.6600 - accuracy: 0.6050 - val_loss: 0.6403 - val_accuracy: 0.6304
# Epoch 248/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6643 - accuracy: 0.5955 - val_loss: 0.6463 - val_accuracy: 0.6283
# Epoch 249/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6628 - accuracy: 0.6127 - val_loss: 0.6395 - val_accuracy: 0.6357
# Epoch 250/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6453 - accuracy: 0.6248 - val_loss: 0.6464 - val_accuracy: 0.6316
# Epoch 251/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6664 - accuracy: 0.5957 - val_loss: 0.6379 - val_accuracy: 0.6473
# Epoch 252/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6478 - accuracy: 0.6248 - val_loss: 0.6396 - val_accuracy: 0.6305
# Epoch 253/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6359 - accuracy: 0.6455 - val_loss: 0.6349 - val_accuracy: 0.6437
# Epoch 254/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6570 - accuracy: 0.6077 - val_loss: 0.6611 - val_accuracy: 0.5900
# Epoch 255/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6707 - accuracy: 0.5888 - val_loss: 0.6372 - val_accuracy: 0.6416
# Epoch 256/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6558 - accuracy: 0.6260 - val_loss: 0.6419 - val_accuracy: 0.6297
# Epoch 257/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6424 - accuracy: 0.6298 - val_loss: 0.6364 - val_accuracy: 0.6496
# Epoch 258/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6562 - accuracy: 0.6143 - val_loss: 0.6392 - val_accuracy: 0.6343
# Epoch 259/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6585 - accuracy: 0.6083 - val_loss: 0.6374 - val_accuracy: 0.6377
# Epoch 260/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6344 - accuracy: 0.6398 - val_loss: 0.6402 - val_accuracy: 0.6322
# Epoch 261/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6525 - accuracy: 0.6185 - val_loss: 0.6555 - val_accuracy: 0.5998
# Epoch 262/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6668 - accuracy: 0.5765 - val_loss: 0.6358 - val_accuracy: 0.6433
# Epoch 263/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6507 - accuracy: 0.6290 - val_loss: 0.6481 - val_accuracy: 0.6163
# Epoch 264/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6424 - accuracy: 0.6230 - val_loss: 0.6359 - val_accuracy: 0.6522
# Epoch 265/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6584 - accuracy: 0.6075 - val_loss: 0.6434 - val_accuracy: 0.6351
# Epoch 266/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6628 - accuracy: 0.6000 - val_loss: 0.6358 - val_accuracy: 0.6412
# Epoch 267/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6365 - accuracy: 0.6480 - val_loss: 0.6591 - val_accuracy: 0.5998
# Epoch 268/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6513 - accuracy: 0.6162 - val_loss: 0.6636 - val_accuracy: 0.5890
# Epoch 269/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6675 - accuracy: 0.5847 - val_loss: 0.6333 - val_accuracy: 0.6480
# Epoch 270/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6500 - accuracy: 0.6280 - val_loss: 0.6444 - val_accuracy: 0.6201
# Epoch 271/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6354 - accuracy: 0.6400 - val_loss: 0.6426 - val_accuracy: 0.6323
# Epoch 272/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6606 - accuracy: 0.6033 - val_loss: 0.6361 - val_accuracy: 0.6480
# Epoch 273/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6561 - accuracy: 0.6077 - val_loss: 0.6353 - val_accuracy: 0.6489
# Epoch 274/300
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.6337 - accuracy: 0.6425 - val_loss: 0.7028 - val_accuracy: 0.5696
# Epoch 275/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6581 - accuracy: 0.6050 - val_loss: 0.6598 - val_accuracy: 0.5978
# Epoch 276/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6670 - accuracy: 0.5885 - val_loss: 0.6337 - val_accuracy: 0.6462
# Epoch 277/300
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6512 - accuracy: 0.6310 - val_loss: 0.6346 - val_accuracy: 0.6430
# Epoch 278/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6311 - accuracy: 0.6410 - val_loss: 0.6507 - val_accuracy: 0.6148
# Epoch 279/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6624 - accuracy: 0.5938 - val_loss: 0.6363 - val_accuracy: 0.6385
# Epoch 280/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6518 - accuracy: 0.6208 - val_loss: 0.6413 - val_accuracy: 0.6353
# Epoch 281/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6450 - accuracy: 0.6292 - val_loss: 0.7050 - val_accuracy: 0.5663
# Epoch 282/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6547 - accuracy: 0.6160 - val_loss: 0.6471 - val_accuracy: 0.6124
# Epoch 283/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6671 - accuracy: 0.5850 - val_loss: 0.6331 - val_accuracy: 0.6508
# Epoch 284/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6475 - accuracy: 0.6360 - val_loss: 0.6329 - val_accuracy: 0.6462
# Epoch 285/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6315 - accuracy: 0.6460 - val_loss: 0.6333 - val_accuracy: 0.6409
# Epoch 286/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6572 - accuracy: 0.6058 - val_loss: 0.6318 - val_accuracy: 0.6498
# Epoch 287/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6562 - accuracy: 0.6143 - val_loss: 0.6349 - val_accuracy: 0.6490
# Epoch 288/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6462 - accuracy: 0.6327 - val_loss: 0.6940 - val_accuracy: 0.5705
# Epoch 289/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6499 - accuracy: 0.6122 - val_loss: 0.6349 - val_accuracy: 0.6387
# Epoch 290/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6594 - accuracy: 0.5987 - val_loss: 0.6361 - val_accuracy: 0.6374
# Epoch 291/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6487 - accuracy: 0.6242 - val_loss: 0.6570 - val_accuracy: 0.5992
# Epoch 292/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6311 - accuracy: 0.6445 - val_loss: 0.6332 - val_accuracy: 0.6404
# Epoch 293/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6602 - accuracy: 0.6005 - val_loss: 0.6359 - val_accuracy: 0.6472
# Epoch 294/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6580 - accuracy: 0.6083 - val_loss: 0.6312 - val_accuracy: 0.6471
# Epoch 295/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6507 - accuracy: 0.6298 - val_loss: 0.6413 - val_accuracy: 0.6251
# Epoch 296/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6399 - accuracy: 0.6267 - val_loss: 0.6321 - val_accuracy: 0.6528
# Epoch 297/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6625 - accuracy: 0.6043 - val_loss: 0.6329 - val_accuracy: 0.6515
# Epoch 298/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6428 - accuracy: 0.6325 - val_loss: 0.6660 - val_accuracy: 0.5813
# Epoch 299/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6284 - accuracy: 0.6492 - val_loss: 0.6334 - val_accuracy: 0.6398
# Epoch 300/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6595 - accuracy: 0.6112 - val_loss: 0.6356 - val_accuracy: 0.6471
