# %%
import math
import random
import os
import time
import json
from functools import partial
from collections import defaultdict

import numpy as np
import pandas as pd

# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf

# %% [markdown]
# ### Check Version

# %%
tf.__version__
# Out:
# '2.9.0'

# %% [markdown]
# ### GPU Configuration

# %%
gpus = tf.config.list_physical_devices('GPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ### Pandas Config

# %%
pd.set_option('display.max_column', None)

# %% [markdown]
# ### Input Pipeline

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256

TRAIN_BATCH_SIZE = 4
VAL_BATCH_SIZE = 4

# %%
CROP_WIDTH = 227
CROP_HEIGHT = 227

# %%
foldFiles = ["adience/unprocessed/fold_0_data.txt",
             "adience/unprocessed/fold_1_data.txt",
             "adience/unprocessed/fold_2_data.txt",
             "adience/unprocessed/fold_3_data.txt",
             "adience/unprocessed/fold_4_data.txt"]

# %%
genderMap = defaultdict(lambda : np.NaN)
genderMap['m'] = 0
genderMap['f'] = 1

# %%
ages = ['(0, 2)', '(4, 6)', '(8, 13)', '(15, 20)', '(25, 32)', '(38, 43)', '(48, 53)', '(60, 100)']
ageMap = defaultdict(lambda : np.NaN)
for i,a in enumerate(ages):
    ageMap[a] = i

# %% [markdown]
# ### Dataset Generation

# %% [markdown]
# Dataset generation pipeline:
# Input:
# - foldFile - Path to fold file. Fold file Describes which images are in the fold and its corresponding labels
# - imgBaseFolder - Base folder to search image from
# - imgPrefix - Prefix of image file
# - genderMap - Map from ['m', 'f', 'u', None], to one hot index
# - ageMap - Map from age category to one hot index
# - imgWidth - Resulting image width
# - imgHeigh - Resulting image height
# - batchSize - Int or None, batch size
# - configureDs - Function accepting dataset for performance configurations
# - preBatch - List of (name, functions) pair that will be mapped before batching. name is used as name parameters for tf graph
# - postBatch - List of (name, functions) that will be mapped after batching. name is used as name parameters for tf graph
#
# The processing functions should have signature function(img, label) -> (img, label)
#
# Pipeline
#
# Read Fold File -> Preprocess filename and labels (dataframe) -> Convert filename and labels to numpy array -> Convert filename and labels to tf dataset -> Parse images and labels -> Configure Dataset for performance -> Pre-Batching preprocessing -> Batch -> Post-Batching preprocessing -> Output
#
# Some preprocessing steps can only be done before and some can only be done after batching, thats why there are seperated pre and post batching list

# %%
def generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, batchSize, configureDs=None, preBatch=[], postBatch=[]):
    
    def parseImage(filename):
        img = tf.io.read_file(filename)
        img = tf.image.decode_jpeg(img)
        img = tf.image.resize(img, [imgHeight, imgWidth])
         
        return img
    
    # Read Fold File
    foldData = []
    for f in foldFiles:
        foldData.append(pd.read_csv(f, sep="\t"))
    foldData = pd.concat(foldData)
    
    # Form File Name
    foldData['filename'] = foldData.apply(lambda r: os.path.join(imgBaseFolder, r['user_id'], f"{imgPrefix}.{r['face_id']}.{r['original_image']}"), axis=1)
    
    # Generate Label One Hot Index
    foldData['gender_ind'] = foldData['gender'].map(genderMap)
    foldData['age_ind'] = foldData['age'].map(ageMap)
    
    # Remove dirty data
    foldData.dropna(subset=['gender_ind', 'age_ind'], inplace=True)
    
    # Dataframe to numpy
    filenames = foldData['filename'].to_numpy()
    
    genderIndex = foldData['gender_ind'].to_numpy().astype(int)
    ageIndex = foldData['age_ind'].to_numpy().astype(int)
    
    # Numpy to Dataset
    fnDs = tf.data.Dataset.from_tensor_slices(filenames)
    genderIndDs = tf.data.Dataset.from_tensor_slices(genderIndex)
    ageIndDs = tf.data.Dataset.from_tensor_slices(ageIndex)
    
    # Parse Images
    imageDs = fnDs.map(parseImage, num_parallel_calls=tf.data.AUTOTUNE, name="parse_image")
    
    # Parse Labels
    genderLabDs = genderIndDs.map(lambda x: tf.one_hot(x, genderDepth), num_parallel_calls=tf.data.AUTOTUNE, name="gender_one_hot")
    ageLabDs = ageIndDs.map(lambda x: tf.one_hot(x, ageDepth), num_parallel_calls=tf.data.AUTOTUNE, name="age_one_hot")
    
    # Combine Labels
    labelDs = tf.data.Dataset.zip((genderLabDs, ageLabDs), name="label_zip")
    labelDs = labelDs.map(lambda g,a: {"gender": g, "age": a}, num_parallel_calls=tf.data.AUTOTUNE, name='label_dict')
    
    # Combine Images and Labels into dataset
    ds = tf.data.Dataset.zip((imageDs, labelDs))
    
    # Configure Performance
    if(configureDs is not None):
        ds = configureDs(ds)
    
    # Pre Batch Preprocessing
    for n,f in preBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    # Batch
    if(batchSize is not None):
        ds = ds.batch(batchSize, name="ds_batch")
    
    # Post Batch Preprocessing
    for n,f in postBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    return ds

# %% [markdown]
# ### Preprocessings

# %%
def trainConfigPerformance(ds):
    #ds = ds.cache()
    ds = ds.shuffle(buffer_size=100)
    ds = ds.repeat()
    return ds

# %%
def valConfigPerformance(ds):
    #ds = ds.cache()
    return ds

# %% [markdown]
# #### Preprocessing steps

# %%
def trainPreprocessA(img, lab):
        
        img = tf.image.random_crop(img, [CROP_HEIGHT, CROP_WIDTH, 3])
        
        ud = tf.random.uniform([], dtype=tf.float32)
        udCond = tf.less(ud, 0.5)
        
        img = tf.cond(udCond, lambda: tf.image.flip_up_down(img), lambda: img)
        
        lr = tf.random.uniform([], dtype=tf.float32)
        lrCond = tf.less(lr, 0.5)
        
        img = tf.cond(lrCond, lambda: tf.image.flip_left_right(img), lambda: img)
        
        img = tf.image.random_brightness(img, 63/255)
        
        img = tf.image.random_contrast(img, 0.2, 1.8)
        
        return img, lab

# %%
def preprocessB(img, lab, rotL, rotH, shXL, shXH, shYL, shYH, zoomL, zoomH, hTransL, hTransH, vTransL, vTransH):
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    rRot = tf.random.uniform([shape[0]], minval=rotL, maxval=rotH, dtype=tf.float32)
    rShearX = tf.random.uniform([shape[0]], minval=shXL, maxval=shXH, dtype=tf.float32)
    rShearY = tf.random.uniform([shape[0]], minval=shYL, maxval=shYH, dtype=tf.float32)
    rZoom = tf.random.uniform([shape[0]], minval=zoomL, maxval=zoomH, dtype=tf.float32) #% Zoom
    rTx = tf.random.uniform([shape[0]], minval=hTransL, maxval=hTransH, dtype=tf.float32) #% Horiz Translation
    rTy = tf.random.uniform([shape[0]], minval=vTransL, maxval=vTransH, dtype=tf.float32) #% Vert Translation

    cT = tf.math.cos(rRot)
    sT = tf.math.sin(rRot)

    one = tf.ones([shape[0]], dtype=tf.float32)
    zero = tf.zeros([shape[0]], dtype=tf.float32)

    transC = tf.stack([[1, 0, -shapeF[2]/2], [0, 1, -shapeF[1]/2], [0, 0, 1]])
    transCI = tf.stack([[1, 0, shapeF[2]/2], [0, 1, shapeF[1]/2], [0, 0, 1]])

    trans = tf.transpose(tf.stack([[one, zero, rTx*shapeF[2]], [zero, one, rTy*shapeF[1]], [zero, zero, one]]), [2,0,1])
    rot = tf.transpose(tf.stack([[cT, -sT, zero], [sT, cT, zero], [zero, zero, one]]), [2,0,1])
    scale = tf.transpose(tf.stack([[rZoom, rShearX, zero], [rShearY, rZoom, zero], [zero, zero, one]]), [2,0,1])

    rotScale = rot@scale

    afTMat = transCI @ trans @ rotScale @ transC
    afT = tf.reshape(afTMat, [shape[0], -1])[:,:-1]

    img = tf.raw_ops.ImageProjectiveTransformV3(interpolation='NEAREST', images=img, transforms=afT, output_shape=shape[1:3], fill_value=0)

    return img, lab

# %%
def preprocessNoise(img, lab, gMean, gStd, spAmountP, spRatio, speckleVar):
        
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    # Gaussian Noise
    gNoise = tf.random.normal(shape, gMean, gStd)

    img += gNoise

    # Salt and pepper noise
    spMask = tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spAmountP), tf.float32)
    spNoise = 255*tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spRatio), tf.float32)

    img = tf.math.add(tf.math.multiply(img, 1.0 - spMask), tf.math.multiply(spNoise, spMask))

    # Speckles
    sNoise = speckleVar * tf.random.normal(shape)
    img = img + tf.math.multiply(img, sNoise)

    img = tf.clip_by_value(img, 0, 255)

    return img, lab

# %%
def clipValue(img, lab):
    img = tf.clip_by_value(img, 0.0, 255.0)
    return img, lab

# %%
def valPreprocessA(img, lab):
        
        img = tf.image.crop_to_bounding_box(img,
                                            (IMG_HEIGHT-CROP_HEIGHT) // 2,
                                            (IMG_WIDTH-CROP_WIDTH) // 2,
                                            CROP_HEIGHT,
                                            CROP_WIDTH)
        
        return img, lab

# %% [markdown]
# #### Label extractor

# %%
def extractGenderLabel(img, lab):
    
    lab = lab['gender']
    
    return img, lab

# %%
def extractAgeLabel(img, lab):
    
    lab = lab['age']
    
    return img, lab

# %% [markdown]
# ### Generate Folds for K-Folds validation

# %%
def generateFoldDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, valBatchSize, trainConfigureDs=None, trainPreBatch=[], trainPostBatch=[], valConfigureDs=None, valPreBatch=[], valPostBatch=[]):
    '''
        Returns list of (train, validation) datasets
    '''
    
    N = len(foldFiles)
    
    folds = []
    
    for i in range(N):
        
        trainFiles = foldFiles[:i]
        if(i < N-1):
            trainFiles.extend(foldFiles[i+1:])
            
        valFiles = foldFiles[i]
        
        trainDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, configureDs=trainConfigureDs, preBatch=trainPreBatch, postBatch=trainPostBatch)
        valDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, valBatchSize, configureDs=valConfigureDs, preBatch=valPreBatch, postBatch=valPostBatch)
        
        folds.append((trainDs, valDs))
        
    return folds

# %%
genParams = {
            "rotation": [-math.pi, math.pi],
            "shearX": [-0.2, 0.2],
            "shearY": [-0.2, 0.2],
            
            "zoom": [0.8, 1.2], # +- 20%
            "hTranslation": [-0.2, 0.2], # +- 20%
            "vTranslation": [-0.2, 0.2], # +- 20%
            
            "gaussianMean": 0.0,
            "gaussianStd": 2.0,
            
            "spAmount": 0.0001,
            "spRatio": 0.5,
            
            "speckleVar": 0.01
        }

# %%
trainPreprocessB = partial(preprocessB,
                           rotL = genParams['rotation'][0],
                           rotH = genParams['rotation'][1],
                           shXL = genParams['shearX'][0],
                           shXH = genParams['shearX'][1], 
                           shYL = genParams['shearY'][0],
                           shYH = genParams['shearY'][1],
                           zoomL = genParams['zoom'][0],
                           zoomH = genParams['zoom'][1],
                           hTransL = genParams['hTranslation'][0],
                           hTransH = genParams['hTranslation'][1],
                           vTransL = genParams['vTranslation'][0],
                           vTransH = genParams['vTranslation'][1])

# %%
trainPreprocessC = partial(preprocessNoise,
                           gMean = genParams['gaussianMean'],
                           gStd = genParams['gaussianStd'],
                           spAmountP = genParams['spAmount'],
                           spRatio = genParams['spRatio'],
                           speckleVar = genParams['speckleVar'])

# %%
trainPreBatch = [("train_process_a", trainPreprocessA)]
trainPostBatch = [("train_process_b", trainPreprocessB),
                  ("train_process_c", trainPreprocessC),
                  ("train_clip", clipValue),
                  ("train_extract_gender", extractGenderLabel)]

valPreBatch = [("val_process_a", valPreprocessA), 
               ("val_extract_gender", extractGenderLabel)]

# %%
folds = generateFoldDs(foldFiles, "adience/faces", "coarse_tilt_aligned_face", genderMap, ageMap, 2, 8, 
                       IMG_WIDTH, IMG_HEIGHT, TRAIN_BATCH_SIZE, VAL_BATCH_SIZE, 
                       trainConfigureDs=trainConfigPerformance, trainPreBatch=trainPreBatch, 
                       trainPostBatch=trainPostBatch,
                       valConfigureDs=valConfigPerformance, valPreBatch=valPreBatch)
# Out:
# 2022-11-05 18:49:54.139801: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-05 18:49:54.637186: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 4459 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
len(folds)
# Out:
# 5

# %% [markdown]
# ### Check data

# %%
for x,y in folds[0][0].take(1):
    pass

# %%
x
# Out:
# <tf.Tensor: shape=(4, 227, 227, 3), dtype=float32, numpy=
# array([[[[0.00000000e+00, 0.00000000e+00, 1.08076179e+00],
#          [0.00000000e+00, 1.96157682e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 1.40041733e+00, 0.00000000e+00],
#          [3.13970923e+00, 0.00000000e+00, 2.37192765e-01],
#          [1.05660748e+00, 5.96217029e-02, 5.99863470e-01]],
#
#         [[0.00000000e+00, 1.48409724e-01, 8.98230493e-01],
#          [1.19658661e+00, 3.06057382e+00, 1.34998643e+00],
#          [0.00000000e+00, 0.00000000e+00, 1.69112170e+00],
#          ...,
#          [0.00000000e+00, 1.79668546e+00, 1.46885383e+00],
#          [0.00000000e+00, 2.74237603e-01, 2.70029378e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00]],
#
#         [[2
+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 1.36287972e-01],
#          ...,
#          [3.12636518e+00, 0.00000000e+00, 3.61026466e-01],
#          [1.55315250e-01, 2.29370141e+00, 0.00000000e+00],
#          [2.86702895e+00, 0.00000000e+00, 0.00000000e+00]]]],
#       dtype=float32)>

# %%
y
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[1., 0.],
#        [0., 1.],
#        [0., 1.],
#        [1., 0.]], dtype=float32)>

# %%
fig1, ax1 = plt.subplots(nrows=TRAIN_BATCH_SIZE, ncols=1)

if(TRAIN_BATCH_SIZE is None or TRAIN_BATCH_SIZE == 1):
    ax1.imshow(x/255)
    ax1.set_title(y)
else:
    for i in range(TRAIN_BATCH_SIZE):
        ax1[i].imshow(x[i]/255)
        ax1[i].set_title(f"Gender:{y[i]}")
        
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model

# %%
def createModel():
    inp = tf.keras.Input(shape=(CROP_HEIGHT, CROP_WIDTH, 3))

    conv1 = tf.keras.layers.Conv2D(64, 7, strides=(4,4), activation='relu', name='conv1')
    pool1 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool1')

    conv2 = tf.keras.layers.Conv2D(128, 5, activation='relu', name='conv2')
    pool2 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool2')

    conv3 = tf.keras.layers.Conv2D(256, 3, activation='relu', name='conv3')
    pool3 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool3')

    flat1 = tf.keras.layers.Flatten(name='flat1')
    fc1 = tf.keras.layers.Dense(128, activation='relu', name='fc1')
    do1 = tf.keras.layers.Dropout(0.5, name='do1')

    fc2 = tf.keras.layers.Dense(2, activation='softmax', name='fc2')

    o = inp / 127.5 - 1.0
    
    o = conv1(o)
    o = pool1(o)

    o = conv2(o)
    o = pool2(o)

    o = conv3(o)
    o = pool3(o)

    o = flat1(o)
    o = fc1(o)
    o = do1(o)

    o = fc2(o)

    model = tf.keras.models.Model(inputs=inp, outputs=o, name='CNN_1')
    
    return model

# %%
model = createModel()

# %%
model.summary()
# Out:
# Model: "CNN_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 227, 227, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 227, 227, 3)      0
#  a)
#
#  conv1 (Conv2D)              (None, 56, 56, 64)        9472
#
#  pool1 (MaxPooling2D)        (None, 27, 27, 64)        0
#
#  conv2 (Conv2D)              (None, 23, 23, 128)       204928
#
#  pool2 (MaxPooling2D)        (None, 11, 11, 128)       0
#
#  conv3 (Conv2D)              (None, 9, 9, 256)         295168
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  flat1 (Flatten)             (None, 4096)              0
#
#  fc1 (Dense)                 (None, 128)               524416
#
#  do1 (Dropout)               (None, 128)               0
#
#  fc2 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 1,034,242
# Trainable params: 1,034,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile Model

# %%
STEPS_PER_EPOCH = 1000
EPOCH = 300

START_EPOCH = 0
END_EPOCH = START_EPOCH + EPOCH

# %% [markdown]
# #### Learning Rate Schedule

# %%
def schedule(epoch, lr):
    return lr

# %%
logBasePath = "log/CNN_3"
logPrefix = "log"

# %%
for i, (train, val) in enumerate([folds[0]]):
    
    model = createModel()
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.000005)
    loss = tf.keras.losses.CategoricalCrossentropy()
    metrics = ['accuracy']
    
    model.compile(optimizer=opt, loss=loss, metrics=metrics)
    
    tboardCb = tf.keras.callbacks.TensorBoard(log_dir=f"{logBasePath}/{logPrefix}_{i}", histogram_freq=1, profile_batch=(2,10))
    lrSchedule = tf.keras.callbacks.LearningRateScheduler(schedule)
    
    cbs = [tboardCb]
    
    model.evaluate(val)
    model.fit(train, initial_epoch=START_EPOCH, epochs=END_EPOCH, steps_per_epoch=STEPS_PER_EPOCH, callbacks=cbs, validation_data=val)
# Out:
# 2022-11-05 18:49:59.032529: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-05 18:49:59.032560: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-05 18:49:59.032584: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1665] Profiler found 1 GPUs
# 2022-11-05 18:49:59.032868: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/ntcadmin/env/trt-11.0/TensorRT-7.1.3.4/lib:
# 2022-11-05 18:49:59.032945: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so'; dlerror: libcupti.so: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/ntcadmin/env/trt-11.0/TensorRT-7.1.3.4/lib:
# 2022-11-05 18:49:59.032956: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: error 999:
# 2022-11-05 18:49:59.032965: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:184] cuptiSubscribe: ignored due to a previous error.
# 2022-11-05 18:49:59.032972: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-05 18:49:59.032978: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1716] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2022-11-05 18:49:59.033002: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-05 18:49:59.033024: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:140] cuptiFinalize: ignored due to a previous error.
# 2022-11-05 18:49:59.033030: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-05 18:49:59.033033: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1808] function cupti_interface_->Finalize()failed with error
# 2022-11-05 18:49:59.752263: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 3528/3528 [==============================] - 13s 3ms/step - loss: 0.6938 - accuracy: 0.4859
# Epoch 1/300
#   16/1000 [..............................] - ETA: 10s - loss: 0.6991 - accuracy: 0.4688
# 2022-11-05 18:50:13.538454: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-05 18:50:13.538476: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-05 18:50:13.538534: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-05 18:50:13.538547: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:184] cuptiSubscribe: ignored due to a previous error.
# 2022-11-05 18:50:13.538551: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-05 18:50:13.538556: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1716] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2022-11-05 18:50:13.589582: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-11-05 18:50:13.589782: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:140] cuptiFinalize: ignored due to a previous error.
# 2022-11-05 18:50:13.589798: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-05 18:50:13.589805: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1808] function cupti_interface_->Finalize()failed with error
# 2022-11-05 18:50:13.600108: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-05 18:50:13.600149: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-05 18:50:13.600157: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:521]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2022-11-05 18:50:13.602379: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-05 18:50:13.604682: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13
#
# 2022-11-05 18:50:13.606021: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.trace.json.gz
# 2022-11-05 18:50:13.632209: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13
#
# 2022-11-05 18:50:13.637198: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.memory_profile.json.gz
# 2022-11-05 18:50:13.637432: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13
# Dumped tool data for xplane.pb to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.xplane.pb
# Dumped tool data for overview_page.pb to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.overview_page.pb
# Dumped tool data for input_pipeline.pb to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to log/CNN_3/log_0/plugins/profile/2022_11_05_18_50_13/ntcadmin-scse.kernel_stats.pb
# 1000/1000 [==============================] - 18s 17ms/step - loss: 0.6936 - accuracy: 0.5260 - val_loss: 0.6858 - val_accuracy: 0.5598
# Epoch 2/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6891 - accuracy: 0.5540 - val_loss: 0.6877 - val_accuracy: 0.5251
# Epoch 3/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6687 - accuracy: 0.5885 - val_loss: 0.6852 - val_accuracy: 0.5859
# Epoch 4/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6821 - accuracy: 0.5560 - val_loss: 0.6781 - val_accuracy: 0.5766
# Epoch 5/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6864 - accuracy: 0.5403 - val_loss: 0.6760 - val_accuracy: 0.5698
# Epoch 6/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6569 - accuracy: 0.6160 - val_loss: 0.6737 - val_accuracy: 0.5861
# Epoch 7/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6826 - accuracy: 0.5683 - val_loss: 0.6810 - val_accuracy: 0.5426
# Epoch 8/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6867 - accuracy: 0.5525 - val_loss: 0.6724 - val_accuracy: 0.6017
# Epoch 9/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6824 - accuracy: 0.5658 - val_loss: 0.6824 - val_accuracy: 0.5438
# Epoch 10/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6594 - accuracy: 0.5970 - val_loss: 0.6813 - val_accuracy: 0.5668
# Epoch 11/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6788 - accuracy: 0.5763 - val_loss: 0.6795 - val_accuracy: 0.5573
# Epoch 12/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6849 - accuracy: 0.5527 - val_loss: 0.6697 - val_accuracy: 0.5933
# Epoch 13/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6528 - accuracy: 0.6160 - val_loss: 0.6686 - val_accuracy: 0.5949
# Epoch 14/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6752 - accuracy: 0.5805 - val_loss: 0.6865 - val_accuracy: 0.5389
# Epoch 15/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6844 - accuracy: 0.5527 - val_loss: 0.6677 - val_accuracy: 0.6037
# Epoch 16/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6769 - accuracy: 0.5778 - val_loss: 0.6783 - val_accuracy: 0.5527
# Epoch 17/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6542 - accuracy: 0.6072 - val_loss: 0.6808 - val_accuracy: 0.5472
# Epoch 18/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6713 - accuracy: 0.5815 - val_loss: 0.6685 - val_accuracy: 0.5922
# Epoch 19/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6805 - accuracy: 0.5705 - val_loss: 0.6644 - val_accuracy: 0.6110
# Epoch 20/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6441 - accuracy: 0.6323 - val_loss: 0.7467 - val_accuracy: 0.5374
# Epoch 21/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6754 - accuracy: 0.5767 - val_loss: 0.6933 - val_accuracy: 0.5394
# Epoch 22/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6782 - accuracy: 0.5600 - val_loss: 0.6625 - val_accuracy: 0.6138
# Epoch 23/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6725 - accuracy: 0.5945 - val_loss: 0.6645 - val_accuracy: 0.5878
# Epoch 24/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.
300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5761 - accuracy: 0.7015 - val_loss: 0.7227 - val_accuracy: 0.5664
# Epoch 179/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5729 - accuracy: 0.6955 - val_loss: 0.5736 - val_accuracy: 0.6912
# Epoch 180/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6156 - accuracy: 0.6547 - val_loss: 0.5923 - val_accuracy: 0.6809
# Epoch 181/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6092 - accuracy: 0.6647 - val_loss: 0.5942 - val_accuracy: 0.6857
# Epoch 182/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5979 - accuracy: 0.6680 - val_loss: 0.5762 - val_accuracy: 0.7011
# Epoch 183/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5870 - accuracy: 0.6752 - val_loss: 0.5805 - val_accuracy: 0.6920
# Epoch 184/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6086 - accuracy: 0.6597 - val_loss: 0.5884 - val_accuracy: 0.7031
# Epoch 185/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5952 - accuracy: 0.6827 - val_loss: 0.5871 - val_accuracy: 0.6876
# Epoch 186/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5759 - accuracy: 0.7075 - val_loss: 0.5680 - val_accuracy: 0.6965
# Epoch 187/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6128 - accuracy: 0.6590 - val_loss: 0.5691 - val_accuracy: 0.7004
# Epoch 188/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6076 - accuracy: 0.6737 - val_loss: 0.6134 - val_accuracy: 0.6716
# Epoch 189/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5947 - accuracy: 0.6840 - val_loss: 0.5729 - val_accuracy: 0.7053
# Epoch 190/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5930 - accuracy: 0.6775 - val_loss: 0.6123 - val_accuracy: 0.6680
# Epoch 191/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6058 - accuracy: 0.6630 - val_loss: 0.5776 - val_accuracy: 0.7061
# Epoch 192/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5879 - accuracy: 0.6835 - val_loss: 0.5669 - val_accuracy: 0.7026
# Epoch 193/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5735 - accuracy: 0.7057 - val_loss: 0.5792 - val_accuracy: 0.6966
# Epoch 194/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6116 - accuracy: 0.6615 - val_loss: 0.5691 - val_accuracy: 0.7021
# Epoch 195/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6128 - accuracy: 0.6612 - val_loss: 0.5626 - val_accuracy: 0.7034
# Epoch 196/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5768 - accuracy: 0.7007 - val_loss: 0.5723 - val_accuracy: 0.6959
# Epoch 197/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5834 - accuracy: 0.6833 - val_loss: 0.5641 - val_accuracy: 0.7074
# Epoch 198/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6073 - accuracy: 0.6658 - val_loss: 0.5788 - val_accuracy: 0.6990
# Epoch 199/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5895 - accuracy: 0.6815 - val_loss: 0.5771 - val_accuracy: 0.6958
# Epoch 200/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5740 - accuracy: 0.7067 - val_loss: 0.5686 - val_accuracy: 0.7007
# Epoch 201/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6021 - accuracy: 0.6675 - val_loss: 0.5841 - val_accuracy: 0.6829
# Epoch 202/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6140 - accuracy: 0.6463 - val_loss: 0.5614 - val_accuracy: 0.7115
# Epoch 203/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5610 - accuracy: 0.7115 - val_loss: 0.5822 - val_accuracy: 0.6814
# Epoch 204/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5812 - accuracy: 0.6880 - val_loss: 0.5687 - val_accuracy: 0.7060
# Epoch 205/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5990 - accuracy: 0.6802 - val_loss: 0.7471 - val_accuracy: 0.5556
# Epoch 206/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5887 - accuracy: 0.6760 - val_loss: 0.5660 - val_accuracy: 0.7017
# Epoch 207/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5714 - accuracy: 0.6970 - val_loss: 0.5782 - val_accuracy: 0.6834
# Epoch 208/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5983 - accuracy: 0.6743 - val_loss: 0.6086 - val_accuracy: 0.6593
# Epoch 209/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6119 - accuracy: 0.6543 - val_loss: 0.5545 - val_accuracy: 0.7111
# Epoch 210/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5591 - accuracy: 0.7155 - val_loss: 0.5823 - val_accuracy: 0.6816
# Epoch 211/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5734 - accuracy: 0.6817 - val_loss: 0.6480 - val_accuracy: 0.6408
# Epoch 212/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6075 - accuracy: 0.6693 - val_loss: 0.5651 - val_accuracy: 0.7077
# Epoch 213/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5763 - accuracy: 0.6952 - val_loss: 0.5568 - val_accuracy: 0.7091
# Epoch 214/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5646 - accuracy: 0.7028 - val_loss: 0.6464 - val_accuracy: 0.6379
# Epoch 215/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5929 - accuracy: 0.6817 - val_loss: 0.5978 - val_accuracy: 0.6650
# Epoch 216/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6009 - accuracy: 0.6795 - val_loss: 0.5567 - val_accuracy: 0.7160
# Epoch 217/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5624 - accuracy: 0.7103 - val_loss: 0.5720 - val_accuracy: 0.6936
# Epoch 218/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5709 - accuracy: 0.6890 - val_loss: 0.6375 - val_accuracy: 0.6564
# Epoch 219/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5951 - accuracy: 0.6837 - val_loss: 0.5666 - val_accuracy: 0.6987
# Epoch 220/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5749 - accuracy: 0.6935 - val_loss: 0.6193 - val_accuracy: 0.6701
# Epoch 221/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5749 - accuracy: 0.7007 - val_loss: 0.6770 - val_accuracy: 0.6248
# Epoch 222/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5955 - accuracy: 0.6845 - val_loss: 0.5680 - val_accuracy: 0.6944
# Epoch 223/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5904 - accuracy: 0.6815 - val_loss: 0.5529 - val_accuracy: 0.7231
# Epoch 224/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5726 - accuracy: 0.7088 - val_loss: 0.5682 - val_accuracy: 0.6947
# Epoch 225/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5701 - accuracy: 0.7013 - val_loss: 0.5559 - val_accuracy: 0.7090
# Epoch 226/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5963 - accuracy: 0.6733 - val_loss: 0.5441 - val_accuracy: 0.7185
# Epoch 227/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5788 - accuracy: 0.6927 - val_loss: 0.5502 - val_accuracy: 0.7138
# Epoch 228/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5795 - accuracy: 0.6917 - val_loss: 0.6164 - val_accuracy: 0.6569
# Epoch 229/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5841 - accuracy: 0.6852 - val_loss: 0.5606 - val_accuracy: 0.7237
# Epoch 230/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5927 - accuracy: 0.6737 - val_loss: 0.5584 - val_accuracy: 0.7176
# Epoch 231/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5480 - accuracy: 0.7250 - val_loss: 0.6146 - val_accuracy: 0.6592
# Epoch 232/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5693 - accuracy: 0.6933 - val_loss: 0.5689 - val_accuracy: 0.6966
# Epoch 233/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5916 - accuracy: 0.6870 - val_loss: 0.5726 - val_accuracy: 0.6958
# Epoch 234/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5796 - accuracy: 0.6942 - val_loss: 0.5620 - val_accuracy: 0.7046
# Epoch 235/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5855 - accuracy: 0.6805 - val_loss: 0.5608 - val_accuracy: 0.7088
# Epoch 236/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5769 - accuracy: 0.6883 - val_loss: 0.5615 - val_accuracy: 0.7209
# Epoch 237/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5980 - accuracy: 0.6833 - val_loss: 0.5685 - val_accuracy: 0.7238
# Epoch 238/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5510 - accuracy: 0.7230 - val_loss: 0.6658 - val_accuracy: 0.6282
# Epoch 239/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5676 - accuracy: 0.6952 - val_loss: 0.5463 - val_accuracy: 0.7170
# Epoch 240/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5894 - accuracy: 0.6852 - val_loss: 0.5546 - val_accuracy: 0.7126
# Epoch 241/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5691 - accuracy: 0.7013 - val_loss: 0.6026 - val_accuracy: 0.6848
# Epoch 242/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5816 - accuracy: 0.6830 - val_loss: 0.5474 - val_accuracy: 0.7287
# Epoch 243/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5613 - accuracy: 0.6965 - val_loss: 0.5862 - val_accuracy: 0.6747
# Epoch 244/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5925 - accuracy: 0.6890 - val_loss: 0.5851 - val_accuracy: 0.6956
# Epoch 245/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5591 - accuracy: 0.7122 - val_loss: 0.6585 - val_accuracy: 0.6307
# Epoch 246/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5603 - accuracy: 0.7080 - val_loss: 0.5502 - val_accuracy: 0.7111
# Epoch 247/300
# 1000/1000 [==============================] - 16s 17ms/step - loss: 0.5951 - accuracy: 0.6730 - val_loss: 0.5453 - val_accuracy: 0.7209
# Epoch 248/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5639 - accuracy: 0.7003 - val_loss: 0.6489 - val_accuracy: 0.6652
# Epoch 249/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5757 - accuracy: 0.6935 - val_loss: 0.5535 - val_accuracy: 0.7196
# Epoch 250/300
# 1000/1000 [==============================] - 18s 18ms/step - loss: 0.5669 - accuracy: 0.7035 - val_loss: 0.5676 - val_accuracy: 0.7055
# Epoch 251/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5891 - accuracy: 0.6867 - val_loss: 0.5455 - val_accuracy: 0.7270
# Epoch 252/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5588 - accuracy: 0.7105 - val_loss: 0.5290 - val_accuracy: 0.7315
# Epoch 253/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5502 - accuracy: 0.7157 - val_loss: 0.5373 - val_accuracy: 0.7244
# Epoch 254/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5942 - accuracy: 0.6823 - val_loss: 0.5642 - val_accuracy: 0.6986
# Epoch 255/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5835 - accuracy: 0.6877 - val_loss: 0.5426 - val_accuracy: 0.7218
# Epoch 256/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5526 - accuracy: 0.7165 - val_loss: 0.5371 - val_accuracy: 0.7348
# Epoch 257/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5604 - accuracy: 0.7055 - val_loss: 0.5429 - val_accuracy: 0.7235
# Epoch 258/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5818 - accuracy: 0.6938 - val_loss: 0.5735 - val_accuracy: 0.6846
# Epoch 259/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5604 - accuracy: 0.7078 - val_loss: 0.5307 - val_accuracy: 0.7279
# Epoch 260/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5530 - accuracy: 0.7182 - val_loss: 0.5515 - val_accuracy: 0.7161
# Epoch 261/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5851 - accuracy: 0.6823 - val_loss: 0.5479 - val_accuracy: 0.7134
# Epoch 262/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5716 - accuracy: 0.6977 - val_loss: 0.5363 - val_accuracy: 0.7225
# Epoch 263/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5358 - accuracy: 0.7308 - val_loss: 0.5516 - val_accuracy: 0.7055
# Epoch 264/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5594 - accuracy: 0.7070 - val_loss: 0.5502 - val_accuracy: 0.7156
# Epoch 265/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5840 - accuracy: 0.6908 - val_loss: 0.5586 - val_accuracy: 0.7124
# Epoch 266/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5616 - accuracy: 0.6995 - val_loss: 0.5609 - val_accuracy: 0.7006
# Epoch 267/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5454 - accuracy: 0.7205 - val_loss: 0.5342 - val_accuracy: 0.7291
# Epoch 268/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5833 - accuracy: 0.6870 - val_loss: 0.5612 - val_accuracy: 0.7041
# Epoch 269/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5824 - accuracy: 0.6915 - val_loss: 0.5246 - val_accuracy: 0.7372
# Epoch 270/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5474 - accuracy: 0.7207 - val_loss: 0.5508 - val_accuracy: 0.7084
# Epoch 271/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5569 - accuracy: 0.7048 - val_loss: 0.5404 - val_accuracy: 0.7279
# Epoch 272/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5750 - accuracy: 0.6975 - val_loss: 0.6278 - val_accuracy: 0.6466
# Epoch 273/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5526 - accuracy: 0.7178 - val_loss: 0.5342 - val_accuracy: 0.7252
# Epoch 274/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5478 - accuracy: 0.7182 - val_loss: 0.5848 - val_accuracy: 0.6835
# Epoch 275/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5742 - accuracy: 0.7038 - val_loss: 0.5856 - val_accuracy: 0.6812
# Epoch 276/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5781 - accuracy: 0.6930 - val_loss: 0.5288 - val_accuracy: 0.7337
# Epoch 277/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5329 - accuracy: 0.7355 - val_loss: 0.5271 - val_accuracy: 0.7368
# Epoch 278/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5542 - accuracy: 0.7132 - val_loss: 0.6760 - val_accuracy: 0.6355
# Epoch 279/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5830 - accuracy: 0.6988 - val_loss: 0.5294 - val_accuracy: 0.7296
# Epoch 280/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5478 - accuracy: 0.7190 - val_loss: 0.5415 - val_accuracy: 0.7214
# Epoch 281/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5583 - accuracy: 0.7050 - val_loss: 0.6459 - val_accuracy: 0.6371
# Epoch 282/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5772 - accuracy: 0.6950 - val_loss: 0.5547 - val_accuracy: 0.7017
# Epoch 283/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5691 - accuracy: 0.6998 - val_loss: 0.5354 - val_accuracy: 0.7306
# Epoch 284/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5345 - accuracy: 0.7365 - val_loss: 0.6103 - val_accuracy: 0.6688
# Epoch 285/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5587 - accuracy: 0.7090 - val_loss: 0.5299 - val_accuracy: 0.7343
# Epoch 286/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5675 - accuracy: 0.7003 - val_loss: 0.5459 - val_accuracy: 0.7135
# Epoch 287/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5560 - accuracy: 0.7163 - val_loss: 0.5801 - val_accuracy: 0.6986
# Epoch 288/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5501 - accuracy: 0.7140 - val_loss: 0.6854 - val_accuracy: 0.6252
# Epoch 289/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5590 - accuracy: 0.7048 - val_loss: 0.5525 - val_accuracy: 0.7057
# Epoch 290/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5747 - accuracy: 0.7045 - val_loss: 0.5304 - val_accuracy: 0.7345
# Epoch 291/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5285 - accuracy: 0.7383 - val_loss: 0.5139 - val_accuracy: 0.7438
# Epoch 292/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5462 - accuracy: 0.7207 - val_loss: 0.5215 - val_accuracy: 0.7372
# Epoch 293/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.5690 - accuracy: 0.7038 - val_loss: 0.5176 - val_accuracy: 0.7373
# Epoch 294/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5562 - accuracy: 0.7153 - val_loss: 0.5216 - val_accuracy: 0.7352
# Epoch 295/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5662 - accuracy: 0.7023 - val_loss: 0.5466 - val_accuracy: 0.7096
# Epoch 296/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5540 - accuracy: 0.7125 - val_loss: 0.5470 - val_accuracy: 0.7369
# Epoch 297/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5731 - accuracy: 0.6938 - val_loss: 0.5333 - val_accuracy: 0.7412
# Epoch 298/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5252 - accuracy: 0.7343 - val_loss: 0.5861 - val_accuracy: 0.6865
# Epoch 299/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5436 - accuracy: 0.7207 - val_loss: 0.5278 - val_accuracy: 0.7317
# Epoch 300/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.5644 - accuracy: 0.7067 - val_loss: 0.5430 - val_accuracy: 0.7218
