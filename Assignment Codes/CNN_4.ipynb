# %%
import math
import random
import os
import time
import json
from functools import partial
from collections import defaultdict

import numpy as np
import pandas as pd

# %matplotlib notebook
import matplotlib
import matplotlib.pyplot as plt

import tensorflow as tf

# %% [markdown]
# ### Check Version

# %%
tf.__version__
# Out:
# '2.9.0'

# %% [markdown]
# ### GPU Configuration

# %%
gpus = tf.config.list_physical_devices('GPU')

# %%
gpus
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
tf.config.experimental.set_memory_growth(gpus[0], True)

# %% [markdown]
# ### Pandas Config

# %%
pd.set_option('display.max_column', None)

# %% [markdown]
# ### Input Pipeline

# %%
IMG_WIDTH = 256
IMG_HEIGHT = 256

TRAIN_BATCH_SIZE = 4
VAL_BATCH_SIZE = 4

# %%
CROP_WIDTH = 227
CROP_HEIGHT = 227

# %%
foldFiles = ["adience/unprocessed/fold_0_data.txt",
             "adience/unprocessed/fold_1_data.txt",
             "adience/unprocessed/fold_2_data.txt",
             "adience/unprocessed/fold_3_data.txt",
             "adience/unprocessed/fold_4_data.txt"]

# %%
genderMap = defaultdict(lambda : np.NaN)
genderMap['m'] = 0
genderMap['f'] = 1

# %%
ages = ['(0, 2)', '(4, 6)', '(8, 13)', '(15, 20)', '(25, 32)', '(38, 43)', '(48, 53)', '(60, 100)']
ageMap = defaultdict(lambda : np.NaN)
for i,a in enumerate(ages):
    ageMap[a] = i

# %% [markdown]
# ### Dataset Generation

# %% [markdown]
# Dataset generation pipeline:
# Input:
# - foldFile - Path to fold file. Fold file Describes which images are in the fold and its corresponding labels
# - imgBaseFolder - Base folder to search image from
# - imgPrefix - Prefix of image file
# - genderMap - Map from ['m', 'f', 'u', None], to one hot index
# - ageMap - Map from age category to one hot index
# - imgWidth - Resulting image width
# - imgHeigh - Resulting image height
# - batchSize - Int or None, batch size
# - configureDs - Function accepting dataset for performance configurations
# - preBatch - List of (name, functions) pair that will be mapped before batching. name is used as name parameters for tf graph
# - postBatch - List of (name, functions) that will be mapped after batching. name is used as name parameters for tf graph
#
# The processing functions should have signature function(img, label) -> (img, label)
#
# Pipeline
#
# Read Fold File -> Preprocess filename and labels (dataframe) -> Convert filename and labels to numpy array -> Convert filename and labels to tf dataset -> Parse images and labels -> Configure Dataset for performance -> Pre-Batching preprocessing -> Batch -> Post-Batching preprocessing -> Output
#
# Some preprocessing steps can only be done before and some can only be done after batching, thats why there are seperated pre and post batching list

# %%
def generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, batchSize, configureDs=None, preBatch=[], postBatch=[]):
    
    def parseImage(filename):
        img = tf.io.read_file(filename)
        img = tf.image.decode_jpeg(img)
        img = tf.image.resize(img, [imgHeight, imgWidth])
         
        return img
    
    # Read Fold File
    foldData = []
    for f in foldFiles:
        foldData.append(pd.read_csv(f, sep="\t"))
    foldData = pd.concat(foldData)
    
    # Form File Name
    foldData['filename'] = foldData.apply(lambda r: os.path.join(imgBaseFolder, r['user_id'], f"{imgPrefix}.{r['face_id']}.{r['original_image']}"), axis=1)
    
    # Generate Label One Hot Index
    foldData['gender_ind'] = foldData['gender'].map(genderMap)
    foldData['age_ind'] = foldData['age'].map(ageMap)
    
    # Remove dirty data
    foldData.dropna(subset=['gender_ind', 'age_ind'], inplace=True)
    
    # Dataframe to numpy
    filenames = foldData['filename'].to_numpy()
    
    genderIndex = foldData['gender_ind'].to_numpy().astype(int)
    ageIndex = foldData['age_ind'].to_numpy().astype(int)
    
    # Numpy to Dataset
    fnDs = tf.data.Dataset.from_tensor_slices(filenames)
    genderIndDs = tf.data.Dataset.from_tensor_slices(genderIndex)
    ageIndDs = tf.data.Dataset.from_tensor_slices(ageIndex)
    
    # Parse Images
    imageDs = fnDs.map(parseImage, num_parallel_calls=tf.data.AUTOTUNE, name="parse_image")
    
    # Parse Labels
    genderLabDs = genderIndDs.map(lambda x: tf.one_hot(x, genderDepth), num_parallel_calls=tf.data.AUTOTUNE, name="gender_one_hot")
    ageLabDs = ageIndDs.map(lambda x: tf.one_hot(x, ageDepth), num_parallel_calls=tf.data.AUTOTUNE, name="age_one_hot")
    
    # Combine Labels
    labelDs = tf.data.Dataset.zip((genderLabDs, ageLabDs), name="label_zip")
    labelDs = labelDs.map(lambda g,a: {"gender": g, "age": a}, num_parallel_calls=tf.data.AUTOTUNE, name='label_dict')
    
    # Combine Images and Labels into dataset
    ds = tf.data.Dataset.zip((imageDs, labelDs))
    
    # Configure Performance
    if(configureDs is not None):
        ds = configureDs(ds)
    
    # Pre Batch Preprocessing
    for n,f in preBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    # Batch
    if(batchSize is not None):
        ds = ds.batch(batchSize, name="ds_batch")
    
    # Post Batch Preprocessing
    for n,f in postBatch:
        ds = ds.map(f, num_parallel_calls=tf.data.AUTOTUNE, name=n)
    
    return ds

# %% [markdown]
# ### Preprocessings

# %%
def trainConfigPerformance(ds):
    #ds = ds.cache()
    ds = ds.shuffle(buffer_size=100)
    ds = ds.repeat()
    return ds

# %%
def valConfigPerformance(ds):
    #ds = ds.cache()
    return ds

# %% [markdown]
# #### Preprocessing steps

# %%
def trainPreprocessA(img, lab):
        
        img = tf.image.random_crop(img, [CROP_HEIGHT, CROP_WIDTH, 3])
        
        ud = tf.random.uniform([], dtype=tf.float32)
        udCond = tf.less(ud, 0.5)
        
        img = tf.cond(udCond, lambda: tf.image.flip_up_down(img), lambda: img)
        
        lr = tf.random.uniform([], dtype=tf.float32)
        lrCond = tf.less(lr, 0.5)
        
        img = tf.cond(lrCond, lambda: tf.image.flip_left_right(img), lambda: img)
        
        img = tf.image.random_brightness(img, 63/255)
        
        img = tf.image.random_contrast(img, 0.2, 1.8)
        
        return img, lab

# %%
def preprocessB(img, lab, rotL, rotH, shXL, shXH, shYL, shYH, zoomL, zoomH, hTransL, hTransH, vTransL, vTransH):
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    rRot = tf.random.uniform([shape[0]], minval=rotL, maxval=rotH, dtype=tf.float32)
    rShearX = tf.random.uniform([shape[0]], minval=shXL, maxval=shXH, dtype=tf.float32)
    rShearY = tf.random.uniform([shape[0]], minval=shYL, maxval=shYH, dtype=tf.float32)
    rZoom = tf.random.uniform([shape[0]], minval=zoomL, maxval=zoomH, dtype=tf.float32) #% Zoom
    rTx = tf.random.uniform([shape[0]], minval=hTransL, maxval=hTransH, dtype=tf.float32) #% Horiz Translation
    rTy = tf.random.uniform([shape[0]], minval=vTransL, maxval=vTransH, dtype=tf.float32) #% Vert Translation

    cT = tf.math.cos(rRot)
    sT = tf.math.sin(rRot)

    one = tf.ones([shape[0]], dtype=tf.float32)
    zero = tf.zeros([shape[0]], dtype=tf.float32)

    transC = tf.stack([[1, 0, -shapeF[2]/2], [0, 1, -shapeF[1]/2], [0, 0, 1]])
    transCI = tf.stack([[1, 0, shapeF[2]/2], [0, 1, shapeF[1]/2], [0, 0, 1]])

    trans = tf.transpose(tf.stack([[one, zero, rTx*shapeF[2]], [zero, one, rTy*shapeF[1]], [zero, zero, one]]), [2,0,1])
    rot = tf.transpose(tf.stack([[cT, -sT, zero], [sT, cT, zero], [zero, zero, one]]), [2,0,1])
    scale = tf.transpose(tf.stack([[rZoom, rShearX, zero], [rShearY, rZoom, zero], [zero, zero, one]]), [2,0,1])

    rotScale = rot@scale

    afTMat = transCI @ trans @ rotScale @ transC
    afT = tf.reshape(afTMat, [shape[0], -1])[:,:-1]

    img = tf.raw_ops.ImageProjectiveTransformV3(interpolation='NEAREST', images=img, transforms=afT, output_shape=shape[1:3], fill_value=0)

    return img, lab

# %%
def preprocessNoise(img, lab, gMean, gStd, spAmountP, spRatio, speckleVar):
        
    shape = tf.shape(img)
    shapeF = tf.cast(shape, tf.float32)

    # Gaussian Noise
    gNoise = tf.random.normal(shape, gMean, gStd)

    img += gNoise

    # Salt and pepper noise
    spMask = tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spAmountP), tf.float32)
    spNoise = 255*tf.cast(tf.math.less(tf.random.uniform(shape, dtype=tf.float32), spRatio), tf.float32)

    img = tf.math.add(tf.math.multiply(img, 1.0 - spMask), tf.math.multiply(spNoise, spMask))

    # Speckles
    sNoise = speckleVar * tf.random.normal(shape)
    img = img + tf.math.multiply(img, sNoise)

    img = tf.clip_by_value(img, 0, 255)

    return img, lab

# %%
def clipValue(img, lab):
    img = tf.clip_by_value(img, 0.0, 255.0)
    return img, lab

# %%
def valPreprocessA(img, lab):
        
        img = tf.image.crop_to_bounding_box(img,
                                            (IMG_HEIGHT-CROP_HEIGHT) // 2,
                                            (IMG_WIDTH-CROP_WIDTH) // 2,
                                            CROP_HEIGHT,
                                            CROP_WIDTH)
        
        return img, lab

# %% [markdown]
# #### Label extractor

# %%
def extractGenderLabel(img, lab):
    
    lab = lab['gender']
    
    return img, lab

# %%
def extractAgeLabel(img, lab):
    
    lab = lab['age']
    
    return img, lab

# %% [markdown]
# ### Generate Folds for K-Folds validation

# %%
def generateFoldDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, valBatchSize, trainConfigureDs=None, trainPreBatch=[], trainPostBatch=[], valConfigureDs=None, valPreBatch=[], valPostBatch=[]):
    '''
        Returns list of (train, validation) datasets
    '''
    
    N = len(foldFiles)
    
    folds = []
    
    for i in range(N):
        
        trainFiles = foldFiles[:i]
        if(i < N-1):
            trainFiles.extend(foldFiles[i+1:])
            
        valFiles = foldFiles[i]
        
        trainDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, trainBatchSize, configureDs=trainConfigureDs, preBatch=trainPreBatch, postBatch=trainPostBatch)
        valDs = generateDs(foldFiles, imgBaseFolder, imgPrefix, genderMap, ageMap, genderDepth, ageDepth, imgWidth, imgHeight, valBatchSize, configureDs=valConfigureDs, preBatch=valPreBatch, postBatch=valPostBatch)
        
        folds.append((trainDs, valDs))
        
    return folds

# %%
genParams = {
            "rotation": [-math.pi, math.pi],
            "shearX": [-0.2, 0.2],
            "shearY": [-0.2, 0.2],
            
            "zoom": [0.8, 1.2], # +- 20%
            "hTranslation": [-0.2, 0.2], # +- 20%
            "vTranslation": [-0.2, 0.2], # +- 20%
            
            "gaussianMean": 0.0,
            "gaussianStd": 2.0,
            
            "spAmount": 0.0001,
            "spRatio": 0.5,
            
            "speckleVar": 0.01
        }

# %%
trainPreprocessB = partial(preprocessB,
                           rotL = genParams['rotation'][0],
                           rotH = genParams['rotation'][1],
                           shXL = genParams['shearX'][0],
                           shXH = genParams['shearX'][1], 
                           shYL = genParams['shearY'][0],
                           shYH = genParams['shearY'][1],
                           zoomL = genParams['zoom'][0],
                           zoomH = genParams['zoom'][1],
                           hTransL = genParams['hTranslation'][0],
                           hTransH = genParams['hTranslation'][1],
                           vTransL = genParams['vTranslation'][0],
                           vTransH = genParams['vTranslation'][1])

# %%
trainPreprocessC = partial(preprocessNoise,
                           gMean = genParams['gaussianMean'],
                           gStd = genParams['gaussianStd'],
                           spAmountP = genParams['spAmount'],
                           spRatio = genParams['spRatio'],
                           speckleVar = genParams['speckleVar'])

# %%
trainPreBatch = [("train_process_a", trainPreprocessA)]
trainPostBatch = [("train_process_b", trainPreprocessB),
                  ("train_process_c", trainPreprocessC),
                  ("train_clip", clipValue),
                  ("train_extract_gender", extractGenderLabel)]

valPreBatch = [("val_process_a", valPreprocessA), 
               ("val_extract_gender", extractGenderLabel)]

# %%
folds = generateFoldDs(foldFiles, "adience/faces", "coarse_tilt_aligned_face", genderMap, ageMap, 2, 8, 
                       IMG_WIDTH, IMG_HEIGHT, TRAIN_BATCH_SIZE, VAL_BATCH_SIZE, 
                       trainConfigureDs=trainConfigPerformance, trainPreBatch=trainPreBatch, 
                       trainPostBatch=trainPostBatch,
                       valConfigureDs=valConfigPerformance, valPreBatch=valPreBatch)
# Out:
# 2022-11-06 14:00:02.068802: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2022-11-06 14:00:02.563711: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1532] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 2605 MB memory:  -> device: 0, name: NVIDIA TITAN RTX, pci bus id: 0000:02:00.0, compute capability: 7.5

# %%
len(folds)
# Out:
# 5

# %% [markdown]
# ### Check data

# %%
for x,y in folds[0][0].take(1):
    pass

# %%
x
# Out:
# <tf.Tensor: shape=(4, 227, 227, 3), dtype=float32, numpy=
# array([[[[0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [3.13741708e+00, 0.00000000e+00, 0.00000000e+00],
#          [6.52293205e-01, 2.75905013e-01, 8.99052680e-01],
#          ...,
#          [0.00000000e+00, 0.00000000e+00,
+00, 0.00000000e+00],
#          [0.00000000e+00, 1.85606587e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 1.01261127e+00],
#          ...,
#          [1.52785945e+00, 9.57687736e-01, 8.66787970e-01],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [2.95014811e+00, 0.00000000e+00, 2.86324620e+00]],
#
#         [[7.14764714e-01, 1.88549173e+00, 2.94532275e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [8.16386044e-01, 2.91235852e+00, 0.00000000e+00],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 1.10821140e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [7.58230150e-01, 0.00000000e+00, 2.21718359e+00]],
#
#         [[2.54958820e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [8.76267016e-01, 0.00000000e+00, 3.88706535e-01],
#          ...,
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [0.00000000e+00, 0.00000000e+00, 0.00000000e+00],
#          [1.26093864e+00, 0.00000000e+00, 0.00000000e+00]]]],
#       dtype=float32)>

# %%
y
# Out:
# <tf.Tensor: shape=(4, 2), dtype=float32, numpy=
# array([[1., 0.],
#        [1., 0.],
#        [0., 1.],
#        [1., 0.]], dtype=float32)>

# %%
fig1, ax1 = plt.subplots(nrows=TRAIN_BATCH_SIZE, ncols=1)

if(TRAIN_BATCH_SIZE is None or TRAIN_BATCH_SIZE == 1):
    ax1.imshow(x/255)
    ax1.set_title(y)
else:
    for i in range(TRAIN_BATCH_SIZE):
        ax1[i].imshow(x[i]/255)
        ax1[i].set_title(f"Gender:{y[i]}")
        
plt.tight_layout()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %% [markdown]
# ### Model

# %%
def createModel():
    inp = tf.keras.Input(shape=(CROP_HEIGHT, CROP_WIDTH, 3))

    conv1 = tf.keras.layers.Conv2D(64, 7, strides=(4,4), activation='relu', name='conv1')
    pool1 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool1')

    conv2 = tf.keras.layers.Conv2D(128, 5, activation='relu', name='conv2')
    pool2 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool2')

    conv3 = tf.keras.layers.Conv2D(256, 3, activation='relu', name='conv3')
    pool3 = tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=2, name='pool3')

    flat1 = tf.keras.layers.Flatten(name='flat1')
    fc1 = tf.keras.layers.Dense(128, activation='relu', name='fc1')
    do1 = tf.keras.layers.Dropout(0.5, name='do1')

    fc2 = tf.keras.layers.Dense(2, activation='softmax', name='fc2')

    o = inp / 127.5 - 1.0
    
    o = conv1(o)
    o = pool1(o)

    o = conv2(o)
    o = pool2(o)

    o = conv3(o)
    o = pool3(o)

    o = flat1(o)
    o = fc1(o)
    o = do1(o)

    o = fc2(o)

    model = tf.keras.models.Model(inputs=inp, outputs=o, name='CNN_1')
    
    return model

# %%
model = createModel()

# %%
model.summary()
# Out:
# Model: "CNN_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 227, 227, 3)]     0
#
#  tf.math.truediv (TFOpLambda  (None, 227, 227, 3)      0
#  )
#
#  tf.math.subtract (TFOpLambd  (None, 227, 227, 3)      0
#  a)
#
#  conv1 (Conv2D)              (None, 56, 56, 64)        9472
#
#  pool1 (MaxPooling2D)        (None, 27, 27, 64)        0
#
#  conv2 (Conv2D)              (None, 23, 23, 128)       204928
#
#  pool2 (MaxPooling2D)        (None, 11, 11, 128)       0
#
#  conv3 (Conv2D)              (None, 9, 9, 256)         295168
#
#  pool3 (MaxPooling2D)        (None, 4, 4, 256)         0
#
#  flat1 (Flatten)             (None, 4096)              0
#
#  fc1 (Dense)                 (None, 128)               524416
#
#  do1 (Dropout)               (None, 128)               0
#
#  fc2 (Dense)                 (None, 2)                 258
#
# =================================================================
# Total params: 1,034,242
# Trainable params: 1,034,242
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile Model

# %%
STEPS_PER_EPOCH = 1000
EPOCH = 300

START_EPOCH = 0
END_EPOCH = START_EPOCH + EPOCH

# %% [markdown]
# #### Learning Rate Schedule

# %%
def schedule(epoch, lr):
    return lr

# %%
logBasePath = "log/CNN_4"
logPrefix = "log"

# %%
for i, (train, val) in enumerate([folds[0]]):
    
    model = createModel()
    
    opt = tf.keras.optimizers.Adam(learning_rate=0.000001)
    loss = tf.keras.losses.CategoricalCrossentropy()
    metrics = ['accuracy']
    
    model.compile(optimizer=opt, loss=loss, metrics=metrics)
    
    tboardCb = tf.keras.callbacks.TensorBoard(log_dir=f"{logBasePath}/{logPrefix}_{i}", histogram_freq=1, profile_batch=(2,10))
    lrSchedule = tf.keras.callbacks.LearningRateScheduler(schedule)
    
    cbs = [tboardCb]
    
    model.evaluate(val)
    model.fit(train, initial_epoch=START_EPOCH, epochs=END_EPOCH, steps_per_epoch=STEPS_PER_EPOCH, callbacks=cbs, validation_data=val)
# Out:
# 2022-11-06 14:00:25.131417: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-06 14:00:25.131447: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-06 14:00:25.131472: I tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1665] Profiler found 1 GPUs
# 2022-11-06 14:00:25.131764: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so.11.2'; dlerror: libcupti.so.11.2: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/ntcadmin/env/trt-11.0/TensorRT-7.1.3.4/lib:
# 2022-11-06 14:00:25.131850: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcupti.so'; dlerror: libcupti.so: cannot open shared object file: No such file or directory; LD_LIBRARY_PATH: /usr/local/cuda-11.2/lib64:/home/ntcadmin/env/trt-11.0/TensorRT-7.1.3.4/lib:
# 2022-11-06 14:00:25.131869: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:135] cuptiGetTimestamp: error 999:
# 2022-11-06 14:00:25.131879: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:184] cuptiSubscribe: ignored due to a previous error.
# 2022-11-06 14:00:25.131886: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:00:25.131894: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1716] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2022-11-06 14:00:25.131922: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-06 14:00:25.131947: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:140] cuptiFinalize: ignored due to a previous error.
# 2022-11-06 14:00:25.131953: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:00:25.131957: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1808] function cupti_interface_->Finalize()failed with error
# 2022-11-06 14:00:25.825137: I tensorflow/stream_executor/cuda/cuda_dnn.cc:384] Loaded cuDNN version 8100
# 3528/3528 [==============================] - 13s 3ms/step - loss: 0.6938 - accuracy: 0.5231
# Epoch 1/300
#   18/1000 [..............................] - ETA: 9s - loss: 0.7100 - accuracy: 0.4444
# 2022-11-06 14:00:39.034384: I tensorflow/core/profiler/lib/profiler_session.cc:99] Profiler session initializing.
# 2022-11-06 14:00:39.034435: I tensorflow/core/profiler/lib/profiler_session.cc:114] Profiler session started.
# 2022-11-06 14:00:39.034521: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-06 14:00:39.034545: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:184] cuptiSubscribe: ignored due to a previous error.
# 2022-11-06 14:00:39.034558: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:00:39.034570: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1716] function cupti_interface_->Subscribe( &subscriber_, (CUpti_CallbackFunc)ApiCallback, this)failed with error
# 2022-11-06 14:00:39.093847: I tensorflow/core/profiler/lib/profiler_session.cc:66] Profiler session collecting data.
# 2022-11-06 14:00:39.094037: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:140] cuptiFinalize: ignored due to a previous error.
# 2022-11-06 14:00:39.094057: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:457] cuptiGetResultString: ignored due to a previous error.
# 2022-11-06 14:00:39.094068: E tensorflow/core/profiler/internal/gpu/cupti_tracer.cc:1808] function cupti_interface_->Finalize()failed with error
# 2022-11-06 14:00:39.102341: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-06 14:00:39.102362: E tensorflow/core/profiler/internal/gpu/cupti_error_manager.cc:133] cuptiGetTimestamp: ignored due to a previous error.
# 2022-11-06 14:00:39.102369: I tensorflow/core/profiler/internal/gpu/cupti_collector.cc:521]  GpuTracer has collected 0 callback api events and 0 activity events.
# 2022-11-06 14:00:39.104234: I tensorflow/core/profiler/lib/profiler_session.cc:126] Profiler session tear down.
# 2022-11-06 14:00:39.107465: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39
#
# 2022-11-06 14:00:39.109096: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for trace.json.gz to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.trace.json.gz
# 2022-11-06 14:00:39.137170: I tensorflow/core/profiler/rpc/client/save_profile.cc:136] Creating directory: log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39
#
# 2022-11-06 14:00:39.142517: I tensorflow/core/profiler/rpc/client/save_profile.cc:142] Dumped gzipped tool data for memory_profile.json.gz to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.memory_profile.json.gz
# 2022-11-06 14:00:39.142783: I tensorflow/core/profiler/rpc/client/capture_profile.cc:251] Creating directory: log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39
# Dumped tool data for xplane.pb to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.xplane.pb
# Dumped tool data for overview_page.pb to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.overview_page.pb
# Dumped tool data for input_pipeline.pb to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.input_pipeline.pb
# Dumped tool data for tensorflow_stats.pb to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.tensorflow_stats.pb
# Dumped tool data for kernel_stats.pb to log/CNN_4/log_0/plugins/profile/2022_11_06_14_00_39/ntcadmin-scse.kernel_stats.pb
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6963 - accuracy: 0.5082 - val_loss: 0.6912 - val_accuracy: 0.5335
# Epoch 2/300
#    9/1000 [..............................] - ETA: 6s - loss: 0.6935 - accuracy: 0.5278
# 2022-11-06 14:00:55.538777: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 49152000 exceeds 10% of free system memory.
# 2022-11-06 14:00:55.559935: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 70778880 exceeds 10% of free system memory.
# 2022-11-06 14:00:55.585634: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 125829120 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6975 - accuracy: 0.4988 - val_loss: 0.6896 - val_accuracy: 0.5322
# Epoch 3/300
#   18/1000 [..............................] - ETA: 5s - loss: 0.6795 - accuracy: 0.6250
# 2022-11-06 14:01:11.657345: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 49152000 exceeds 10% of free system memory.
# 2022-11-06 14:01:11.678472: W tensorflow/core/framework/cpu_allocator_impl.cc:82] Allocation of 70778880 exceeds 10% of free system memory.
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6848 - accuracy: 0.5577 - val_loss: 0.6883 - val_accuracy: 0.5509
# Epoch 4/300
# 1000/1000 [==============================] - 16s 16ms/step - loss: 0.6879 - accuracy: 0.5465 - val_loss: 0.6869 - val_accuracy: 0.5541
# Epoch 5/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6934 - accuracy: 0.5120 - val_loss: 0.6864 - val_accuracy: 0.5708
# Epoch 6/300
# 1000/1000 [==============================] - 19s 19ms/step - loss: 0.6781 - accuracy: 0.5717 - val_loss: 0.6894 - val_accuracy: 0.5272
# Epoch 7/300
# 1000/1000 [==============================] - 18s 18ms/step - loss: 0.6907 - accuracy: 0.5400 - val_loss: 0.6881 - val_accuracy: 0.5254
# Epoch 8/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.6938 - accuracy: 0.5015 - val_loss: 0.6844 - val_accuracy: 0.5714
# Epoch 9/300
# 1000/1000 [==============================] - 17s 17ms/step - loss: 0.
300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6773 - accuracy: 0.5673 - val_loss: 0.6616 - val_accuracy: 0.6010
# Epoch 66/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6587 - accuracy: 0.6090 - val_loss: 0.6650 - val_accuracy: 0.5886
# Epoch 67/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6718 - accuracy: 0.5755 - val_loss: 0.6727 - val_accuracy: 0.5635
# Epoch 68/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6819 - accuracy: 0.5565 - val_loss: 0.6595 - val_accuracy: 0.6125
# Epoch 69/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6763 - accuracy: 0.5775 - val_loss: 0.6625 - val_accuracy: 0.5932
# Epoch 70/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6628 - accuracy: 0.5995 - val_loss: 0.6597 - val_accuracy: 0.6200
# Epoch 71/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6725 - accuracy: 0.5803 - val_loss: 0.6593 - val_accuracy: 0.6202
# Epoch 72/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6776 - accuracy: 0.5720 - val_loss: 0.6596 - val_accuracy: 0.6073
# Epoch 73/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6588 - accuracy: 0.6158 - val_loss: 0.6748 - val_accuracy: 0.5657
# Epoch 74/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6743 - accuracy: 0.5650 - val_loss: 0.6725 - val_accuracy: 0.5645
# Epoch 75/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6799 - accuracy: 0.5642 - val_loss: 0.6579 - val_accuracy: 0.6186
# Epoch 76/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6738 - accuracy: 0.5962 - val_loss: 0.6631 - val_accuracy: 0.5873
# Epoch 77/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6597 - accuracy: 0.6055 - val_loss: 0.6594 - val_accuracy: 0.6311
# Epoch 78/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6743 - accuracy: 0.5740 - val_loss: 0.6631 - val_accuracy: 0.6267
# Epoch 79/300
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6765 - accuracy: 0.5727 - val_loss: 0.6576 - val_accuracy: 0.6228
# Epoch 80/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6567 - accuracy: 0.6125 - val_loss: 0.6931 - val_accuracy: 0.5512
# Epoch 81/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6745 - accuracy: 0.5750 - val_loss: 0.6725 - val_accuracy: 0.5629
# Epoch 82/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6795 - accuracy: 0.5610 - val_loss: 0.6570 - val_accuracy: 0.6153
# Epoch 83/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6725 - accuracy: 0.5925 - val_loss: 0.6573 - val_accuracy: 0.6087
# Epoch 84/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6553 - accuracy: 0.6033 - val_loss: 0.6615 - val_accuracy: 0.6245
# Epoch 85/300
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.6749 - accuracy: 0.5778 - val_loss: 0.6561 - val_accuracy: 0.6134
# Epoch 86/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6707 - accuracy: 0.5903 - val_loss: 0.6571 - val_accuracy: 0.6317
# Epoch 87/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6581 - accuracy: 0.6047 - val_loss: 0.7136 - val_accuracy: 0.5413
# Epoch 88/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6760 - accuracy: 0.5785 - val_loss: 0.6663 - val_accuracy: 0.5747
# Epoch 89/300
# 1000/1000 [==============================] - 32s 32ms/step - loss: 0.6783 - accuracy: 0.5650 - val_loss: 0.6553 - val_accuracy: 0.6153
# Epoch 90/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6679 - accuracy: 0.5982 - val_loss: 0.6544 - val_accuracy: 0.6173
# Epoch 91/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6543 - accuracy: 0.6140 - val_loss: 0.6539 - val_accuracy: 0.6207
# Epoch 92/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6752 - accuracy: 0.5698 - val_loss: 0.6569 - val_accuracy: 0.6069
# Epoch 93/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.
300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6633 - accuracy: 0.6033 - val_loss: 0.6511 - val_accuracy: 0.6351
# Epoch 154/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6527 - accuracy: 0.6258 - val_loss: 0.7201 - val_accuracy: 0.5489
# Epoch 155/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6671 - accuracy: 0.5847 - val_loss: 0.6527 - val_accuracy: 0.6039
# Epoch 156/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6686 - accuracy: 0.5850 - val_loss: 0.6457 - val_accuracy: 0.6364
# Epoch 157/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6648 - accuracy: 0.6008 - val_loss: 0.6452 - val_accuracy: 0.6350
# Epoch 158/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6445 - accuracy: 0.6277 - val_loss: 0.6469 - val_accuracy: 0.6215
# Epoch 159/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 0.6653 - accuracy: 0.5860 - val_loss: 0.6445 - val_accuracy: 0.6373
# Epoch 160/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6625 - accuracy: 0.6008 - val_loss: 0.6464 - val_accuracy: 0.6447
# Epoch 161/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6598 - accuracy: 0.6145 - val_loss: 0.7044 - val_accuracy: 0.5525
# Epoch 162/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6600 - accuracy: 0.6045 - val_loss: 0.6470 - val_accuracy: 0.6187
# Epoch 163/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6677 - accuracy: 0.5845 - val_loss: 0.6462 - val_accuracy: 0.6233
# Epoch 164/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6576 - accuracy: 0.6145 - val_loss: 0.6650 - val_accuracy: 0.5876
# Epoch 165/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6431 - accuracy: 0.6285 - val_loss: 0.6497 - val_accuracy: 0.6130
# Epoch 166/300
# 1000/1000 [==============================] - 34s 34ms/step - loss: 0.6671 - accuracy: 0.5947 - val_loss: 0.6459 - val_accuracy: 0.6442
# Epoch 167/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6680 - accuracy: 0.5895 - val_loss: 0.6431 - val_accuracy: 0.6337
# Epoch 168/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 0.6671 - accuracy: 0.5978 - val_loss: 0.6549 - val_accuracy: 0.6022
# Epoch 169/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6520 - accuracy: 0.6022 - val_loss: 0.6446 - val_accuracy: 0.6407
# Epoch 170/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6722 - accuracy: 0.5773 - val_loss: 0.6463 - val_accuracy: 0.6425
# Epoch 171/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6588 - accuracy: 0.6205 - val_loss: 0.6662 - val_accuracy: 0.5832
# Epoch 172/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6438 - accuracy: 0.6292 - val_loss: 0.6487 - val_accuracy: 0.6168
# Epoch 173/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6667 - accuracy: 0.5790 - val_loss: 0.6453 - val_accuracy: 0.6452
# Epoch 174/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6656 - accuracy: 0.5863 - val_loss: 0.6432 - val_accuracy: 0.6333
# Epoch 175/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6676 - accuracy: 0.6020 - val_loss: 0.6485 - val_accuracy: 0.6155
# Epoch 176/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6495 - accuracy: 0.6135 - val_loss: 0.6445 - val_accuracy: 0.6302
# Epoch 177/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6651 - accuracy: 0.5930 - val_loss: 0.6492 - val_accuracy: 0.6408
# Epoch 178/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6557 - accuracy: 0.6187 - val_loss: 0.6534 - val_accuracy: 0.6246
# Epoch 179/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6461 - accuracy: 0.6255 - val_loss: 0.6482 - val_accuracy: 0.6186
# Epoch 180/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6662 - accuracy: 0.5810 - val_loss: 0.6423 - val_accuracy: 0.6351
# Epoch 181/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6627 - accuracy: 0.6008 - val_loss: 0.6549 - val_accuracy: 0.6190
# Epoch 182/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6679 - accuracy: 0.6028 - val_loss: 0.6430 - val_accuracy: 0.6352
# Epoch 183/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6508 - accuracy: 0.6075 - val_loss: 0.6446 - val_accuracy: 0.6459
# Epoch 184/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6673 - accuracy: 0.5953 - val_loss: 0.6446 - val_accuracy: 0.6464
# Epoch 185/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6603 - accuracy: 0.6035 - val_loss: 0.6416 - val_accuracy: 0.6445
# Epoch 186/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6395 - accuracy: 0.6490 - val_loss: 0.6438 - val_accuracy: 0.6297
# Epoch 187/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6617 - accuracy: 0.6008 - val_loss: 0.6573 - val_accuracy: 0.5950
# Epoch 188/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6674 - accuracy: 0.5853 - val_loss: 0.6407 - val_accuracy: 0.6464
# Epoch 189/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6624 - accuracy: 0.6065 - val_loss: 0.6467 - val_accuracy: 0.6205
# Epoch 190/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6501 - accuracy: 0.6058 - val_loss: 0.6474 - val_accuracy: 0.6379
# Epoch 191/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6643 - accuracy: 0.5960 - val_loss: 0.6412 - val_accuracy: 0.6377
# Epoch 192/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6642 - accuracy: 0.5955 - val_loss: 0.6445 - val_accuracy: 0.6238
# Epoch 193/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6404 - accuracy: 0.6475 - val_loss: 0.6426 - val_accuracy: 0.6325
# Epoch 194/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6575 - accuracy: 0.6000 - val_loss: 0.6683 - val_accuracy: 0.5782
# Epoch 195/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6730 - accuracy: 0.5785 - val_loss: 0.6410 - val_accuracy: 0.6340
# Epoch 196/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6588 - accuracy: 0.6095 - val_loss: 0.6489 - val_accuracy: 0.6166
# Epoch 197/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6457 - accuracy: 0.6158 - val_loss: 0.6414 - val_accuracy: 0.6484
# Epoch 198/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6637 - accuracy: 0.6035 - val_loss: 0.6400 - val_accuracy: 0.6462
# Epoch 199/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6611 - accuracy: 0.5997 - val_loss: 0.6428 - val_accuracy: 0.6287
# Epoch 200/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6416 - accuracy: 0.6382 - val_loss: 0.6522 - val_accuracy: 0.6110
# Epoch 201/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6543 - accuracy: 0.6065 - val_loss: 0.6673 - val_accuracy: 0.5775
# Epoch 202/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6707 - accuracy: 0.5897 - val_loss: 0.6388 - val_accuracy: 0.6418
# Epoch 203/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6534 - accuracy: 0.6277 - val_loss: 0.6535 - val_accuracy: 0.6044
# Epoch 204/300
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.6429 - accuracy: 0.6308 - val_loss: 0.6411 - val_accuracy: 0.6459
# Epoch 205/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6600 - accuracy: 0.5950 - val_loss: 0.6514 - val_accuracy: 0.6247
# Epoch 206/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6722 - accuracy: 0.5832 - val_loss: 0.6384 - val_accuracy: 0.6420
# Epoch 207/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6426 - accuracy: 0.6348 - val_loss: 0.6782 - val_accuracy: 0.5759
# Epoch 208/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6604 - accuracy: 0.5925 - val_loss: 0.6646 - val_accuracy: 0.5797
# Epoch 209/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6743 - accuracy: 0.5755 - val_loss: 0.6402 - val_accuracy: 0.6421
# Epoch 210/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6569 - accuracy: 0.6267 - val_loss: 0.6463 - val_accuracy: 0.6218
# Epoch 211/300
# 1000/1000 [==============================] - 30s 30ms/step - loss: 0.6408 - accuracy: 0.6365 - val_loss: 0.6496 - val_accuracy: 0.6303
# Epoch 212/300
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6650 - accuracy: 0.5972 - val_loss: 0.6418 - val_accuracy: 0.6300
# Epoch 213/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6642 - accuracy: 0.5935 - val_loss: 0.6434 - val_accuracy: 0.6435
# Epoch 214/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6388 - accuracy: 0.6378 - val_loss: 0.7455 - val_accuracy: 0.5470
# Epoch 215/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6650 - accuracy: 0.5982 - val_loss: 0.6618 - val_accuracy: 0.5868
# Epoch 216/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6711 - accuracy: 0.5832 - val_loss: 0.6394 - val_accuracy: 0.6424
# Epoch 217/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6583 - accuracy: 0.6187 - val_loss: 0.6393 - val_accuracy: 0.6368
# Epoch 218/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6362 - accuracy: 0.6342 - val_loss: 0.6376 - val_accuracy: 0.6474
# Epoch 219/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6585 - accuracy: 0.6037 - val_loss: 0.6409 - val_accuracy: 0.6290
# Epoch 220/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6591 - accuracy: 0.6060 - val_loss: 0.6472 - val_accuracy: 0.6328
# Epoch 221/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6546 - accuracy: 0.6223 - val_loss: 0.7163 - val_accuracy: 0.5558
# Epoch 222/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6592 - accuracy: 0.6080 - val_loss: 0.6471 - val_accuracy: 0.6143
# Epoch 223/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6645 - accuracy: 0.5960 - val_loss: 0.6378 - val_accuracy: 0.6438
# Epoch 224/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6545 - accuracy: 0.6208 - val_loss: 0.6381 - val_accuracy: 0.6503
# Epoch 225/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6354 - accuracy: 0.6405 - val_loss: 0.6380 - val_accuracy: 0.6378
# Epoch 226/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6628 - accuracy: 0.5975 - val_loss: 0.6385 - val_accuracy: 0.6492
# Epoch 227/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6612 - accuracy: 0.6000 - val_loss: 0.6353 - val_accuracy: 0.6489
# Epoch 228/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6565 - accuracy: 0.6075 - val_loss: 0.6755 - val_accuracy: 0.5773
# Epoch 229/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6511 - accuracy: 0.6093 - val_loss: 0.6374 - val_accuracy: 0.6495
# Epoch 230/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6635 - accuracy: 0.5962 - val_loss: 0.6385 - val_accuracy: 0.6407
# Epoch 231/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6492 - accuracy: 0.6270 - val_loss: 0.6710 - val_accuracy: 0.5647
# Epoch 232/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6461 - accuracy: 0.6158 - val_loss: 0.6404 - val_accuracy: 0.6331
# Epoch 233/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6627 - accuracy: 0.5930 - val_loss: 0.6415 - val_accuracy: 0.6488
# Epoch 234/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6629 - accuracy: 0.5950 - val_loss: 0.6395 - val_accuracy: 0.6324
# Epoch 235/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6618 - accuracy: 0.6150 - val_loss: 0.6391 - val_accuracy: 0.6343
# Epoch 236/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6428 - accuracy: 0.6212 - val_loss: 0.6363 - val_accuracy: 0.6455
# Epoch 237/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6607 - accuracy: 0.5960 - val_loss: 0.6370 - val_accuracy: 0.6518
# Epoch 238/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6509 - accuracy: 0.6240 - val_loss: 0.6557 - val_accuracy: 0.6047
# Epoch 239/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6402 - accuracy: 0.6367 - val_loss: 0.6375 - val_accuracy: 0.6371
# Epoch 240/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6590 - accuracy: 0.6018 - val_loss: 0.6353 - val_accuracy: 0.6541
# Epoch 241/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6560 - accuracy: 0.6080 - val_loss: 0.6332 - val_accuracy: 0.6529
# Epoch 242/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6590 - accuracy: 0.6115 - val_loss: 0.6372 - val_accuracy: 0.6358
# Epoch 243/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6389 - accuracy: 0.6317 - val_loss: 0.6362 - val_accuracy: 0.6402
# Epoch 244/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6618 - accuracy: 0.5855 - val_loss: 0.6384 - val_accuracy: 0.6498
# Epoch 245/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6512 - accuracy: 0.6273 - val_loss: 0.6375 - val_accuracy: 0.6499
# Epoch 246/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6292 - accuracy: 0.6455 - val_loss: 0.6391 - val_accuracy: 0.6343
# Epoch 247/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6621 - accuracy: 0.5965 - val_loss: 0.6359 - val_accuracy: 0.6356
# Epoch 248/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6603 - accuracy: 0.5993 - val_loss: 0.6398 - val_accuracy: 0.6469
# Epoch 249/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6547 - accuracy: 0.6192 - val_loss: 0.6381 - val_accuracy: 0.6333
# Epoch 250/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6438 - accuracy: 0.6250 - val_loss: 0.6409 - val_accuracy: 0.6416
# Epoch 251/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6628 - accuracy: 0.5907 - val_loss: 0.6360 - val_accuracy: 0.6527
# Epoch 252/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6574 - accuracy: 0.6083 - val_loss: 0.6357 - val_accuracy: 0.6388
# Epoch 253/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6342 - accuracy: 0.6430 - val_loss: 0.6340 - val_accuracy: 0.6448
# Epoch 254/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6571 - accuracy: 0.6065 - val_loss: 0.6601 - val_accuracy: 0.5922
# Epoch 255/300
# 1000/1000 [==============================] - 21s 21ms/step - loss: 0.6709 - accuracy: 0.5845 - val_loss: 0.6348 - val_accuracy: 0.6433
# Epoch 256/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6512 - accuracy: 0.6273 - val_loss: 0.6392 - val_accuracy: 0.6312
# Epoch 257/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6422 - accuracy: 0.6155 - val_loss: 0.6344 - val_accuracy: 0.6513
# Epoch 258/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6585 - accuracy: 0.6065 - val_loss: 0.6381 - val_accuracy: 0.6331
# Epoch 259/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6558 - accuracy: 0.6108 - val_loss: 0.6377 - val_accuracy: 0.6343
# Epoch 260/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6342 - accuracy: 0.6488 - val_loss: 0.6355 - val_accuracy: 0.6414
# Epoch 261/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6563 - accuracy: 0.6060 - val_loss: 0.6564 - val_accuracy: 0.5962
# Epoch 262/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6677 - accuracy: 0.5925 - val_loss: 0.6338 - val_accuracy: 0.6432
# Epoch 263/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6535 - accuracy: 0.6235 - val_loss: 0.6523 - val_accuracy: 0.6068
# Epoch 264/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6397 - accuracy: 0.6280 - val_loss: 0.6358 - val_accuracy: 0.6525
# Epoch 265/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6592 - accuracy: 0.6053 - val_loss: 0.6405 - val_accuracy: 0.6486
# Epoch 266/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6593 - accuracy: 0.6085 - val_loss: 0.6390 - val_accuracy: 0.6312
# Epoch 267/300
# 1000/1000 [==============================] - 20s 20ms/step - loss: 0.6317 - accuracy: 0.6440 - val_loss: 0.6507 - val_accuracy: 0.6143
# Epoch 268/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6518 - accuracy: 0.6212 - val_loss: 0.6669 - val_accuracy: 0.5854
# Epoch 269/300
# 1000/1000 [==============================] - 26s 26ms/step - loss: 0.6682 - accuracy: 0.5780 - val_loss: 0.6323 - val_accuracy: 0.6516
# Epoch 270/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6473 - accuracy: 0.6340 - val_loss: 0.6511 - val_accuracy: 0.6107
# Epoch 271/300
# 1000/1000 [==============================] - 22s 22ms/step - loss: 0.6326 - accuracy: 0.6380 - val_loss: 0.6427 - val_accuracy: 0.6370
# Epoch 272/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6554 - accuracy: 0.6012 - val_loss: 0.6331 - val_accuracy: 0.6535
# Epoch 273/300
# 1000/1000 [==============================] - 24s 25ms/step - loss: 0.6595 - accuracy: 0.6143 - val_loss: 0.6321 - val_accuracy: 0.6540
# Epoch 274/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6327 - accuracy: 0.6385 - val_loss: 0.7202 - val_accuracy: 0.5596
# Epoch 275/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6626 - accuracy: 0.5993 - val_loss: 0.6584 - val_accuracy: 0.5957
# Epoch 276/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6663 - accuracy: 0.5828 - val_loss: 0.6327 - val_accuracy: 0.6463
# Epoch 277/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6512 - accuracy: 0.6237 - val_loss: 0.6320 - val_accuracy: 0.6472
# Epoch 278/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6323 - accuracy: 0.6415 - val_loss: 0.6405 - val_accuracy: 0.6413
# Epoch 279/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6599 - accuracy: 0.5968 - val_loss: 0.6366 - val_accuracy: 0.6349
# Epoch 280/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6566 - accuracy: 0.6122 - val_loss: 0.6343 - val_accuracy: 0.6555
# Epoch 281/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6404 - accuracy: 0.6342 - val_loss: 0.7195 - val_accuracy: 0.5587
# Epoch 282/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6549 - accuracy: 0.6087 - val_loss: 0.6466 - val_accuracy: 0.6131
# Epoch 283/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6618 - accuracy: 0.5982 - val_loss: 0.6309 - val_accuracy: 0.6517
# Epoch 284/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6508 - accuracy: 0.6240 - val_loss: 0.6314 - val_accuracy: 0.6475
# Epoch 285/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6333 - accuracy: 0.6440 - val_loss: 0.6288 - val_accuracy: 0.6508
# Epoch 286/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6601 - accuracy: 0.5990 - val_loss: 0.6303 - val_accuracy: 0.6531
# Epoch 287/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6532 - accuracy: 0.6210 - val_loss: 0.6364 - val_accuracy: 0.6494
# Epoch 288/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6466 - accuracy: 0.6250 - val_loss: 0.6958 - val_accuracy: 0.5752
# Epoch 289/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6479 - accuracy: 0.6102 - val_loss: 0.6329 - val_accuracy: 0.6382
# Epoch 290/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6590 - accuracy: 0.6133 - val_loss: 0.6329 - val_accuracy: 0.6428
# Epoch 291/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6472 - accuracy: 0.6327 - val_loss: 0.6510 - val_accuracy: 0.6138
# Epoch 292/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6342 - accuracy: 0.6425 - val_loss: 0.6326 - val_accuracy: 0.6404
# Epoch 293/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6575 - accuracy: 0.6055 - val_loss: 0.6353 - val_accuracy: 0.6504
# Epoch 294/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6582 - accuracy: 0.6083 - val_loss: 0.6295 - val_accuracy: 0.6500
# Epoch 295/300
# 1000/1000 [==============================] - 23s 23ms/step - loss: 0.6525 - accuracy: 0.6198 - val_loss: 0.6421 - val_accuracy: 0.6238
# Epoch 296/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6395 - accuracy: 0.6233 - val_loss: 0.6295 - val_accuracy: 0.6552
# Epoch 297/300
# 1000/1000 [==============================] - 31s 31ms/step - loss: 0.6604 - accuracy: 0.6080 - val_loss: 0.6306 - val_accuracy: 0.6579
# Epoch 298/300
# 1000/1000 [==============================] - 24s 24ms/step - loss: 0.6400 - accuracy: 0.6330 - val_loss: 0.6581 - val_accuracy: 0.5950
# Epoch 299/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6328 - accuracy: 0.6410 - val_loss: 0.6319 - val_accuracy: 0.6439
# Epoch 300/300
# 1000/1000 [==============================] - 25s 25ms/step - loss: 0.6553 - accuracy: 0.6112 - val_loss: 0.6371 - val_accuracy: 0.6459
